# %% [markdown]
# ## I.1. Install

# %%
# # # GOOGLE Colab ONLY : Mount GOOGLE Drive
# from google.colab import drive
# drive.mount("/content/drive")

# %%
import os
# GOOGLE Colab ONLY : Get & store the default work path
user_path = os.path.join(os.getcwd(), "drive", "MyDrive", "Colab Notebooks")

# LOCAL : Get & store the current working path
# user_path = os.path.dirname(os.path.abspath("NoNeedFilename"))

print(user_path)
# Out:
# /content/drive/MyDrive/Colab Notebooks

# %%
# requirements_filepath = os.path.join(user_path, "requirements.txt")
# !pip install -r {requirements_filepath}

# %% [markdown]
# ## I.2. Libraries Import

# %%
import numpy as np
import matplotlib.pyplot as plt

# Machine Learning
# import keras
from keras.models import Model
from keras.preprocessing.image import ImageDataGenerator
from keras.layers import Dense, Dropout, GlobalAveragePooling2D, BatchNormalization
from keras.optimizers import Adam, Nadam, SGD, RMSprop
from sklearn.metrics import confusion_matrix, classification_report, f1_score

from keras.applications import EfficientNetB1, EfficientNetB2, EfficientNetB3, EfficientNetV2B1, EfficientNetV2B2, EfficientNetV2B3

# %% [markdown]
# ## I.4. Image Processing

# %% [markdown]
# ### I.4.2. Set Image Folder Path

# %%
# GOOGLE Colab ONLY
train_dir = os.path.join(user_path, "IMAGE_SPLIT", "train")
val_dir = os.path.join(user_path, "IMAGE_SPLIT", "val")
test_dir = os.path.join(user_path, "IMAGE_SPLIT", "test")

# LOCAL
# train_dir = r"C:\WORKSPACES\DATA\ML_DL\IMAGE_SPLIT\train"
# val_dir = r"C:\WORKSPACES\DATA\ML_DL\IMAGE_SPLIT\val"
# test_dir = r"C:\WORKSPACES\DATA\ML_DL\IMAGE_SPLIT\test"

# %% [markdown]
# ### I.4.3. Data augmentation techniques

# %%
train_datagen = ImageDataGenerator(
    rescale = 1./255,
    shear_range = 0.2,
    rotation_range = 20,
    width_shift_range = 0.1,
    height_shift_range = 0.1,
    zoom_range = [0.9, 1.25],
    brightness_range = [0.5, 1.5],
    horizontal_flip = True,
    vertical_flip = True
)

val_datagen = ImageDataGenerator(
    rescale = 1./255)

test_datagen = ImageDataGenerator(
    rescale = 1./255)

# %% [markdown]
# ### I.4.4. Setup Data generators

# %%
# Variables
batch_size = 32
height = 240
width = 240
image_shape = (height, width) # images of size 240x240 px with 3 color channels RGB automatically

train_generator = train_datagen.flow_from_directory(
    train_dir,
    class_mode = "categorical",
    target_size = image_shape,
    batch_size = batch_size
)

val_generator = val_datagen.flow_from_directory(
    val_dir,
    class_mode = "categorical",
    target_size = image_shape,
    batch_size = batch_size
)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    class_mode = "categorical",
    target_size = image_shape,
    batch_size = batch_size,
    shuffle = False
)
# Out:
# Found 4200 images belonging to 3 classes.
# Found 1200 images belonging to 3 classes.
# Found 600 images belonging to 3 classes.

# %% [markdown]
# ## II.1. Define variables and parameters

# %%
from keras.metrics import Precision, Recall, AUC

# Model to use for transfer learning
model_name = "EfficientNetV2B1"
ModelNameFunc = globals()[model_name]

# Work path
folder_name = f"{model_name}_L1N32L2N16-RMS"
work_path = os.path.join(user_path, folder_name)

# Top Architecture for the new model
l1_neurons = 32                 # Number of neurons on layer 1 (deeper)
l1_activation = "relu"
dropout = 0.4                   # 0.2 - 0.5
l2_neurons = 16                 # Number of neurons on layer 2
l2_activation = "relu"
output_neurons = 3              # This layer will have 3 neurons or units fully connected. In line with our 3 classes.
output_activation = "softmax"

# Metrics (parameter average = "macro" by default )
precision = Precision(name = "Precision")
recall = Recall(name = "Recall")
# f1 = (2 * (precision * recall) / (precision + recall))
# auc = AUC(name = "AUC")

# TRAIN : model.compile
compile_optimizer = "RMSprop"                  # Test : Nadam, RMSprop, SGD
compile_loss = "categorical_crossentropy"   # More than 2 classes, so categorical
compile_metrics = ["accuracy", precision, recall]

# TRAIN : model.fit
epochs = 30
verbose = 1

# FINE TUNE : model.compile
ft_compile_optimizer = RMSprop(learning_rate = 1e-5)
# ft_compile_optimizer : Very low learning rate. Test : Nadam, RMSprop, SGD
ft_compile_loss = "categorical_crossentropy"
ft_compile_metrics = ["accuracy", precision, recall]

# FINE TUNE : model.fit
ft_epochs = 15
ft_verbose = 1

# SAVE : File Path .h5
fileh5_path = os.path.join(work_path, f"{folder_name}_H5_Model", f"{folder_name}_TRAIN_ManualSave.h5")
ft_fileh5_path = os.path.join(work_path, f"{folder_name}_H5_Model", f"{folder_name}_FT_ManualSave.h5")

# %% [markdown]
# ## II.2. Define optimizations

# %% [markdown]
# ### II.2.1. Train optimizations (callbacks)

# %%
from keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint, TensorBoard, CSVLogger

# Define the early stopping
early_stopping = EarlyStopping(
    monitor = "val_loss",        # Metric to monitor
    patience = 5,                # Number of epochs with no improvement  (around 10% of nb of epochs)
    verbose = 1,                 # Verbosity mode (0, 1, or 2)
    restore_best_weights = True  # Whether to restore model weights to the best epoch
)

# Define the learning rate scheduler
lr_scheduler = ReduceLROnPlateau(
    monitor = "val_loss",       # Metric to monitor
    factor = 0.2,               # Factor by which to reduce the learning rate
    patience = 5,               # Number of epochs with no improvement (default = 10)
    verbose = 1,                # Verbosity mode (0, 1, or 2)
    min_lr = 1e-6               # Minimum learning rate
)

# Define the model checkpoint callback
checkpoint = ModelCheckpoint(
    # filepath = os.path.join(work_path, f"{model_name}_TRAIN_CheckPoint"), # to use if don't wanna save to a .h5 or .keras file
    filepath = os.path.join(work_path, f"{folder_name}_H5_Model", f"{folder_name}_TRAIN_MCPBest.h5"),
    monitor = "val_loss",       # Metric to monitor
    save_freq = "epoch",        # Default = epoch
    save_weights_only = False,  # Default = False
    save_best_only = True,      # Save only if the monitored metric improves
    mode = "min",               # "min" if monitoring loss, "max" if monitoring accuracy
    verbose = 1                 # Verbosity mode (0, 1, or 2)
)

# Define TensorBoard Logs
log_dir = os.path.join(work_path, f"{folder_name}_LOGS_TRAIN")
tensorboard = TensorBoard(
    log_dir = log_dir,
    write_graph = True,
    write_images = True,
    update_freq = "epoch"
)

# Define CSVLogger
CSV_Log_filename = os.path.join(work_path, f"{folder_name}_TRAIN.log")
CSV_Logger = CSVLogger(
    CSV_Log_filename,
    separator = "|",
    append = False
)

# Define the callbacks list
callbacks_list = [early_stopping, lr_scheduler, checkpoint, tensorboard, CSV_Logger]

# %% [markdown]
# ### II.2.2. Fine Tune Optimization

# %%
# Define the FT Early stopping
ft_early_stopping = EarlyStopping(
    monitor = "val_loss",
    patience = 3,
    verbose = 1,                 # Verbosity mode (0, 1, or 2)
    restore_best_weights = True  # Whether to restore model weights to the best epoch
)

# Define the FT Learning rate scheduler
ft_lr_scheduler = ReduceLROnPlateau(
    monitor = "val_loss",  # Metric to monitor
    factor = 0.2,          # Factor by which to reduce the learning rate
    patience = 3,          # Number of epochs with no improvement (default = 10)
    verbose = 1,           # Verbosity mode (0, 1, or 2)
    min_lr = 1e-6          # Minimum learning rate
)

# Define the FT checkpoint callback
ft_checkpoint = ModelCheckpoint(
    # filepath = os.path.join(work_path, f"{model_name}_FT_CheckPoint"), # to use if don't wanna save to a .h5 or .keras file
    filepath = os.path.join(work_path, f"{folder_name}_H5_Model", f"{folder_name}_FT_MCPBest.h5"),
    monitor = "val_loss",       # Metric to monitor
    save_freq = "epoch",        # Default = epoch
    save_weights_only = False,  # Default = False
    save_best_only = True,      # Save only if the monitored metric improves
    mode = "min",               # "min" if monitoring loss, "max" if monitoring accuracy
    verbose = 1                 # Verbosity mode (0, 1, or 2)
)

# Define the FT TensorBoard Logs
ft_log_dir = os.path.join(work_path, f"{folder_name}_LOGS_FT")
ft_tensorboard = TensorBoard(
    log_dir = ft_log_dir,
    write_graph=True,
    write_images=True,
    update_freq = "epoch"
)

# Define the FT CSVLogger
ft_CSV_Log_filename = os.path.join(work_path, f"{folder_name}_FT.log")
ft_CSV_Logger = CSVLogger(
    ft_CSV_Log_filename,
    separator = "|",
    append = False
)

# Define the FT callbacks list
ft_callbacks_list = [ft_early_stopping, ft_lr_scheduler, ft_checkpoint, ft_tensorboard, ft_CSV_Logger]

# %% [markdown]
# ## II.3. Pre train the model

# %% [markdown]
# ### II.3.1. Instantiate a base model with pre-trained model and weights

# %%
# First instantiate a base model with pre-trained weights
base_model = ModelNameFunc(
    include_top = False,
    weights = "imagenet",
    include_preprocessing = False, # ONLY for V2 model, otherwise put it as comment.
    input_shape = (height, width, output_neurons)
)

# %%
display(base_model.input)
# Out:
# <KerasTensor: shape=(None, 240, 240, 3) dtype=float32 (created by layer 'input_1')>

# %% [markdown]
# ### II.3.2. Define the new architecture on top

# %%
x = base_model.output
x = GlobalAveragePooling2D()(x) # Pooling
x = Dense(l1_neurons, activation = l1_activation)(x)
x = Dropout(dropout)(x)
x = Dense(l2_neurons, activation = l2_activation)(x)
x = BatchNormalization()(x)

predictions = Dense(output_neurons, activation = output_activation)(x)

model = Model(inputs = base_model.input, outputs = predictions)

# %%
print(model.input_shape)
# Out:
# (None, 240, 240, 3)

# %% [markdown]
# ### II.3.4. Compile the model

# %%
model.compile(
    optimizer = compile_optimizer,
    loss = compile_loss,
    metrics = compile_metrics
)

# %% [markdown]
# ### II.3.5. Train the model
# It's called "history" because it essentially keeps a historical record of various metrics and data related to how the model performed during training.

# %%
history = model.fit(
    x = train_generator,
    steps_per_epoch = train_generator.samples // batch_size + 1,
    validation_data = val_generator,
    validation_steps = val_generator.samples // batch_size + 1,
    epochs = epochs,
    verbose = verbose,
    callbacks = callbacks_list
)

# Save the model
model.save(fileh5_path)
# Out:
# Epoch 1/30
# 132/132 [==============================] - ETA: 0s - loss: 0.3536 - accuracy: 0.8848 - Precision: 0.9075 - Recall: 0.8617
# Epoch 1: val_loss improved from inf to 0.19538, saving model to /content/drive/MyDrive/Colab Notebooks/EfficientNetV2B1_L1N32L2N16-RMS/EfficientNetV2B1_L1N32L2N16-RMS_H5_Model/EfficientNetV2B1_L1N32L2N16-RMS_TRAIN_MCPBest.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 132/132 [==============================] - 195s 1s/step - loss: 0.3536 - accuracy: 0.8848 - Precision: 0.9075 - Recall: 0.8617 - val_loss: 0.1954 - val_accuracy: 0.9442 - val_Precision: 0.9496 - val_Recall: 0.9425 - lr: 0.0010
# Epoch 2/30
# 132/132 [==============================] - ETA: 0s - loss: 0.2075 - accuracy: 0.9369 - Precision: 0.9458 - Recall: 0.9269
# Epoch 2: val_loss improved from 0.19538 to 0.09404, saving model to /content/drive/MyDrive/Colab Notebooks/EfficientNetV2B1_L1N32L2N16-RMS/EfficientNetV2B1_L1N32L2N16-RMS_H5_Model/EfficientNetV2B1_L1N32L2N16-RMS_TRAIN_MCPBest.h5
# 132/132 [==============================] - 128s 973ms/step - loss: 0.2075 - accuracy: 0.9369 - Precision: 0.9458 - Recall: 0.9269 - val_loss: 0.0940 - val_accuracy: 0.9675 - val_Precision: 0.9707 - val_Recall: 0.9667 - lr: 0.0010
# Epoch 3/30
# 132/132 [==============================] - ETA: 0s - loss: 0.1728 - accuracy: 0.9486 - Precision: 0.9568 - Recall: 0.9431
# Epoch 3: val_loss did not improve from 0.09404
# 132/132 [==============================] - 128s 972ms/step - loss: 0.1728 - accuracy: 0.9486 - Precision: 0.9568 - Recall: 0.9431 - val_loss: 0.1603 - val_accuracy: 0.9358 - val_Precision: 0.9402 - val_Recall: 0.9308 - lr: 0.0010
# Epoch 4/30
# 132/132 [==============================] - ETA: 0s - loss: 0.1478 - accuracy: 0.9538 - Precision: 0.9605 - Recall: 0.9493
# Epoch 4: val_loss did not improve from 0.09404
# 132/132 [==============================] - 131s 986ms/step - loss: 0.1478 - accuracy: 0.9538 - Precision: 0.9605 - Recall: 0.9493 - val_loss: 0.0947 - val_accuracy: 0.9683 - val_Precision: 0.9740 - val_Recall: 0.9683 - lr: 0.0010
# Epoch 5/30
# 132/132 [==============================] - ETA: 0s - loss: 0.1240 - accuracy: 0.9621 - Precision: 0.9673 - Recall: 0.9571
# Epoch 5: val_loss improved from 0.09404 to 0.07177, saving model to /content/drive/MyDrive/Colab Notebooks/EfficientNetV2B1_L1N32L2N16-RMS/EfficientNetV2B1_L1N32L2N16-RMS_H5_Model/EfficientNetV2B1_L1N32L2N16-RMS_TRAIN_MCPBest.h5
# 132/132 [==============================] - 132s 996ms/step - loss: 0.1240 - accuracy: 0.9621 - Precision: 0.9673 - Recall: 0.9571 - val_loss: 0.0718 - val_accuracy: 0.9767 - val_Precision: 0.9791 - val_Recall: 0.9742 - lr: 0.0010
# Epoch 6/30
# 132/132 [==============================] - ETA: 0s - loss: 0.1443 - accuracy: 0.9602 - Precision: 0.9633 - Recall: 0.9550
# Epoch 6: val_loss did not improve from 0.07177
# 132/132 [==============================] - 128s 967ms/step - loss: 0.1443 - accuracy: 0.9602 - Precision: 0.9633 - Recall: 0.9550 - val_loss: 0.2513 - val_accuracy: 0.9175 - val_Precision: 0.9200 - val_Recall: 0.9108 - lr: 0.0010
# Epoch 7/30
# 132/132 [==============================] - ETA: 0s - loss: 0.1127 - accuracy: 0.9669 - Precision: 0.9705 - Recall: 0.9645
# Epoch 7: val_loss did not improve from 0.07177
# 132/132 [==============================] - 127s 959ms/step - loss: 0.1127 - accuracy: 0.9669 - Precision: 0.9705 - Recall: 0.9645 - val_loss: 0.0870 - val_accuracy: 0.9708 - val_Precision: 0.9741 - val_Recall: 0.9700 - lr: 0.0010
# Epoch 8/30
# 132/132 [==============================] - ETA: 0s - loss: 0.1026 - accuracy: 0.9674 - Precision: 0.9685 - Recall: 0.9650
# Epoch 8: val_loss did not improve from 0.07177
# 132/132 [==============================] - 127s 965ms/step - loss: 0.1026 - accuracy: 0.9674 - Precision: 0.9685 - Recall: 0.9650 - val_loss: 0.1993 - val_accuracy: 0.9317 - val_Precision: 0.9331 - val_Recall: 0.9300 - lr: 0.0010
# Epoch 9/30
# 132/132 [==============================] - ETA: 0s - loss: 0.1022 - accuracy: 0.9667 - Precision: 0.9705 - Recall: 0.9638
# Epoch 9: val_loss improved from 0.07177 to 0.05651, saving model to /content/drive/MyDrive/Colab Notebooks/EfficientNetV2B1_L1N32L2N16-RMS/EfficientNetV2B1_L1N32L2N16-RMS_H5_Model/EfficientNetV2B1_L1N32L2N16-RMS_TRAIN_MCPBest.h5
# 132/132 [==============================] - 130s 984ms/step - loss: 0.1022 - accuracy: 0.9667 - Precision: 0.9705 - Recall: 0.9638 - val_loss: 0.0565 - val_accuracy: 0.9875 - val_Precision: 0.9875 - val_Recall: 0.9867 - lr: 0.0010
# Epoch 10/30
# 132/132 [==============================] - ETA: 0s - loss: 0.1028 - accuracy: 0.9712 - Precision: 0.9749 - Recall: 0.9693
# Epoch 10: val_loss did not improve from 0.05651
# 132/132 [==============================] - 124s 941ms/step - loss: 0.1028 - accuracy: 0.9712 - Precision: 0.9749 - Recall: 0.9693 - val_loss: 0.0855 - val_accuracy: 0.9708 - val_Precision: 0.9708 - val_Recall: 0.9692 - lr: 0.0010
# Epoch 11/30
# 132/132 [==============================] - ETA: 0s - loss: 0.0849 - accuracy: 0.9729 - Precision: 0.9758 - Recall: 0.9714
# Epoch 11: val_loss did not improve from 0.05651
# 132/132 [==============================] - 126s 958ms/step - loss: 0.0849 - accuracy: 0.9729 - Precision: 0.9758 - Recall: 0.9714 - val_loss: 0.0718 - val_accuracy: 0.9792 - val_Precision: 0.9799 - val_Recall: 0.9775 - lr: 0.0010
# Epoch 12/30
# 132/132 [==============================] - ETA: 0s - loss: 0.0809 - accuracy: 0.9776 - Precision: 0.9790 - Recall: 0.9755
# Epoch 12: val_loss did not improve from 0.05651
# 132/132 [==============================] - 125s 949ms/step - loss: 0.0809 - accuracy: 0.9776 - Precision: 0.9790 - Recall: 0.9755 - val_loss: 0.0952 - val_accuracy: 0.9775 - val_Precision: 0.9783 - val_Recall: 0.9750 - lr: 0.0010
# Epoch 13/30
# 132/132 [==============================] - ETA: 0s - loss: 0.0783 - accuracy: 0.9769 - Precision: 0.9785 - Recall: 0.9752
# Epoch 13: val_loss did not improve from 0.05651
# 132/132 [==============================] - 131s 991ms/step - loss: 0.0783 - accuracy: 0.9769 - Precision: 0.9785 - Recall: 0.9752 - val_loss: 0.0729 - val_accuracy: 0.9783 - val_Precision: 0.9799 - val_Recall: 0.9775 - lr: 0.0010
# Epoch 14/30
# 132/132 [==============================] - ETA: 0s - loss: 0.0780 - accuracy: 0.9757 - Precision: 0.9773 - Recall: 0.9740Restoring model weights from the end of the best epoch: 9.
#
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
#
# Epoch 14: val_loss did not improve from 0.05651
# 132/132 [==============================] - 128s 963ms/step - loss: 0.0780 - accuracy: 0.9757 - Precision: 0.9773 - Recall: 0.9740 - val_loss: 0.1150 - val_accuracy: 0.9650 - val_Precision: 0.9665 - val_Recall: 0.9625 - lr: 0.0010
# Epoch 14: early stopping

# %% [markdown]
# ### II.3.7. Evaluate Pre trained model

# %%
# Predict the values from the Test Dataset
Y_pred = model.predict(test_generator, steps = test_generator.samples // batch_size + 1)

# Convert predictions classes from one hot vectors
Y_pred_classes = np.argmax(Y_pred, axis = 1)
# Out:
# 19/19 [==============================] - 9s 355ms/step

# %%
# Evaluate the model on the Test Dataset using `evaluate`
# f1 = F1Score(test_generator.classes, Y_pred_classes)
f1 = f1_score(test_generator.classes, Y_pred_classes, average = "macro")
print("F1 Score : ", f1)
print("Evaluate on Test Data")
results = model.evaluate(test_generator, batch_size = batch_size)
# Out:
# F1 Score :  0.9817029228119957
# Evaluate on Test Data
# 19/19 [==============================] - 5s 253ms/step - loss: 0.0470 - accuracy: 0.9817 - Precision: 0.9817 - Recall: 0.9817

# %% [markdown]
# ### II.3.8. Plot the Accuracy and the loss graphs

# %%
# Plot the Loss graph
plt.plot(history.history["loss"])
plt.plot(history.history["val_loss"])
plt.title("Model Loss")
plt.ylabel("Loss")
plt.xlabel("Epoch")
plt.legend(["Train", "Val"], loc = "upper left")
plt.show()

# %%
# Plot the Accuracy graph
plt.plot(history.history["accuracy"])
plt.plot(history.history["val_accuracy"])
plt.title("Model Accuracy")
plt.ylabel("Accuracy")
plt.xlabel("Epoch")
plt.legend(["Train", "Val"], loc = "lower left")
plt.show()

# %% [markdown]
# ### II.3.8. Trained Model : Confusion Matrix

# %%
# # Predict the values from the Test Dataset
# Y_pred = model.predict(test_generator, steps = test_generator.samples // batch_size + 1)

# # Convert predictions classes from one hot vectors
# Y_pred_classes = np.argmax(Y_pred, axis = 1)

# Convert validation observations from one hot vectors
# Y_true = np.argmax(test_generator.classes, axis = 1)
# OR
Y_true = test_generator.classes

# Compute the confusion matrix
cm = confusion_matrix(Y_true, Y_pred_classes)

# Print the confusion matrix
print("Confusion Matrix")
print(cm)

# Retrieve class names (label)
names_from_dir = sorted(os.listdir(val_dir))
dict(enumerate(names_from_dir))
#OR
class_names = list(val_generator.class_indices.keys())
# Check if the both are similar
print(names_from_dir == class_names)

# Print the classification report
print("Classification Report")
print(classification_report(Y_true, Y_pred_classes, target_names = class_names, digits = 4))
# Out:
# Confusion Matrix
# [[197   3   0]
#  [  3 197   0]
#  [  2   3 195]]
# True
# Classification Report
#               precision    recall  f1-score   support
#
#          Bee     0.9752    0.9850    0.9801       200
#    Butterfly     0.9704    0.9850    0.9777       200
#      Ladybug     1.0000    0.9750    0.9873       200
#
#     accuracy                         0.9817       600
#    macro avg     0.9819    0.9817    0.9817       600
# weighted avg     0.9819    0.9817    0.9817       600

# %% [markdown]
# ### II.3.9. Confusion Matrix Function

# %%
def plot_confusion_matrix(
    cm,
    classes,
    normalize = False,
    title = "Confusion matrix",
    cmap = plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype("float") / cm.sum(axis =1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)
    plt.imshow(cm, interpolation = "nearest", cmap = cmap)
    plt.title(title)
    plt.colorbar()
    plt.tight_layout()
    plt.ylabel("True label")
    plt.xlabel("Predicted label")

# %% [markdown]
# ### II.3.10. Trained Model : Confusion Matrix Graph

# %%
plot_confusion_matrix(
    cm,
    class_names,
    normalize = True,
    title = "Confusion matrix",
    cmap = plt.cm.Blues
    )
# Out:
# Normalized confusion matrix
# [[0.985 0.015 0.   ]
#  [0.015 0.985 0.   ]
#  [0.01  0.015 0.975]]

# %% [markdown]
# ## II.4. Fine Tuning
# This requires unfreezing the base model and then recompiling the model (necessary for the changes to take effect), and then resuming training.

# %% [markdown]
# ### II.4.1. Unfreeze the base model

# %%
# Unfreeze the base model
base_model.trainable = True

# %% [markdown]
# ### II.4.2. Re compile the model with a very low learning rate

# %%
# It's important to recompile your model after you make any changes
# to the `trainable` attribute of any inner layer, so that your changes
# are take into account
model.compile(
    optimizer = ft_compile_optimizer,
    loss = ft_compile_loss,
    metrics = ft_compile_metrics
)

# %% [markdown]
# ### II.4.3. Retraining the model

# %%
# Resume training
ft_history = model.fit(
    x = train_generator,
    steps_per_epoch = train_generator.samples // batch_size + 1,
    validation_data = val_generator,
    validation_steps = val_generator.samples // batch_size + 1,
    epochs = ft_epochs,
    verbose = ft_verbose,
    callbacks = ft_callbacks_list
)

# Save the Fine tuned model
model.save(ft_fileh5_path)
# Out:
# Epoch 1/15
# 132/132 [==============================] - ETA: 0s - loss: 0.0666 - accuracy: 0.9790 - Precision: 0.9826 - Recall: 0.9765
# Epoch 1: val_loss improved from inf to 0.05523, saving model to /content/drive/MyDrive/Colab Notebooks/EfficientNetV2B1_L1N32L2N16-RMS/EfficientNetV2B1_L1N32L2N16-RMS_H5_Model/EfficientNetV2B1_L1N32L2N16-RMS_FT_MCPBest.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 132/132 [==============================] - 177s 982ms/step - loss: 0.0666 - accuracy: 0.9790 - Precision: 0.9826 - Recall: 0.9765 - val_loss: 0.0552 - val_accuracy: 0.9883 - val_Precision: 0.9883 - val_Recall: 0.9867 - lr: 1.0000e-05
# Epoch 2/15
# 132/132 [==============================] - ETA: 0s - loss: 0.0679 - accuracy: 0.9824 - Precision: 0.9844 - Recall: 0.9793
# Epoch 2: val_loss improved from 0.05523 to 0.05217, saving model to /content/drive/MyDrive/Colab Notebooks/EfficientNetV2B1_L1N32L2N16-RMS/EfficientNetV2B1_L1N32L2N16-RMS_H5_Model/EfficientNetV2B1_L1N32L2N16-RMS_FT_MCPBest.h5
# 132/132 [==============================] - 128s 968ms/step - loss: 0.0679 - accuracy: 0.9824 - Precision: 0.9844 - Recall: 0.9793 - val_loss: 0.0522 - val_accuracy: 0.9867 - val_Precision: 0.9867 - val_Recall: 0.9858 - lr: 1.0000e-05
# Epoch 3/15
# 132/132 [==============================] - ETA: 0s - loss: 0.0656 - accuracy: 0.9833 - Precision: 0.9854 - Recall: 0.9795
# Epoch 3: val_loss improved from 0.05217 to 0.04726, saving model to /content/drive/MyDrive/Colab Notebooks/EfficientNetV2B1_L1N32L2N16-RMS/EfficientNetV2B1_L1N32L2N16-RMS_H5_Model/EfficientNetV2B1_L1N32L2N16-RMS_FT_MCPBest.h5
# 132/132 [==============================] - 130s 978ms/step - loss: 0.0656 - accuracy: 0.9833 - Precision: 0.9854 - Recall: 0.9795 - val_loss: 0.0473 - val_accuracy: 0.9875 - val_Precision: 0.9891 - val_Recall: 0.9875 - lr: 1.0000e-05
# Epoch 4/15
# 132/132 [==============================] - ETA: 0s - loss: 0.0570 - accuracy: 0.9838 - Precision: 0.9849 - Recall: 0.9817
# Epoch 4: val_loss improved from 0.04726 to 0.04625, saving model to /content/drive/MyDrive/Colab Notebooks/EfficientNetV2B1_L1N32L2N16-RMS/EfficientNetV2B1_L1N32L2N16-RMS_H5_Model/EfficientNetV2B1_L1N32L2N16-RMS_FT_MCPBest.h5
# 132/132 [==============================] - 129s 975ms/step - loss: 0.0570 - accuracy: 0.9838 - Precision: 0.9849 - Recall: 0.9817 - val_loss: 0.0462 - val_accuracy: 0.9850 - val_Precision: 0.9866 - val_Recall: 0.9850 - lr: 1.0000e-05
# Epoch 5/15
# 132/132 [==============================] - ETA: 0s - loss: 0.0597 - accuracy: 0.9843 - Precision: 0.9866 - Recall: 0.9814
# Epoch 5: val_loss improved from 0.04625 to 0.04464, saving model to /content/drive/MyDrive/Colab Notebooks/EfficientNetV2B1_L1N32L2N16-RMS/EfficientNetV2B1_L1N32L2N16-RMS_H5_Model/EfficientNetV2B1_L1N32L2N16-RMS_FT_MCPBest.h5
# 132/132 [==============================] - 128s 966ms/step - loss: 0.0597 - accuracy: 0.9843 - Precision: 0.9866 - Recall: 0.9814 - val_loss: 0.0446 - val_accuracy: 0.9883 - val_Precision: 0.9900 - val_Recall: 0.9883 - lr: 1.0000e-05
# Epoch 6/15
# 132/132 [==============================] - ETA: 0s - loss: 0.0519 - accuracy: 0.9857 - Precision: 0.9866 - Recall: 0.9850
# Epoch 6: val_loss improved from 0.04464 to 0.04344, saving model to /content/drive/MyDrive/Colab Notebooks/EfficientNetV2B1_L1N32L2N16-RMS/EfficientNetV2B1_L1N32L2N16-RMS_H5_Model/EfficientNetV2B1_L1N32L2N16-RMS_FT_MCPBest.h5
# 132/132 [==============================] - 135s 1s/step - loss: 0.0519 - accuracy: 0.9857 - Precision: 0.9866 - Recall: 0.9850 - val_loss: 0.0434 - val_accuracy: 0.9892 - val_Precision: 0.9908 - val_Recall: 0.9883 - lr: 1.0000e-05
# Epoch 7/15
# 132/132 [==============================] - ETA: 0s - loss: 0.0535 - accuracy: 0.9869 - Precision: 0.9888 - Recall: 0.9850
# Epoch 7: val_loss improved from 0.04344 to 0.04082, saving model to /content/drive/MyDrive/Colab Notebooks/EfficientNetV2B1_L1N32L2N16-RMS/EfficientNetV2B1_L1N32L2N16-RMS_H5_Model/EfficientNetV2B1_L1N32L2N16-RMS_FT_MCPBest.h5
# 132/132 [==============================] - 130s 988ms/step - loss: 0.0535 - accuracy: 0.9869 - Precision: 0.9888 - Recall: 0.9850 - val_loss: 0.0408 - val_accuracy: 0.9883 - val_Precision: 0.9892 - val_Recall: 0.9883 - lr: 1.0000e-05
# Epoch 8/15
# 132/132 [==============================] - ETA: 0s - loss: 0.0516 - accuracy: 0.9862 - Precision: 0.9883 - Recall: 0.9836
# Epoch 8: val_loss did not improve from 0.04082
# 132/132 [==============================] - 127s 959ms/step - loss: 0.0516 - accuracy: 0.9862 - Precision: 0.9883 - Recall: 0.9836 - val_loss: 0.0416 - val_accuracy: 0.9883 - val_Precision: 0.9883 - val_Recall: 0.9883 - lr: 1.0000e-05
# Epoch 9/15
# 132/132 [==============================] - ETA: 0s - loss: 0.0463 - accuracy: 0.9883 - Precision: 0.9893 - Recall: 0.9874
# Epoch 9: val_loss improved from 0.04082 to 0.03957, saving model to /content/drive/MyDrive/Colab Notebooks/EfficientNetV2B1_L1N32L2N16-RMS/EfficientNetV2B1_L1N32L2N16-RMS_H5_Model/EfficientNetV2B1_L1N32L2N16-RMS_FT_MCPBest.h5
# 132/132 [==============================] - 129s 980ms/step - loss: 0.0463 - accuracy: 0.9883 - Precision: 0.9893 - Recall: 0.9874 - val_loss: 0.0396 - val_accuracy: 0.9875 - val_Precision: 0.9891 - val_Recall: 0.9867 - lr: 1.0000e-05
# Epoch 10/15
# 132/132 [==============================] - ETA: 0s - loss: 0.0520 - accuracy: 0.9848 - Precision: 0.9873 - Recall: 0.9833
# Epoch 10: val_loss did not improve from 0.03957
# 132/132 [==============================] - 126s 955ms/step - loss: 0.0520 - accuracy: 0.9848 - Precision: 0.9873 - Recall: 0.9833 - val_loss: 0.0401 - val_accuracy: 0.9892 - val_Precision: 0.9891 - val_Recall: 0.9875 - lr: 1.0000e-05
# Epoch 11/15
# 132/132 [==============================] - ETA: 0s - loss: 0.0432 - accuracy: 0.9886 - Precision: 0.9893 - Recall: 0.9869
# Epoch 11: val_loss did not improve from 0.03957
# 132/132 [==============================] - 126s 957ms/step - loss: 0.0432 - accuracy: 0.9886 - Precision: 0.9893 - Recall: 0.9869 - val_loss: 0.0422 - val_accuracy: 0.9883 - val_Precision: 0.9892 - val_Recall: 0.9883 - lr: 1.0000e-05
# Epoch 12/15
# 132/132 [==============================] - ETA: 0s - loss: 0.0540 - accuracy: 0.9845 - Precision: 0.9859 - Recall: 0.9829
# Epoch 12: val_loss improved from 0.03957 to 0.03882, saving model to /content/drive/MyDrive/Colab Notebooks/EfficientNetV2B1_L1N32L2N16-RMS/EfficientNetV2B1_L1N32L2N16-RMS_H5_Model/EfficientNetV2B1_L1N32L2N16-RMS_FT_MCPBest.h5
# 132/132 [==============================] - 130s 982ms/step - loss: 0.0540 - accuracy: 0.9845 - Precision: 0.9859 - Recall: 0.9829 - val_loss: 0.0388 - val_accuracy: 0.9883 - val_Precision: 0.9883 - val_Recall: 0.9875 - lr: 1.0000e-05
# Epoch 13/15
# 132/132 [==============================] - ETA: 0s - loss: 0.0532 - accuracy: 0.9833 - Precision: 0.9850 - Recall: 0.9824
# Epoch 13: val_loss improved from 0.03882 to 0.03773, saving model to /content/drive/MyDrive/Colab Notebooks/EfficientNetV2B1_L1N32L2N16-RMS/EfficientNetV2B1_L1N32L2N16-RMS_H5_Model/EfficientNetV2B1_L1N32L2N16-RMS_FT_MCPBest.h5
# 132/132 [==============================] - 126s 954ms/step - loss: 0.0532 - accuracy: 0.9833 - Precision: 0.9850 - Recall: 0.9824 - val_loss: 0.0377 - val_accuracy: 0.9892 - val_Precision: 0.9892 - val_Recall: 0.9892 - lr: 1.0000e-05
# Epoch 14/15
# 132/132 [==============================] - ETA: 0s - loss: 0.0426 - accuracy: 0.9895 - Precision: 0.9912 - Recall: 0.9869
# Epoch 14: val_loss improved from 0.03773 to 0.03705, saving model to /content/drive/MyDrive/Colab Notebooks/EfficientNetV2B1_L1N32L2N16-RMS/EfficientNetV2B1_L1N32L2N16-RMS_H5_Model/EfficientNetV2B1_L1N32L2N16-RMS_FT_MCPBest.h5
# 132/132 [==============================] - 130s 985ms/step - loss: 0.0426 - accuracy: 0.9895 - Precision: 0.9912 - Recall: 0.9869 - val_loss: 0.0370 - val_accuracy: 0.9900 - val_Precision: 0.9908 - val_Recall: 0.9892 - lr: 1.0000e-05
# Epoch 15/15
# 132/132 [==============================] - ETA: 0s - loss: 0.0509 - accuracy: 0.9871 - Precision: 0.9895 - Recall: 0.9850
# Epoch 15: val_loss did not improve from 0.03705
# 132/132 [==============================] - 125s 949ms/step - loss: 0.0509 - accuracy: 0.9871 - Precision: 0.9895 - Recall: 0.9850 - val_loss: 0.0378 - val_accuracy: 0.9892 - val_Precision: 0.9900 - val_Recall: 0.9892 - lr: 1.0000e-05

# %% [markdown]
# ### II.4.4. Evaluation Fine Tune Model

# %%
# Evaluate the model on the Test Dataset using `evaluate`
# f1 = F1Score(test_generator.classes, Y_pred_classes)
ft_f1 = f1_score(test_generator.classes, Y_pred_classes, average = "macro")
print("F1 Score : ", ft_f1)
print("Evaluate on Test Data")
ft_results = model.evaluate(test_generator, batch_size = batch_size)
# Out:
# F1 Score :  0.9817029228119957
# Evaluate on Test Data
# 19/19 [==============================] - 5s 273ms/step - loss: 0.0355 - accuracy: 0.9900 - Precision: 0.9900 - Recall: 0.9900

# %%
# Plot the Loss graph
plt.plot(ft_history.history["loss"])
plt.plot(ft_history.history["val_loss"])
plt.title("Model Loss")
plt.ylabel("loss")
plt.xlabel("epoch")
plt.legend(["Train", "Val"], loc = "upper left")
plt.show()

# %%
# Plot the Accuracy graph
plt.plot(ft_history.history["accuracy"])
plt.plot(ft_history.history["val_accuracy"])
plt.title("Model Accuracy")
plt.ylabel("Accuracy")
plt.xlabel("Epoch")
plt.legend(["Train", "Val"], loc = "lower left")
plt.show()

# %% [markdown]
# ### II.4.5. Fine Tuned Model : Confusion Matrix

# %%
# # Predict the values from the validation dataset
# Y_pred = model.predict(test_generator, steps = test_generator.samples // batch_size + 1)

# # Convert predictions classes from one hot vectors
# Y_pred_classes = np.argmax(Y_pred, axis = 1)

# Convert validation observations from one hot vectors
# Y_true = np.argmax(test_generator.classes, axis = 1)
# OR
Y_true = test_generator.classes

# Compute the confusion matrix
ft_cm = confusion_matrix(Y_true, Y_pred_classes)

# Print the confusion matrix
print("Confusion Matrix")
print(ft_cm)

# Retrieve class names (label)
names_from_dir = sorted(os.listdir(val_dir))
dict(enumerate(names_from_dir))
#OR
class_names = list(val_generator.class_indices.keys())
# Check if the both are similar
print(names_from_dir == class_names)

# Print the classification report
print("Classification Report")
print(classification_report(Y_true, Y_pred_classes, target_names = class_names, digits = 4))
# Out:
# Confusion Matrix
# [[197   3   0]
#  [  3 197   0]
#  [  2   3 195]]
# True
# Classification Report
#               precision    recall  f1-score   support
#
#          Bee     0.9752    0.9850    0.9801       200
#    Butterfly     0.9704    0.9850    0.9777       200
#      Ladybug     1.0000    0.9750    0.9873       200
#
#     accuracy                         0.9817       600
#    macro avg     0.9819    0.9817    0.9817       600
# weighted avg     0.9819    0.9817    0.9817       600

# %% [markdown]
# ### II.4.5. Fine Tuned Model : Confusion Matrix Graph

# %%
plot_confusion_matrix(ft_cm,
                      class_names,
                      normalize = True,
                      title = "Confusion matrix",
                      cmap = plt.cm.Blues
                      )
# Out:
# Normalized confusion matrix
# [[0.985 0.015 0.   ]
#  [0.015 0.985 0.   ]
#  [0.01  0.015 0.975]]
