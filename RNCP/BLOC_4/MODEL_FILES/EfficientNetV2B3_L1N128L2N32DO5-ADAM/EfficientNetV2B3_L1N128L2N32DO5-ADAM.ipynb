# %% [markdown]
# ## I.1. Install

# %%
# # GOOGLE Colab ONLY : Mount GOOGLE Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
# GOOGLE Colab ONLY : Get & store the default work path
user_path = os.path.join(os.getcwd(), "drive", "MyDrive", "Colab Notebooks")

# LOCAL : Get & store the current working path
# user_path = os.path.dirname(os.path.abspath("NoNeedFilename"))

print(user_path)
# Out:
# /content/drive/MyDrive/Colab Notebooks

# %%
# requirements_filepath = os.path.join(user_path, "requirements.txt")
# !pip install -r {requirements_filepath}

# %% [markdown]
# ## I.2. Libraries Import

# %%
import numpy as np
import matplotlib.pyplot as plt

# Machine Learning
import keras
from keras.models import Model
from keras.preprocessing.image import ImageDataGenerator
from keras.layers import Dense, Dropout, GlobalAveragePooling2D, BatchNormalization
from keras.optimizers import Adam, Nadam, SGD, RMSprop
from sklearn.metrics import confusion_matrix, classification_report
from keras.applications import EfficientNetB1, EfficientNetB2, EfficientNetB3, EfficientNetV2B1, EfficientNetV2B2, EfficientNetV2B3

# %% [markdown]
# ## I.4. Image Processing

# %% [markdown]
# ### I.4.2. Set Image Folder Path

# %%
# GOOGLE Colab ONLY
train_dir = os.path.join(user_path, "IMAGE_SPLIT", "train")
val_dir = os.path.join(user_path, "IMAGE_SPLIT", "val")
test_dir = os.path.join(user_path, "IMAGE_SPLIT", "test")

# LOCAL
# train_dir = r"C:\WORKSPACES\DATA\ML_DL\IMAGE_SPLIT\train"
# val_dir = r"C:\WORKSPACES\DATA\ML_DL\IMAGE_SPLIT\val"
# test_dir = r"C:\WORKSPACES\DATA\ML_DL\IMAGE_SPLIT\test"

# %% [markdown]
# ### I.4.3. Data augmentation techniques

# %%
train_datagen = ImageDataGenerator(
    rescale = 1./255,
    shear_range = 0.2,
    rotation_range = 20,
    width_shift_range = 0.1,
    height_shift_range = 0.1,
    zoom_range = [0.9, 1.25],
    brightness_range = [0.5, 1.5],
    horizontal_flip = True,
    vertical_flip = True
)

val_datagen = ImageDataGenerator(
    rescale = 1./255)

test_datagen = ImageDataGenerator(
    rescale = 1./255)

# %% [markdown]
# ### I.4.4. Setup Data generators

# %%
# Variables
batch_size = 32
height = 240
width = 240
image_shape = (height, width) # images of size 240x240 px with 3 color channels RGB automatically


train_generator = train_datagen.flow_from_directory(
    train_dir,
    class_mode = "categorical",
    target_size = image_shape,
    batch_size = batch_size
)

val_generator = val_datagen.flow_from_directory(
    val_dir,
    class_mode = "categorical",
    target_size = image_shape,
    batch_size = batch_size
)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    class_mode = "categorical",
    target_size = image_shape,
    batch_size = batch_size,
    shuffle = False
)
# Out:
# Found 4200 images belonging to 3 classes.
# Found 1200 images belonging to 3 classes.
# Found 600 images belonging to 3 classes.

# %% [markdown]
# ## II.1. Define variables and parameters

# %%
from keras.metrics import Precision, Recall, F1Score, AUC

# Model to use for transfer learning
model_name = "EfficientNetV2B3"
ModelNameFunc = globals()[model_name]

# Work path
folder_name = f"{model_name}_L1N128L2N32DO5"
work_path = os.path.join(user_path, folder_name)

# Top Architecture for the new model
l1_neurons = 128                 # Number of neurons on layer 1 (deeper)
l1_activation = "relu"
dropout = 0.5                   # 0.2 - 0.5
l2_neurons = 32                 # Number of neurons on layer 2
l2_activation = "relu"
output_neurons = 3              # This layer will have 3 neurons or units fully connected. In line with our 3 classes.
output_activation = "softmax"

# Metrics (parameter average = "macro" by default )
precision = Precision(name = "Precision")
recall = Recall(name = "Recall")
# f1 = F1Score(name = "F1")
# auc = AUC(name = "AUC")

# TRAIN : model.compile
compile_optimizer = "Adam"                  # Test : Nadam, RMSprop, SGD
compile_loss = "categorical_crossentropy"   # More than 2 classes, so categorical
compile_metrics = ["accuracy", precision, recall]

# TRAIN : model.fit
epochs = 50
verbose = 1

# FINE TUNE : model.compile
ft_compile_optimizer = Adam(learning_rate = 1e-5)
# ft_compile_optimizer : Very low learning rate. Test : Nadam, RMSprop, SGD
ft_compile_loss = "categorical_crossentropy"
ft_compile_metrics = ["accuracy", precision, recall]

# FINE TUNE : model.fit
ft_epochs = 20
ft_verbose = 1

# SAVE : File Path .h5
fileh5_path = os.path.join(work_path, f"{folder_name}_H5_Model", f"{folder_name}_TRAIN_ManualSave.h5")
ft_fileh5_path = os.path.join(work_path, f"{folder_name}_H5_Model", f"{folder_name}_FT_ManualSave.h5")

# %% [markdown]
# ## II.2. Define optimizations

# %% [markdown]
# ### II.2.1. Train optimizations

# %%
from keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint, TensorBoard, CSVLogger

# Define the early stopping
early_stopping = EarlyStopping(
    monitor = "val_loss",        # Metric to monitor
    patience = 7,                # Number of epochs with no improvement  (around 10% of nb of epochs)
    verbose = 1,                 # Verbosity mode (0, 1, or 2)
    restore_best_weights = True  # Whether to restore model weights to the best epoch
)

# Define the learning rate scheduler
lr_scheduler = ReduceLROnPlateau(
    monitor = "val_loss",       # Metric to monitor
    factor = 0.2,               # Factor by which to reduce the learning rate
    patience = 5,               # Number of epochs with no improvement (default = 10)
    verbose = 1,                # Verbosity mode (0, 1, or 2)
    min_lr = 1e-6               # Minimum learning rate
)

# Define the model checkpoint callback
checkpoint = ModelCheckpoint(
    # filepath = os.path.join(user_path, f"{model_name}_TRAIN_CheckPoint"), # to use if don't wanna save to a .h5 or .keras file
    filepath = os.path.join(work_path, f"{folder_name}_H5_Model", f"{folder_name}_TRAIN_MCPBest.h5"),
    monitor = "val_loss",       # Metric to monitor
    save_freq = "epoch",        # Default = epoch
    save_weights_only = False,  # Default = False
    save_best_only = True,      # Save only if the monitored metric improves
    mode = "min",               # "min" if monitoring loss, "max" if monitoring accuracy
    verbose = 1                 # Verbosity mode (0, 1, or 2)
)

# Define TensorBoard Logs
log_dir = os.path.join(work_path, f"{folder_name}_LOGS_TRAIN")
tensorboard = TensorBoard(
    log_dir = log_dir,
    write_graph = True,
    write_images = True,
    update_freq = "epoch"
)

# Define CSVLogger
CSV_Log_filename = os.path.join(work_path, f"{folder_name}_TRAIN.log")
CSV_Logger = CSVLogger(
    CSV_Log_filename,
    separator = "|",
    append = False
)

# Include it in the callbacks list
callbacks_list = [early_stopping, lr_scheduler, checkpoint, tensorboard]

# %% [markdown]
# ### II.2.2. Fine Tune Optimization

# %%
# Define the FT Early stopping
ft_early_stopping = EarlyStopping(
    monitor = "val_loss",
    patience = 5,
    verbose = 1,                 # Verbosity mode (0, 1, or 2)
    restore_best_weights = True  # Whether to restore model weights to the best epoch
)

# Define the FT Learning rate scheduler
ft_lr_scheduler = ReduceLROnPlateau(
    monitor = "val_loss",  # Metric to monitor
    factor = 0.2,          # Factor by which to reduce the learning rate
    patience = 3,          # Number of epochs with no improvement (default = 10)
    verbose = 1,           # Verbosity mode (0, 1, or 2)
    min_lr = 1e-6          # Minimum learning rate
)

# Define the FT checkpoint callback
ft_checkpoint = ModelCheckpoint(
    # filepath = os.path.join(work_path, f"{model_name}_FT_CheckPoint"), # to use if don't wanna save to a .h5 or .keras file
    filepath = os.path.join(work_path, f"{model_name}_H5_Model", f"{model_name}_FT_MCPBest.h5"),
    monitor = "val_loss",       # Metric to monitor
    save_freq = "epoch",        # Default = epoch
    save_weights_only = False,  # Default = False
    save_best_only = True,      # Save only if the monitored metric improves
    mode = "min",               # "min" if monitoring loss, "max" if monitoring accuracy
    verbose = 1                 # Verbosity mode (0, 1, or 2)
)

# Define the FT TensorBoard Logs
ft_log_dir = os.path.join(work_path, f"{folder_name}_LOGS_FT")
ft_tensorboard = TensorBoard(
    log_dir = ft_log_dir,
    write_graph=True,
    write_images=True,
    update_freq = "epoch"
)

# Define the FT CSVLogger
ft_CSV_Log_filename = os.path.join(work_path, f"{folder_name}FT.log")
ft_CSV_Logger = CSVLogger(
    ft_CSV_Log_filename,
    separator = "|",
    append = False
)

# Define the FT callbacks list
ft_callbacks_list = [ft_early_stopping, ft_lr_scheduler, ft_checkpoint, ft_tensorboard, ft_CSV_Logger]

# %% [markdown]
# ## II.3. Pre train the model

# %% [markdown]
# ### II.3.1. Instantiate a base model with pre-trained model and weights

# %%
# First instantiate a base model with pre-trained weights
base_model = ModelNameFunc(
    include_top = False,
    weights = "imagenet",
    include_preprocessing = False, # ONLY for V2 model, otherwise put it as comment.
    input_shape = (height, width, output_neurons)
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/efficientnet_v2/efficientnetv2-b3_notop.h5
# 52606240/52606240 [==============================] - 0s 0us/step

# %%
display(base_model.input)
# Out:
# <KerasTensor: shape=(None, 240, 240, 3) dtype=float32 (created by layer 'input_1')>

# %% [markdown]
# ### II.3.2. Define the new architecture on top

# %%
x = base_model.output
x = GlobalAveragePooling2D()(x) # Pooling
x = Dense(l1_neurons, activation = l1_activation)(x)
x = Dropout(dropout)(x)
x = Dense(l2_neurons, activation = l2_activation)(x)
x = BatchNormalization()(x)

predictions = Dense(output_neurons, activation = output_activation)(x)

model = Model(inputs = base_model.input, outputs = predictions)

# %%
print(model.input_shape)
# Out:
# (None, 240, 240, 3)

# %% [markdown]
# ### II.3.4. Compile the model

# %%
model.compile(
    optimizer = compile_optimizer,
    loss = compile_loss,
    metrics = compile_metrics
)

# %% [markdown]
# ### II.3.5. Train the model
# It's called "history" because it essentially keeps a historical record of various metrics and data related to how the model performed during training.

# %%
history = model.fit(
    x = train_generator,
    steps_per_epoch = train_generator.samples // batch_size + 1,
    validation_data = val_generator,
    validation_steps = val_generator.samples // batch_size + 1,
    epochs = epochs,
    verbose = verbose,
    callbacks = callbacks_list
)

# Save the model
model.save(fileh5_path)
# Out:
# Epoch 1/50
# 132/132 [==============================] - ETA: 0s - loss: 0.3022 - accuracy: 0.8940 - Precision: 0.9100 - Recall: 0.8740
# Epoch 1: val_loss improved from inf to 0.08651, saving model to /content/drive/MyDrive/Colab Notebooks/EfficientNetV2B3_L1N128L2N32DO5/EfficientNetV2B3_L1N128L2N32DO5_H5_Model/EfficientNetV2B3_L1N128L2N32DO5_TRAIN_MCPBest.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 132/132 [==============================] - 2137s 16s/step - loss: 0.3022 - accuracy: 0.8940 - Precision: 0.9100 - Recall: 0.8740 - val_loss: 0.0865 - val_accuracy: 0.9708 - val_Precision: 0.9740 - val_Recall: 0.9692 - lr: 0.0010
# Epoch 2/50
# 132/132 [==============================] - ETA: 0s - loss: 0.1842 - accuracy: 0.9386 - Precision: 0.9457 - Recall: 0.9336
# Epoch 2: val_loss did not improve from 0.08651
# 132/132 [==============================] - 126s 950ms/step - loss: 0.1842 - accuracy: 0.9386 - Precision: 0.9457 - Recall: 0.9336 - val_loss: 0.1623 - val_accuracy: 0.9433 - val_Precision: 0.9449 - val_Recall: 0.9433 - lr: 0.0010
# Epoch 3/50
# 132/132 [==============================] - ETA: 0s - loss: 0.1754 - accuracy: 0.9455 - Precision: 0.9493 - Recall: 0.9410
# Epoch 3: val_loss improved from 0.08651 to 0.07355, saving model to /content/drive/MyDrive/Colab Notebooks/EfficientNetV2B3_L1N128L2N32DO5/EfficientNetV2B3_L1N128L2N32DO5_H5_Model/EfficientNetV2B3_L1N128L2N32DO5_TRAIN_MCPBest.h5
# 132/132 [==============================] - 126s 953ms/step - loss: 0.1754 - accuracy: 0.9455 - Precision: 0.9493 - Recall: 0.9410 - val_loss: 0.0736 - val_accuracy: 0.9683 - val_Precision: 0.9707 - val_Recall: 0.9667 - lr: 0.0010
# Epoch 4/50
# 132/132 [==============================] - ETA: 0s - loss: 0.1669 - accuracy: 0.9479 - Precision: 0.9524 - Recall: 0.9426
# Epoch 4: val_loss did not improve from 0.07355
# 132/132 [==============================] - 124s 939ms/step - loss: 0.1669 - accuracy: 0.9479 - Precision: 0.9524 - Recall: 0.9426 - val_loss: 0.0757 - val_accuracy: 0.9733 - val_Precision: 0.9741 - val_Recall: 0.9725 - lr: 0.0010
# Epoch 5/50
# 132/132 [==============================] - ETA: 0s - loss: 0.1142 - accuracy: 0.9631 - Precision: 0.9667 - Recall: 0.9607
# Epoch 5: val_loss did not improve from 0.07355
# 132/132 [==============================] - 122s 925ms/step - loss: 0.1142 - accuracy: 0.9631 - Precision: 0.9667 - Recall: 0.9607 - val_loss: 0.1542 - val_accuracy: 0.9500 - val_Precision: 0.9524 - val_Recall: 0.9500 - lr: 0.0010
# Epoch 6/50
# 132/132 [==============================] - ETA: 0s - loss: 0.1219 - accuracy: 0.9586 - Precision: 0.9633 - Recall: 0.9564
# Epoch 6: val_loss did not improve from 0.07355
# 132/132 [==============================] - 123s 935ms/step - loss: 0.1219 - accuracy: 0.9586 - Precision: 0.9633 - Recall: 0.9564 - val_loss: 0.0740 - val_accuracy: 0.9708 - val_Precision: 0.9708 - val_Recall: 0.9708 - lr: 0.0010
# Epoch 7/50
# 132/132 [==============================] - ETA: 0s - loss: 0.1210 - accuracy: 0.9607 - Precision: 0.9645 - Recall: 0.9579
# Epoch 7: val_loss did not improve from 0.07355
# 132/132 [==============================] - 122s 923ms/step - loss: 0.1210 - accuracy: 0.9607 - Precision: 0.9645 - Recall: 0.9579 - val_loss: 0.1270 - val_accuracy: 0.9608 - val_Precision: 0.9608 - val_Recall: 0.9600 - lr: 0.0010
# Epoch 8/50
# 132/132 [==============================] - ETA: 0s - loss: 0.1009 - accuracy: 0.9686 - Precision: 0.9708 - Recall: 0.9652
# Epoch 8: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
#
# Epoch 8: val_loss did not improve from 0.07355
# 132/132 [==============================] - 122s 927ms/step - loss: 0.1009 - accuracy: 0.9686 - Precision: 0.9708 - Recall: 0.9652 - val_loss: 0.2323 - val_accuracy: 0.9267 - val_Precision: 0.9281 - val_Recall: 0.9250 - lr: 0.0010
# Epoch 9/50
# 132/132 [==============================] - ETA: 0s - loss: 0.0889 - accuracy: 0.9731 - Precision: 0.9761 - Recall: 0.9712
# Epoch 9: val_loss improved from 0.07355 to 0.05931, saving model to /content/drive/MyDrive/Colab Notebooks/EfficientNetV2B3_L1N128L2N32DO5/EfficientNetV2B3_L1N128L2N32DO5_H5_Model/EfficientNetV2B3_L1N128L2N32DO5_TRAIN_MCPBest.h5
# 132/132 [==============================] - 128s 963ms/step - loss: 0.0889 - accuracy: 0.9731 - Precision: 0.9761 - Recall: 0.9712 - val_loss: 0.0593 - val_accuracy: 0.9850 - val_Precision: 0.9858 - val_Recall: 0.9842 - lr: 2.0000e-04
# Epoch 10/50
# 132/132 [==============================] - ETA: 0s - loss: 0.0580 - accuracy: 0.9817 - Precision: 0.9838 - Recall: 0.9805
# Epoch 10: val_loss improved from 0.05931 to 0.05141, saving model to /content/drive/MyDrive/Colab Notebooks/EfficientNetV2B3_L1N128L2N32DO5/EfficientNetV2B3_L1N128L2N32DO5_H5_Model/EfficientNetV2B3_L1N128L2N32DO5_TRAIN_MCPBest.h5
# 132/132 [==============================] - 127s 962ms/step - loss: 0.0580 - accuracy: 0.9817 - Precision: 0.9838 - Recall: 0.9805 - val_loss: 0.0514 - val_accuracy: 0.9858 - val_Precision: 0.9858 - val_Recall: 0.9858 - lr: 2.0000e-04
# Epoch 11/50
# 132/132 [==============================] - ETA: 0s - loss: 0.0356 - accuracy: 0.9886 - Precision: 0.9890 - Recall: 0.9879
# Epoch 11: val_loss improved from 0.05141 to 0.04633, saving model to /content/drive/MyDrive/Colab Notebooks/EfficientNetV2B3_L1N128L2N32DO5/EfficientNetV2B3_L1N128L2N32DO5_H5_Model/EfficientNetV2B3_L1N128L2N32DO5_TRAIN_MCPBest.h5
# 132/132 [==============================] - 128s 970ms/step - loss: 0.0356 - accuracy: 0.9886 - Precision: 0.9890 - Recall: 0.9879 - val_loss: 0.0463 - val_accuracy: 0.9858 - val_Precision: 0.9858 - val_Recall: 0.9858 - lr: 2.0000e-04
# Epoch 12/50
# 132/132 [==============================] - ETA: 0s - loss: 0.0380 - accuracy: 0.9890 - Precision: 0.9900 - Recall: 0.9883
# Epoch 12: val_loss did not improve from 0.04633
# 132/132 [==============================] - 122s 924ms/step - loss: 0.0380 - accuracy: 0.9890 - Precision: 0.9900 - Recall: 0.9883 - val_loss: 0.0533 - val_accuracy: 0.9842 - val_Precision: 0.9842 - val_Recall: 0.9842 - lr: 2.0000e-04
# Epoch 13/50
# 132/132 [==============================] - ETA: 0s - loss: 0.0298 - accuracy: 0.9919 - Precision: 0.9919 - Recall: 0.9914
# Epoch 13: val_loss improved from 0.04633 to 0.04095, saving model to /content/drive/MyDrive/Colab Notebooks/EfficientNetV2B3_L1N128L2N32DO5/EfficientNetV2B3_L1N128L2N32DO5_H5_Model/EfficientNetV2B3_L1N128L2N32DO5_TRAIN_MCPBest.h5
# 132/132 [==============================] - 126s 954ms/step - loss: 0.0298 - accuracy: 0.9919 - Precision: 0.9919 - Recall: 0.9914 - val_loss: 0.0410 - val_accuracy: 0.9858 - val_Precision: 0.9858 - val_Recall: 0.9850 - lr: 2.0000e-04
# Epoch 14/50
# 132/132 [==============================] - ETA: 0s - loss: 0.0307 - accuracy: 0.9933 - Precision: 0.9936 - Recall: 0.9931
# Epoch 14: val_loss did not improve from 0.04095
# 132/132 [==============================] - 123s 932ms/step - loss: 0.0307 - accuracy: 0.9933 - Precision: 0.9936 - Recall: 0.9931 - val_loss: 0.0442 - val_accuracy: 0.9858 - val_Precision: 0.9858 - val_Recall: 0.9858 - lr: 2.0000e-04
# Epoch 15/50
# 132/132 [==============================] - ETA: 0s - loss: 0.0264 - accuracy: 0.9931 - Precision: 0.9933 - Recall: 0.9931
# Epoch 15: val_loss did not improve from 0.04095
# 132/132 [==============================] - 123s 932ms/step - loss: 0.0264 - accuracy: 0.9931 - Precision: 0.9933 - Recall: 0.9931 - val_loss: 0.0574 - val_accuracy: 0.9842 - val_Precision: 0.9842 - val_Recall: 0.9842 - lr: 2.0000e-04
# Epoch 16/50
# 132/132 [==============================] - ETA: 0s - loss: 0.0243 - accuracy: 0.9931 - Precision: 0.9933 - Recall: 0.9931
# Epoch 16: val_loss improved from 0.04095 to 0.03869, saving model to /content/drive/MyDrive/Colab Notebooks/EfficientNetV2B3_L1N128L2N32DO5/EfficientNetV2B3_L1N128L2N32DO5_H5_Model/EfficientNetV2B3_L1N128L2N32DO5_TRAIN_MCPBest.h5
# 132/132 [==============================] - 128s 970ms/step - loss: 0.0243 - accuracy: 0.9931 - Precision: 0.9933 - Recall: 0.9931 - val_loss: 0.0387 - val_accuracy: 0.9883 - val_Precision: 0.9883 - val_Recall: 0.9883 - lr: 2.0000e-04
# Epoch 17/50
# 132/132 [==============================] - ETA: 0s - loss: 0.0298 - accuracy: 0.9917 - Precision: 0.9924 - Recall: 0.9914
# Epoch 17: val_loss did not improve from 0.03869
# 132/132 [==============================] - 122s 927ms/step - loss: 0.0298 - accuracy: 0.9917 - Precision: 0.9924 - Recall: 0.9914 - val_loss: 0.0427 - val_accuracy: 0.9875 - val_Precision: 0.9875 - val_Recall: 0.9875 - lr: 2.0000e-04
# Epoch 18/50
# 132/132 [==============================] - ETA: 0s - loss: 0.0208 - accuracy: 0.9933 - Precision: 0.9936 - Recall: 0.9933
# Epoch 18: val_loss did not improve from 0.03869
# 132/132 [==============================] - 123s 928ms/step - loss: 0.0208 - accuracy: 0.9933 - Precision: 0.9936 - Recall: 0.9933 - val_loss: 0.0471 - val_accuracy: 0.9883 - val_Precision: 0.9883 - val_Recall: 0.9883 - lr: 2.0000e-04
# Epoch 19/50
# 132/132 [==============================] - ETA: 0s - loss: 0.0216 - accuracy: 0.9943 - Precision: 0.9943 - Recall: 0.9943
# Epoch 19: val_loss did not improve from 0.03869
# 132/132 [==============================] - 122s 923ms/step - loss: 0.0216 - accuracy: 0.9943 - Precision: 0.9943 - Recall: 0.9943 - val_loss: 0.0437 - val_accuracy: 0.9850 - val_Precision: 0.9850 - val_Recall: 0.9850 - lr: 2.0000e-04
# Epoch 20/50
# 132/132 [==============================] - ETA: 0s - loss: 0.0117 - accuracy: 0.9974 - Precision: 0.9976 - Recall: 0.9971
# Epoch 20: val_loss did not improve from 0.03869
# 132/132 [==============================] - 122s 920ms/step - loss: 0.0117 - accuracy: 0.9974 - Precision: 0.9976 - Recall: 0.9971 - val_loss: 0.0489 - val_accuracy: 0.9867 - val_Precision: 0.9867 - val_Recall: 0.9867 - lr: 2.0000e-04
# Epoch 21/50
# 132/132 [==============================] - ETA: 0s - loss: 0.0124 - accuracy: 0.9976 - Precision: 0.9976 - Recall: 0.9976
# Epoch 21: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
#
# Epoch 21: val_loss did not improve from 0.03869
# 132/132 [==============================] - 125s 943ms/step - loss: 0.0124 - accuracy: 0.9976 - Precision: 0.9976 - Recall: 0.9976 - val_loss: 0.0456 - val_accuracy: 0.9875 - val_Precision: 0.9875 - val_Recall: 0.9875 - lr: 2.0000e-04
# Epoch 22/50
# 132/132 [==============================] - ETA: 0s - loss: 0.0086 - accuracy: 0.9988 - Precision: 0.9988 - Recall: 0.9988
# Epoch 22: val_loss did not improve from 0.03869
# 132/132 [==============================] - 124s 936ms/step - loss: 0.0086 - accuracy: 0.9988 - Precision: 0.9988 - Recall: 0.9988 - val_loss: 0.0492 - val_accuracy: 0.9867 - val_Precision: 0.9867 - val_Recall: 0.9867 - lr: 4.0000e-05
# Epoch 23/50
# 132/132 [==============================] - ETA: 0s - loss: 0.0113 - accuracy: 0.9974 - Precision: 0.9976 - Recall: 0.9974Restoring model weights from the end of the best epoch: 16.
#
# Epoch 23: val_loss did not improve from 0.03869
# 132/132 [==============================] - 125s 944ms/step - loss: 0.0113 - accuracy: 0.9974 - Precision: 0.9976 - Recall: 0.9974 - val_loss: 0.0474 - val_accuracy: 0.9892 - val_Precision: 0.9892 - val_Recall: 0.9892 - lr: 4.0000e-05
# Epoch 23: early stopping

# %% [markdown]
# ### II.3.7. Evaluate Pre trained model

# %%
# Predict the values from the Test Dataset
Y_pred = model.predict(test_generator, steps = test_generator.samples // batch_size + 1)

# Convert predictions classes from one hot vectors
Y_pred_classes = np.argmax(Y_pred, axis = 1)
# Out:
# 19/19 [==============================] - 219s 12s/step

# %%
import sklearn.metrics
# Evaluate the model on the Test Dataset using `evaluate`
# f1 = F1Score(test_generator.classes, Y_pred_classes)
f1 = sklearn.metrics.f1_score(test_generator.classes, Y_pred_classes, average = "macro")
print("F1 Score : ", f1)
print("Evaluate on Test Data")
results = model.evaluate(test_generator, batch_size = batch_size)
# Out:
# 0.9916749688018883
# Evaluate on Test Data
# 19/19 [==============================] - 5s 245ms/step - loss: 0.0268 - accuracy: 0.9917 - Precision: 0.9917 - Recall: 0.9917

# %% [markdown]
# ### II.3.8. Plot the Accuracy and the loss graphs

# %%
# Plot the Loss graph
plt.plot(history.history["loss"])
plt.plot(history.history["val_loss"])
plt.title("Model Loss")
plt.ylabel("Loss")
plt.xlabel("Epoch")
plt.legend(["Train", "Val"], loc = "upper left")
plt.show()

# %%
# Plot the Accuracy graph
plt.plot(history.history["accuracy"])
plt.plot(history.history["val_accuracy"])
plt.title("Model Accuracy")
plt.ylabel("Accuracy")
plt.xlabel("Epoch")
plt.legend(["Train", "Val"], loc = "lower left")
plt.show()

# %% [markdown]
# ### II.3.8. Trained Model : Confusion Matrix

# %%
# # Predict the values from the Test Dataset
# Y_pred = model.predict(test_generator, steps = test_generator.samples // batch_size + 1)

# # Convert predictions classes from one hot vectors
# Y_pred_classes = np.argmax(Y_pred, axis = 1)

# Convert validation observations from one hot vectors
# Y_true = np.argmax(test_generator.classes, axis = 1)
# OR
Y_true = test_generator.classes

# Compute the confusion matrix
cm = confusion_matrix(Y_true, Y_pred_classes)

# Print the confusion matrix
print("Confusion Matrix")
print(cm)

# Retrieve class names (label)
names_from_dir = sorted(os.listdir(val_dir))
dict(enumerate(names_from_dir))
#OR
class_names = list(val_generator.class_indices.keys())
# Check if the both are similar
print(names_from_dir == class_names)

# Print the classification report
print("Classification Report")
print(classification_report(Y_true, Y_pred_classes, target_names = class_names, digits = 4))
# Out:
# Confusion Matrix
# [[198   2   0]
#  [  2 198   0]
#  [  0   1 199]]
# True
# Classification Report
#               precision    recall  f1-score   support
#
#          Bee     0.9900    0.9900    0.9900       200
#    Butterfly     0.9851    0.9900    0.9875       200
#      Ladybug     1.0000    0.9950    0.9975       200
#
#     accuracy                         0.9917       600
#    macro avg     0.9917    0.9917    0.9917       600
# weighted avg     0.9917    0.9917    0.9917       600

# %% [markdown]
# ### II.3.9. Confusion Matrix Function

# %%
def plot_confusion_matrix(
    cm,
    classes,
    normalize = False,
    title = "Confusion matrix",
    cmap = plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype("float") / cm.sum(axis =1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)
    plt.imshow(cm, interpolation = "nearest", cmap = cmap)
    plt.title(title)
    plt.colorbar()
    plt.tight_layout()
    plt.ylabel("True label")
    plt.xlabel("Predicted label")

# %% [markdown]
# ### II.3.10. Trained Model : Confusion Matrix Graph

# %%
plot_confusion_matrix(
    cm,
    class_names,
    normalize = True,
    title = "Confusion matrix",
    cmap = plt.cm.Blues
    )
# Out:
# Normalized confusion matrix
# [[0.99  0.01  0.   ]
#  [0.01  0.99  0.   ]
#  [0.    0.005 0.995]]

# %% [markdown]
# ## II.4. Fine Tuning
# This requires unfreezing the base model and then recompiling the model (necessary for the changes to take effect), and then resuming training.

# %% [markdown]
# ### II.4.1. Unfreeze the base model

# %%
# Unfreeze the base model
base_model.trainable = True

# %% [markdown]
# ### II.4.2. Re compile the model with a very low learning rate

# %%
# It's important to recompile your model after you make any changes
# to the `trainable` attribute of any inner layer, so that your changes
# are take into account
model.compile(
    optimizer = ft_compile_optimizer,
    loss = ft_compile_loss,
    metrics = ft_compile_metrics
)

# %% [markdown]
# ### II.4.3. Retraining the model

# %%
# Resume training
ft_history = model.fit(
    x = train_generator,
    steps_per_epoch = train_generator.samples // batch_size + 1,
    validation_data = val_generator,
    validation_steps = val_generator.samples // batch_size + 1,
    epochs = ft_epochs,
    verbose = ft_verbose,
    callbacks = ft_callbacks_list
)

# Save the Fine tuned model
model.save(ft_fileh5_path)
# Out:
# Epoch 1/20
# 132/132 [==============================] - ETA: 0s - loss: 0.0157 - accuracy: 0.9967 - Precision: 0.9960 - Recall: 0.9958
# Epoch 1: val_loss improved from inf to 0.04126, saving model to /content/drive/MyDrive/Colab Notebooks/EfficientNetV2B3_H5_Model/EfficientNetV2B3_FT_MCPBest.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 132/132 [==============================] - 219s 1s/step - loss: 0.0157 - accuracy: 0.9967 - Precision: 0.9960 - Recall: 0.9958 - val_loss: 0.0413 - val_accuracy: 0.9883 - val_Precision: 0.9883 - val_Recall: 0.9875 - lr: 1.0000e-05
# Epoch 2/20
# 132/132 [==============================] - ETA: 0s - loss: 0.0154 - accuracy: 0.9971 - Precision: 0.9971 - Recall: 0.9971
# Epoch 2: val_loss did not improve from 0.04126
# 132/132 [==============================] - 131s 989ms/step - loss: 0.0154 - accuracy: 0.9971 - Precision: 0.9971 - Recall: 0.9971 - val_loss: 0.0419 - val_accuracy: 0.9883 - val_Precision: 0.9883 - val_Recall: 0.9883 - lr: 1.0000e-05
# Epoch 3/20
# 132/132 [==============================] - ETA: 0s - loss: 0.0129 - accuracy: 0.9967 - Precision: 0.9967 - Recall: 0.9964
# Epoch 3: val_loss improved from 0.04126 to 0.04060, saving model to /content/drive/MyDrive/Colab Notebooks/EfficientNetV2B3_H5_Model/EfficientNetV2B3_FT_MCPBest.h5
# 132/132 [==============================] - 134s 1s/step - loss: 0.0129 - accuracy: 0.9967 - Precision: 0.9967 - Recall: 0.9964 - val_loss: 0.0406 - val_accuracy: 0.9892 - val_Precision: 0.9892 - val_Recall: 0.9892 - lr: 1.0000e-05
# Epoch 4/20
# 132/132 [==============================] - ETA: 0s - loss: 0.0152 - accuracy: 0.9960 - Precision: 0.9962 - Recall: 0.9960
# Epoch 4: val_loss improved from 0.04060 to 0.03637, saving model to /content/drive/MyDrive/Colab Notebooks/EfficientNetV2B3_H5_Model/EfficientNetV2B3_FT_MCPBest.h5
# 132/132 [==============================] - 133s 1s/step - loss: 0.0152 - accuracy: 0.9960 - Precision: 0.9962 - Recall: 0.9960 - val_loss: 0.0364 - val_accuracy: 0.9908 - val_Precision: 0.9908 - val_Recall: 0.9908 - lr: 1.0000e-05
# Epoch 5/20
# 132/132 [==============================] - ETA: 0s - loss: 0.0139 - accuracy: 0.9960 - Precision: 0.9962 - Recall: 0.9960
# Epoch 5: val_loss did not improve from 0.03637
# 132/132 [==============================] - 129s 978ms/step - loss: 0.0139 - accuracy: 0.9960 - Precision: 0.9962 - Recall: 0.9960 - val_loss: 0.0385 - val_accuracy: 0.9892 - val_Precision: 0.9892 - val_Recall: 0.9892 - lr: 1.0000e-05
# Epoch 6/20
# 132/132 [==============================] - ETA: 0s - loss: 0.0185 - accuracy: 0.9962 - Precision: 0.9962 - Recall: 0.9960
# Epoch 6: val_loss improved from 0.03637 to 0.03590, saving model to /content/drive/MyDrive/Colab Notebooks/EfficientNetV2B3_H5_Model/EfficientNetV2B3_FT_MCPBest.h5
# 132/132 [==============================] - 128s 972ms/step - loss: 0.0185 - accuracy: 0.9962 - Precision: 0.9962 - Recall: 0.9960 - val_loss: 0.0359 - val_accuracy: 0.9892 - val_Precision: 0.9892 - val_Recall: 0.9892 - lr: 1.0000e-05
# Epoch 7/20
# 132/132 [==============================] - ETA: 0s - loss: 0.0116 - accuracy: 0.9969 - Precision: 0.9969 - Recall: 0.9969
# Epoch 7: val_loss did not improve from 0.03590
# 132/132 [==============================] - 127s 964ms/step - loss: 0.0116 - accuracy: 0.9969 - Precision: 0.9969 - Recall: 0.9969 - val_loss: 0.0372 - val_accuracy: 0.9900 - val_Precision: 0.9900 - val_Recall: 0.9900 - lr: 1.0000e-05
# Epoch 8/20
# 132/132 [==============================] - ETA: 0s - loss: 0.0148 - accuracy: 0.9969 - Precision: 0.9971 - Recall: 0.9969
# Epoch 8: val_loss did not improve from 0.03590
# 132/132 [==============================] - 125s 942ms/step - loss: 0.0148 - accuracy: 0.9969 - Precision: 0.9971 - Recall: 0.9969 - val_loss: 0.0371 - val_accuracy: 0.9883 - val_Precision: 0.9883 - val_Recall: 0.9883 - lr: 1.0000e-05
# Epoch 9/20
# 132/132 [==============================] - ETA: 0s - loss: 0.0136 - accuracy: 0.9962 - Precision: 0.9962 - Recall: 0.9962
# Epoch 9: ReduceLROnPlateau reducing learning rate to 1.9999999494757505e-06.
#
# Epoch 9: val_loss did not improve from 0.03590
# 132/132 [==============================] - 123s 927ms/step - loss: 0.0136 - accuracy: 0.9962 - Precision: 0.9962 - Recall: 0.9962 - val_loss: 0.0373 - val_accuracy: 0.9883 - val_Precision: 0.9883 - val_Recall: 0.9883 - lr: 1.0000e-05
# Epoch 10/20
# 132/132 [==============================] - ETA: 0s - loss: 0.0121 - accuracy: 0.9964 - Precision: 0.9967 - Recall: 0.9964
# Epoch 10: val_loss improved from 0.03590 to 0.03515, saving model to /content/drive/MyDrive/Colab Notebooks/EfficientNetV2B3_H5_Model/EfficientNetV2B3_FT_MCPBest.h5
# 132/132 [==============================] - 126s 952ms/step - loss: 0.0121 - accuracy: 0.9964 - Precision: 0.9967 - Recall: 0.9964 - val_loss: 0.0352 - val_accuracy: 0.9908 - val_Precision: 0.9908 - val_Recall: 0.9908 - lr: 2.0000e-06
# Epoch 11/20
# 132/132 [==============================] - ETA: 0s - loss: 0.0090 - accuracy: 0.9986 - Precision: 0.9988 - Recall: 0.9986
# Epoch 11: val_loss improved from 0.03515 to 0.03482, saving model to /content/drive/MyDrive/Colab Notebooks/EfficientNetV2B3_H5_Model/EfficientNetV2B3_FT_MCPBest.h5
# 132/132 [==============================] - 128s 969ms/step - loss: 0.0090 - accuracy: 0.9986 - Precision: 0.9988 - Recall: 0.9986 - val_loss: 0.0348 - val_accuracy: 0.9908 - val_Precision: 0.9908 - val_Recall: 0.9908 - lr: 2.0000e-06
# Epoch 12/20
# 132/132 [==============================] - ETA: 0s - loss: 0.0164 - accuracy: 0.9950 - Precision: 0.9950 - Recall: 0.9948
# Epoch 12: val_loss did not improve from 0.03482
# 132/132 [==============================] - 122s 923ms/step - loss: 0.0164 - accuracy: 0.9950 - Precision: 0.9950 - Recall: 0.9948 - val_loss: 0.0365 - val_accuracy: 0.9900 - val_Precision: 0.9900 - val_Recall: 0.9892 - lr: 2.0000e-06
# Epoch 13/20
# 132/132 [==============================] - ETA: 0s - loss: 0.0127 - accuracy: 0.9967 - Precision: 0.9967 - Recall: 0.9967
# Epoch 13: val_loss improved from 0.03482 to 0.03376, saving model to /content/drive/MyDrive/Colab Notebooks/EfficientNetV2B3_H5_Model/EfficientNetV2B3_FT_MCPBest.h5
# 132/132 [==============================] - 130s 985ms/step - loss: 0.0127 - accuracy: 0.9967 - Precision: 0.9967 - Recall: 0.9967 - val_loss: 0.0338 - val_accuracy: 0.9917 - val_Precision: 0.9917 - val_Recall: 0.9917 - lr: 2.0000e-06
# Epoch 14/20
# 132/132 [==============================] - ETA: 0s - loss: 0.0119 - accuracy: 0.9971 - Precision: 0.9974 - Recall: 0.9971
# Epoch 14: val_loss did not improve from 0.03376
# 132/132 [==============================] - 122s 925ms/step - loss: 0.0119 - accuracy: 0.9971 - Precision: 0.9974 - Recall: 0.9971 - val_loss: 0.0359 - val_accuracy: 0.9892 - val_Precision: 0.9900 - val_Recall: 0.9892 - lr: 2.0000e-06
# Epoch 15/20
# 132/132 [==============================] - ETA: 0s - loss: 0.0130 - accuracy: 0.9967 - Precision: 0.9969 - Recall: 0.9964
# Epoch 15: val_loss did not improve from 0.03376
# 132/132 [==============================] - 147s 1s/step - loss: 0.0130 - accuracy: 0.9967 - Precision: 0.9969 - Recall: 0.9964 - val_loss: 0.0354 - val_accuracy: 0.9892 - val_Precision: 0.9892 - val_Recall: 0.9892 - lr: 2.0000e-06
# Epoch 16/20
# 132/132 [==============================] - ETA: 0s - loss: 0.0079 - accuracy: 0.9983 - Precision: 0.9983 - Recall: 0.9983
# Epoch 16: ReduceLROnPlateau reducing learning rate to 1e-06.
#
# Epoch 16: val_loss did not improve from 0.03376
# 132/132 [==============================] - 138s 1s/step - loss: 0.0079 - accuracy: 0.9983 - Precision: 0.9983 - Recall: 0.9983 - val_loss: 0.0345 - val_accuracy: 0.9900 - val_Precision: 0.9900 - val_Recall: 0.9900 - lr: 2.0000e-06
# Epoch 17/20
# 132/132 [==============================] - ETA: 0s - loss: 0.0108 - accuracy: 0.9969 - Precision: 0.9974 - Recall: 0.9969
# Epoch 17: val_loss did not improve from 0.03376
# 132/132 [==============================] - 137s 1s/step - loss: 0.0108 - accuracy: 0.9969 - Precision: 0.9974 - Recall: 0.9969 - val_loss: 0.0340 - val_accuracy: 0.9900 - val_Precision: 0.9900 - val_Recall: 0.9900 - lr: 1.0000e-06
# Epoch 18/20
# 132/132 [==============================] - ETA: 0s - loss: 0.0088 - accuracy: 0.9981 - Precision: 0.9981 - Recall: 0.9981Restoring model weights from the end of the best epoch: 13.
#
# Epoch 18: val_loss did not improve from 0.03376
# 132/132 [==============================] - 123s 933ms/step - loss: 0.0088 - accuracy: 0.9981 - Precision: 0.9981 - Recall: 0.9981 - val_loss: 0.0357 - val_accuracy: 0.9900 - val_Precision: 0.9900 - val_Recall: 0.9900 - lr: 1.0000e-06
# Epoch 18: early stopping

# %% [markdown]
# ### II.4.4. Evaluation Fine Tune Model

# %%
# Predict the values from the Test Dataset
Y_pred = model.predict(test_generator, steps = test_generator.samples // batch_size + 1)

# Convert predictions classes from one hot vectors
Y_pred_classes = np.argmax(Y_pred, axis = 1)
# Out:
# 19/19 [==============================] - 8s 298ms/step

# %%
# Evaluate the model on the Test Dataset using `evaluate`
# f1 = F1Score(test_generator.classes, Y_pred_classes)
ft_f1 = f1_score(test_generator.classes, Y_pred_classes, average = "macro")
print("F1 Score : ", ft_f1)
print("Evaluate on Test Data")
ft_results = model.evaluate(test_generator, batch_size = batch_size)
# Out:
# 0.9949999687498048
# Evaluate on Test Data
# 19/19 [==============================] - 5s 245ms/step - loss: 0.0299 - accuracy: 0.9950 - Precision: 0.9950 - Recall: 0.9950

# %%
# Plot the Loss graph
plt.plot(ft_history.history["loss"])
plt.plot(ft_history.history["val_loss"])
plt.title("Model Loss")
plt.ylabel("loss")
plt.xlabel("epoch")
plt.legend(["Train", "Val"], loc = "upper left")
plt.show()

# %%
# Plot the Accuracy graph
plt.plot(ft_history.history["accuracy"])
plt.plot(ft_history.history["val_accuracy"])
plt.title("Model Accuracy")
plt.ylabel("Accuracy")
plt.xlabel("Epoch")
plt.legend(["Train", "Val"], loc = "lower left")
plt.show()

# %% [markdown]
# ### II.4.5. Fine Tuned Model : Confusion Matrix

# %%
# # Predict the values from the validation dataset
# Y_pred = model.predict(test_generator, steps = test_generator.samples // batch_size + 1)

# # Convert predictions classes from one hot vectors
# Y_pred_classes = np.argmax(Y_pred, axis = 1)

# Convert validation observations from one hot vectors
# Y_true = np.argmax(test_generator.classes, axis = 1)
# OR
Y_true = test_generator.classes

# Compute the confusion matrix
ft_cm = confusion_matrix(Y_true, Y_pred_classes)

# Print the confusion matrix
print("Confusion Matrix")
print(ft_cm)

# Retrieve class names (label)
names_from_dir = sorted(os.listdir(val_dir))
dict(enumerate(names_from_dir))
#OR
class_names = list(val_generator.class_indices.keys())
# Check if the both are similar
print(names_from_dir == class_names)

# Print the classification report
print("Classification Report")
print(classification_report(Y_true, Y_pred_classes, target_names = class_names, digits = 4))
# Out:
# Confusion Matrix
# [[199   1   0]
#  [  2 198   0]
#  [  0   0 200]]
# True
# Classification Report
#               precision    recall  f1-score   support
#
#          Bee     0.9900    0.9950    0.9925       200
#    Butterfly     0.9950    0.9900    0.9925       200
#      Ladybug     1.0000    1.0000    1.0000       200
#
#     accuracy                         0.9950       600
#    macro avg     0.9950    0.9950    0.9950       600
# weighted avg     0.9950    0.9950    0.9950       600

# %% [markdown]
# ### II.4.5. Fine Tuned Model : Confusion Matrix Graph

# %%
plot_confusion_matrix(ft_cm,
                      class_names,
                      normalize = True,
                      title = "Confusion matrix",
                      cmap = plt.cm.Blues
                      )
# Out:
# Normalized confusion matrix
# [[0.995 0.005 0.   ]
#  [0.01  0.99  0.   ]
#  [0.    0.    1.   ]]

# %% [markdown]
# # III. READ LOGS

# %% [markdown]
# ## III.1. TRAIN

# %%
# %load_ext tensorboard
# %tensorboard --logdir log_dir

# %% [markdown]
# ## III.2. FINE TUNE

# %%
# %load_ext tensorboard
# %tensorboard --logdir ft_log_dir
