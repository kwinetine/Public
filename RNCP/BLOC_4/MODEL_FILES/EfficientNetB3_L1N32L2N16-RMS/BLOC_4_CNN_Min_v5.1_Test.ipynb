# %% [markdown]
# ## I.1. Install

# %%
# # # GOOGLE Colab ONLY : Mount GOOGLE Drive
# from google.colab import drive
# drive.mount("/content/drive")

# %%
import os
# GOOGLE Colab ONLY : Get & store the default work path
user_path = os.path.join(os.getcwd(), "drive", "MyDrive", "Colab Notebooks")

# LOCAL : Get & store the current working path
# user_path = os.path.dirname(os.path.abspath("NoNeedFilename"))

print(user_path)
# Out:
# /content/drive/MyDrive/Colab Notebooks

# %%
# requirements_filepath = os.path.join(user_path, "requirements.txt")
# !pip install -r {requirements_filepath}

# %% [markdown]
# ## I.2. Libraries Import

# %%
import numpy as np
import matplotlib.pyplot as plt

# Machine Learning
# import keras
from keras.models import Model
from keras.preprocessing.image import ImageDataGenerator
from keras.layers import Dense, Dropout, GlobalAveragePooling2D, BatchNormalization
from keras.optimizers import Adam, Nadam, SGD, RMSprop
from sklearn.metrics import confusion_matrix, classification_report, f1_score

from keras.applications import EfficientNetB1, EfficientNetB2, EfficientNetB3, EfficientNetV2B1, EfficientNetV2B2, EfficientNetV2B3

# %% [markdown]
# ## I.4. Image Processing

# %% [markdown]
# ### I.4.2. Set Image Folder Path

# %%
# GOOGLE Colab ONLY
train_dir = os.path.join(user_path, "IMAGE_SPLIT", "train")
val_dir = os.path.join(user_path, "IMAGE_SPLIT", "val")
test_dir = os.path.join(user_path, "IMAGE_SPLIT", "test")

# LOCAL
# train_dir = r"C:\WORKSPACES\DATA\ML_DL\IMAGE_SPLIT\train"
# val_dir = r"C:\WORKSPACES\DATA\ML_DL\IMAGE_SPLIT\val"
# test_dir = r"C:\WORKSPACES\DATA\ML_DL\IMAGE_SPLIT\test"

# %% [markdown]
# ### I.4.3. Data augmentation techniques

# %%
train_datagen = ImageDataGenerator(
    rescale = 1./255,
    shear_range = 0.2,
    rotation_range = 20,
    width_shift_range = 0.1,
    height_shift_range = 0.1,
    zoom_range = [0.9, 1.25],
    brightness_range = [0.5, 1.5],
    horizontal_flip = True,
    vertical_flip = True
)

val_datagen = ImageDataGenerator(
    rescale = 1./255)

test_datagen = ImageDataGenerator(
    rescale = 1./255)

# %% [markdown]
# ### I.4.4. Setup Data generators

# %%
# Variables
batch_size = 32
height = 240
width = 240
image_shape = (height, width) # images of size 240x240 px with 3 color channels RGB automatically

train_generator = train_datagen.flow_from_directory(
    train_dir,
    class_mode = "categorical",
    target_size = image_shape,
    batch_size = batch_size
)

val_generator = val_datagen.flow_from_directory(
    val_dir,
    class_mode = "categorical",
    target_size = image_shape,
    batch_size = batch_size
)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    class_mode = "categorical",
    target_size = image_shape,
    batch_size = batch_size,
    shuffle = False
)
# Out:
# Found 4200 images belonging to 3 classes.
# Found 1200 images belonging to 3 classes.
# Found 600 images belonging to 3 classes.

# %% [markdown]
# ## II.1. Define variables and parameters

# %%
from keras.metrics import Precision, Recall, AUC

# Model to use for transfer learning
model_name = "EfficientNetB3"
ModelNameFunc = globals()[model_name]

# Work path
folder_name = f"{model_name}_L1N32L2N16-RMS"
work_path = os.path.join(user_path, folder_name)

# Top Architecture for the new model
l1_neurons = 32                 # Number of neurons on layer 1 (deeper)
l1_activation = "relu"
dropout = 0.4                   # 0.2 - 0.5
l2_neurons = 16                 # Number of neurons on layer 2
l2_activation = "relu"
output_neurons = 3              # This layer will have 3 neurons or units fully connected. In line with our 3 classes.
output_activation = "softmax"

# Metrics (parameter average = "macro" by default )
precision = Precision(name = "Precision")
recall = Recall(name = "Recall")
# f1 = (2 * (precision * recall) / (precision + recall))
# auc = AUC(name = "AUC")

# TRAIN : model.compile
compile_optimizer = "RMSprop"                  # Test : Nadam, RMSprop, SGD
compile_loss = "categorical_crossentropy"   # More than 2 classes, so categorical
compile_metrics = ["accuracy", precision, recall]

# TRAIN : model.fit
epochs = 30
verbose = 1

# FINE TUNE : model.compile
ft_compile_optimizer = RMSprop(learning_rate = 1e-5)
# ft_compile_optimizer : Very low learning rate. Test : Nadam, RMSprop, SGD
ft_compile_loss = "categorical_crossentropy"
ft_compile_metrics = ["accuracy", precision, recall]

# FINE TUNE : model.fit
ft_epochs = 15
ft_verbose = 1

# SAVE : File Path .h5
fileh5_path = os.path.join(work_path, f"{folder_name}_H5_Model", f"{folder_name}_TRAIN_ManualSave.h5")
ft_fileh5_path = os.path.join(work_path, f"{folder_name}_H5_Model", f"{folder_name}_FT_ManualSave.h5")

# %% [markdown]
# ## II.2. Define optimizations

# %% [markdown]
# ### II.2.1. Train optimizations (callbacks)

# %%
from keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint, TensorBoard, CSVLogger

# Define the early stopping
early_stopping = EarlyStopping(
    monitor = "val_loss",        # Metric to monitor
    patience = 5,                # Number of epochs with no improvement  (around 10% of nb of epochs)
    verbose = 1,                 # Verbosity mode (0, 1, or 2)
    restore_best_weights = True  # Whether to restore model weights to the best epoch
)

# Define the learning rate scheduler
lr_scheduler = ReduceLROnPlateau(
    monitor = "val_loss",       # Metric to monitor
    factor = 0.2,               # Factor by which to reduce the learning rate
    patience = 5,               # Number of epochs with no improvement (default = 10)
    verbose = 1,                # Verbosity mode (0, 1, or 2)
    min_lr = 1e-6               # Minimum learning rate
)

# Define the model checkpoint callback
checkpoint = ModelCheckpoint(
    # filepath = os.path.join(work_path, f"{model_name}_TRAIN_CheckPoint"), # to use if don't wanna save to a .h5 or .keras file
    filepath = os.path.join(work_path, f"{folder_name}_H5_Model", f"{folder_name}_TRAIN_MCPBest.h5"),
    monitor = "val_loss",       # Metric to monitor
    save_freq = "epoch",        # Default = epoch
    save_weights_only = False,  # Default = False
    save_best_only = True,      # Save only if the monitored metric improves
    mode = "min",               # "min" if monitoring loss, "max" if monitoring accuracy
    verbose = 1                 # Verbosity mode (0, 1, or 2)
)

# Define TensorBoard Logs
log_dir = os.path.join(work_path, f"{folder_name}_LOGS_TRAIN")
tensorboard = TensorBoard(
    log_dir = log_dir,
    write_graph = True,
    write_images = True,
    update_freq = "epoch"
)

# Define CSVLogger
CSV_Log_filename = os.path.join(work_path, f"{folder_name}_TRAIN.log")
CSV_Logger = CSVLogger(
    CSV_Log_filename,
    separator = "|",
    append = False
)

# Define the callbacks list
callbacks_list = [early_stopping, lr_scheduler, checkpoint, tensorboard, CSV_Logger]

# %% [markdown]
# ### II.2.2. Fine Tune Optimization

# %%
# Define the FT Early stopping
ft_early_stopping = EarlyStopping(
    monitor = "val_loss",
    patience = 3,
    verbose = 1,                 # Verbosity mode (0, 1, or 2)
    restore_best_weights = True  # Whether to restore model weights to the best epoch
)

# Define the FT Learning rate scheduler
ft_lr_scheduler = ReduceLROnPlateau(
    monitor = "val_loss",  # Metric to monitor
    factor = 0.2,          # Factor by which to reduce the learning rate
    patience = 3,          # Number of epochs with no improvement (default = 10)
    verbose = 1,           # Verbosity mode (0, 1, or 2)
    min_lr = 1e-6          # Minimum learning rate
)

# Define the FT checkpoint callback
ft_checkpoint = ModelCheckpoint(
    # filepath = os.path.join(work_path, f"{model_name}_FT_CheckPoint"), # to use if don't wanna save to a .h5 or .keras file
    filepath = os.path.join(work_path, f"{folder_name}_H5_Model", f"{folder_name}_FT_MCPBest.h5"),
    monitor = "val_loss",       # Metric to monitor
    save_freq = "epoch",        # Default = epoch
    save_weights_only = False,  # Default = False
    save_best_only = True,      # Save only if the monitored metric improves
    mode = "min",               # "min" if monitoring loss, "max" if monitoring accuracy
    verbose = 1                 # Verbosity mode (0, 1, or 2)
)

# Define the FT TensorBoard Logs
ft_log_dir = os.path.join(work_path, f"{folder_name}_LOGS_FT")
ft_tensorboard = TensorBoard(
    log_dir = ft_log_dir,
    write_graph=True,
    write_images=True,
    update_freq = "epoch"
)

# Define the FT CSVLogger
ft_CSV_Log_filename = os.path.join(work_path, f"{folder_name}_FT.log")
ft_CSV_Logger = CSVLogger(
    ft_CSV_Log_filename,
    separator = "|",
    append = False
)

# Define the FT callbacks list
ft_callbacks_list = [ft_early_stopping, ft_lr_scheduler, ft_checkpoint, ft_tensorboard, ft_CSV_Logger]

# %% [markdown]
# ## II.3. Pre train the model

# %% [markdown]
# ### II.3.1. Instantiate a base model with pre-trained model and weights

# %%
# First instantiate a base model with pre-trained weights
base_model = ModelNameFunc(
    include_top = False,
    weights = "imagenet",
    # include_preprocessing = False, # ONLY for V2 model, otherwise put it as comment.
    input_shape = (height, width, output_neurons)
)
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb3_notop.h5
# 43941136/43941136 [==============================] - 3s 0us/step

# %%
display(base_model.input)
# Out:
# <KerasTensor: shape=(None, 240, 240, 3) dtype=float32 (created by layer 'input_1')>

# %% [markdown]
# ### II.3.2. Define the new architecture on top

# %%
x = base_model.output
x = GlobalAveragePooling2D()(x) # Pooling
x = Dense(l1_neurons, activation = l1_activation)(x)
x = Dropout(dropout)(x)
x = Dense(l2_neurons, activation = l2_activation)(x)
x = BatchNormalization()(x)

predictions = Dense(output_neurons, activation = output_activation)(x)

model = Model(inputs = base_model.input, outputs = predictions)

# %%
print(model.input_shape)
# Out:
# (None, 240, 240, 3)

# %% [markdown]
# ### II.3.4. Compile the model

# %%
model.compile(
    optimizer = compile_optimizer,
    loss = compile_loss,
    metrics = compile_metrics
)

# %% [markdown]
# ### II.3.5. Train the model
# It's called "history" because it essentially keeps a historical record of various metrics and data related to how the model performed during training.

# %%
history = model.fit(
    x = train_generator,
    steps_per_epoch = train_generator.samples // batch_size + 1,
    validation_data = val_generator,
    validation_steps = val_generator.samples // batch_size + 1,
    epochs = epochs,
    verbose = verbose,
    callbacks = callbacks_list
)

# Save the model
model.save(fileh5_path)
# Out:
# Epoch 1/30
# 132/132 [==============================] - ETA: 0s - loss: 0.3718 - accuracy: 0.8736 - Precision: 0.9045 - Recall: 0.8414
# Epoch 1: val_loss improved from inf to 4.27920, saving model to /content/drive/MyDrive/Colab Notebooks/EfficientNetB3_L1N32L2N16-RMS/EfficientNetB3_L1N32L2N16-RMS_H5_Model/EfficientNetB3_L1N32L2N16-RMS_TRAIN_MCPBest.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 132/132 [==============================] - 3474s 26s/step - loss: 0.3718 - accuracy: 0.8736 - Precision: 0.9045 - Recall: 0.8414 - val_loss: 4.2792 - val_accuracy: 0.3333 - val_Precision: 0.3333 - val_Recall: 0.3333 - lr: 0.0010
# Epoch 2/30
# 132/132 [==============================] - ETA: 0s - loss: 0.2437 - accuracy: 0.9229 - Precision: 0.9371 - Recall: 0.9088
# Epoch 2: val_loss improved from 4.27920 to 1.49057, saving model to /content/drive/MyDrive/Colab Notebooks/EfficientNetB3_L1N32L2N16-RMS/EfficientNetB3_L1N32L2N16-RMS_H5_Model/EfficientNetB3_L1N32L2N16-RMS_TRAIN_MCPBest.h5
# 132/132 [==============================] - 146s 1s/step - loss: 0.2437 - accuracy: 0.9229 - Precision: 0.9371 - Recall: 0.9088 - val_loss: 1.4906 - val_accuracy: 0.3333 - val_Precision: 0.3333 - val_Recall: 0.3333 - lr: 0.0010
# Epoch 3/30
# 132/132 [==============================] - ETA: 0s - loss: 0.1752 - accuracy: 0.9471 - Precision: 0.9568 - Recall: 0.9381
# Epoch 3: val_loss improved from 1.49057 to 1.15039, saving model to /content/drive/MyDrive/Colab Notebooks/EfficientNetB3_L1N32L2N16-RMS/EfficientNetB3_L1N32L2N16-RMS_H5_Model/EfficientNetB3_L1N32L2N16-RMS_TRAIN_MCPBest.h5
# 132/132 [==============================] - 146s 1s/step - loss: 0.1752 - accuracy: 0.9471 - Precision: 0.9568 - Recall: 0.9381 - val_loss: 1.1504 - val_accuracy: 0.3333 - val_Precision: 0.0000e+00 - val_Recall: 0.0000e+00 - lr: 0.0010
# Epoch 4/30
# 132/132 [==============================] - ETA: 0s - loss: 0.1416 - accuracy: 0.9550 - Precision: 0.9612 - Recall: 0.9498
# Epoch 4: val_loss did not improve from 1.15039
# 132/132 [==============================] - 140s 1s/step - loss: 0.1416 - accuracy: 0.9550 - Precision: 0.9612 - Recall: 0.9498 - val_loss: 1.9224 - val_accuracy: 0.3425 - val_Precision: 0.3420 - val_Recall: 0.3417 - lr: 0.0010
# Epoch 5/30
# 132/132 [==============================] - ETA: 0s - loss: 0.1346 - accuracy: 0.9581 - Precision: 0.9637 - Recall: 0.9533
# Epoch 5: val_loss did not improve from 1.15039
# 132/132 [==============================] - 142s 1s/step - loss: 0.1346 - accuracy: 0.9581 - Precision: 0.9637 - Recall: 0.9533 - val_loss: 1.7965 - val_accuracy: 0.3333 - val_Precision: 0.3336 - val_Recall: 0.3333 - lr: 0.0010
# Epoch 6/30
# 132/132 [==============================] - ETA: 0s - loss: 0.1243 - accuracy: 0.9624 - Precision: 0.9664 - Recall: 0.9579
# Epoch 6: val_loss did not improve from 1.15039
# 132/132 [==============================] - 142s 1s/step - loss: 0.1243 - accuracy: 0.9624 - Precision: 0.9664 - Recall: 0.9579 - val_loss: 1.6479 - val_accuracy: 0.4358 - val_Precision: 0.4376 - val_Recall: 0.4325 - lr: 0.0010
# Epoch 7/30
# 132/132 [==============================] - ETA: 0s - loss: 0.1122 - accuracy: 0.9693 - Precision: 0.9724 - Recall: 0.9645
# Epoch 7: val_loss did not improve from 1.15039
# 132/132 [==============================] - 141s 1s/step - loss: 0.1122 - accuracy: 0.9693 - Precision: 0.9724 - Recall: 0.9645 - val_loss: 1.5101 - val_accuracy: 0.3308 - val_Precision: 0.3303 - val_Recall: 0.3292 - lr: 0.0010
# Epoch 8/30
# 132/132 [==============================] - ETA: 0s - loss: 0.0928 - accuracy: 0.9717 - Precision: 0.9760 - Recall: 0.9693Restoring model weights from the end of the best epoch: 3.
#
# Epoch 8: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
#
# Epoch 8: val_loss did not improve from 1.15039
# 132/132 [==============================] - 140s 1s/step - loss: 0.0928 - accuracy: 0.9717 - Precision: 0.9760 - Recall: 0.9693 - val_loss: 1.3311 - val_accuracy: 0.3433 - val_Precision: 0.3464 - val_Recall: 0.3375 - lr: 0.0010
# Epoch 8: early stopping

# %% [markdown]
# ### II.3.7. Evaluate Pre trained model

# %%
# Predict the values from the Test Dataset
Y_pred = model.predict(test_generator, steps = test_generator.samples // batch_size + 1)

# Convert predictions classes from one hot vectors
Y_pred_classes = np.argmax(Y_pred, axis = 1)
# Out:
# 19/19 [==============================] - 474s 26s/step

# %%
# Evaluate the model on the Test Dataset using `evaluate`
# f1 = F1Score(test_generator.classes, Y_pred_classes)
f1 = f1_score(test_generator.classes, Y_pred_classes, average = "macro")
print("F1 Score : ", f1)
print("Evaluate on Test Data")
results = model.evaluate(test_generator, batch_size = batch_size)
# Out:
# F1 Score :  0.16666666666666666
# Evaluate on Test Data
# 19/19 [==============================] - 6s 316ms/step - loss: 1.1513 - accuracy: 0.3333 - Precision: 0.0000e+00 - Recall: 0.0000e+00

# %% [markdown]
# ### II.3.8. Plot the Accuracy and the loss graphs

# %%
# Plot the Loss graph
plt.plot(history.history["loss"])
plt.plot(history.history["val_loss"])
plt.title("Model Loss")
plt.ylabel("Loss")
plt.xlabel("Epoch")
plt.legend(["Train", "Val"], loc = "upper left")
plt.show()

# %%
# Plot the Accuracy graph
plt.plot(history.history["accuracy"])
plt.plot(history.history["val_accuracy"])
plt.title("Model Accuracy")
plt.ylabel("Accuracy")
plt.xlabel("Epoch")
plt.legend(["Train", "Val"], loc = "lower left")
plt.show()

# %% [markdown]
# ### II.3.8. Trained Model : Confusion Matrix

# %%
# # Predict the values from the Test Dataset
# Y_pred = model.predict(test_generator, steps = test_generator.samples // batch_size + 1)

# # Convert predictions classes from one hot vectors
# Y_pred_classes = np.argmax(Y_pred, axis = 1)

# Convert validation observations from one hot vectors
# Y_true = np.argmax(test_generator.classes, axis = 1)
# OR
Y_true = test_generator.classes

# Compute the confusion matrix
cm = confusion_matrix(Y_true, Y_pred_classes)

# Print the confusion matrix
print("Confusion Matrix")
print(cm)

# Retrieve class names (label)
names_from_dir = sorted(os.listdir(val_dir))
dict(enumerate(names_from_dir))
#OR
class_names = list(val_generator.class_indices.keys())
# Check if the both are similar
print(names_from_dir == class_names)

# Print the classification report
print("Classification Report")
print(classification_report(Y_true, Y_pred_classes, target_names = class_names, digits = 4))
# Out:
# Confusion Matrix
# [[200   0   0]
#  [200   0   0]
#  [200   0   0]]
# True
# Classification Report
#               precision    recall  f1-score   support
#
#          Bee     0.3333    1.0000    0.5000       200
#    Butterfly     0.0000    0.0000    0.0000       200
#      Ladybug     0.0000    0.0000    0.0000       200
#
#     accuracy                         0.3333       600
#    macro avg     0.1111    0.3333    0.1667       600
# weighted avg     0.1111    0.3333    0.1667       600
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ### II.3.9. Confusion Matrix Function

# %%
def plot_confusion_matrix(
    cm,
    classes,
    normalize = False,
    title = "Confusion matrix",
    cmap = plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype("float") / cm.sum(axis =1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)
    plt.imshow(cm, interpolation = "nearest", cmap = cmap)
    plt.title(title)
    plt.colorbar()
    plt.tight_layout()
    plt.ylabel("True label")
    plt.xlabel("Predicted label")

# %% [markdown]
# ### II.3.10. Trained Model : Confusion Matrix Graph

# %%
plot_confusion_matrix(
    cm,
    class_names,
    normalize = True,
    title = "Confusion matrix",
    cmap = plt.cm.Blues
    )
# Out:
# Normalized confusion matrix
# [[1. 0. 0.]
#  [1. 0. 0.]
#  [1. 0. 0.]]

# %% [markdown]
# ## II.4. Fine Tuning
# This requires unfreezing the base model and then recompiling the model (necessary for the changes to take effect), and then resuming training.

# %% [markdown]
# ### II.4.1. Unfreeze the base model

# %%
# Unfreeze the base model
base_model.trainable = True

# %% [markdown]
# ### II.4.2. Re compile the model with a very low learning rate

# %%
# It's important to recompile your model after you make any changes
# to the `trainable` attribute of any inner layer, so that your changes
# are take into account
model.compile(
    optimizer = ft_compile_optimizer,
    loss = ft_compile_loss,
    metrics = ft_compile_metrics
)

# %% [markdown]
# ### II.4.3. Retraining the model

# %%
# Resume training
ft_history = model.fit(
    x = train_generator,
    steps_per_epoch = train_generator.samples // batch_size + 1,
    validation_data = val_generator,
    validation_steps = val_generator.samples // batch_size + 1,
    epochs = ft_epochs,
    verbose = ft_verbose,
    callbacks = ft_callbacks_list
)

# Save the Fine tuned model
model.save(ft_fileh5_path)
# Out:
# Epoch 1/15
# 132/132 [==============================] - ETA: 0s - loss: 0.1314 - accuracy: 0.9607 - Precision: 0.9658 - Recall: 0.8348
# Epoch 1: val_loss improved from inf to 1.16603, saving model to /content/drive/MyDrive/Colab Notebooks/EfficientNetB3_L1N32L2N16-RMS/EfficientNetB3_L1N32L2N16-RMS_H5_Model/EfficientNetB3_L1N32L2N16-RMS_FT_MCPBest.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 132/132 [==============================] - 200s 1s/step - loss: 0.1314 - accuracy: 0.9607 - Precision: 0.9658 - Recall: 0.8348 - val_loss: 1.1660 - val_accuracy: 0.4158 - val_Precision: 0.3365 - val_Recall: 0.1175 - lr: 1.0000e-05
# Epoch 2/15
# 132/132 [==============================] - ETA: 0s - loss: 0.1212 - accuracy: 0.9645 - Precision: 0.9694 - Recall: 0.9595
# Epoch 2: val_loss improved from 1.16603 to 0.69952, saving model to /content/drive/MyDrive/Colab Notebooks/EfficientNetB3_L1N32L2N16-RMS/EfficientNetB3_L1N32L2N16-RMS_H5_Model/EfficientNetB3_L1N32L2N16-RMS_FT_MCPBest.h5
# 132/132 [==============================] - 144s 1s/step - loss: 0.1212 - accuracy: 0.9645 - Precision: 0.9694 - Recall: 0.9595 - val_loss: 0.6995 - val_accuracy: 0.7292 - val_Precision: 0.7820 - val_Recall: 0.5858 - lr: 1.0000e-05
# Epoch 3/15
# 132/132 [==============================] - ETA: 0s - loss: 0.1225 - accuracy: 0.9657 - Precision: 0.9711 - Recall: 0.9614
# Epoch 3: val_loss improved from 0.69952 to 0.07172, saving model to /content/drive/MyDrive/Colab Notebooks/EfficientNetB3_L1N32L2N16-RMS/EfficientNetB3_L1N32L2N16-RMS_H5_Model/EfficientNetB3_L1N32L2N16-RMS_FT_MCPBest.h5
# 132/132 [==============================] - 143s 1s/step - loss: 0.1225 - accuracy: 0.9657 - Precision: 0.9711 - Recall: 0.9614 - val_loss: 0.0717 - val_accuracy: 0.9775 - val_Precision: 0.9806 - val_Recall: 0.9708 - lr: 1.0000e-05
# Epoch 4/15
# 132/132 [==============================] - ETA: 0s - loss: 0.1015 - accuracy: 0.9738 - Precision: 0.9776 - Recall: 0.9683
# Epoch 4: val_loss improved from 0.07172 to 0.05895, saving model to /content/drive/MyDrive/Colab Notebooks/EfficientNetB3_L1N32L2N16-RMS/EfficientNetB3_L1N32L2N16-RMS_H5_Model/EfficientNetB3_L1N32L2N16-RMS_FT_MCPBest.h5
# 132/132 [==============================] - 145s 1s/step - loss: 0.1015 - accuracy: 0.9738 - Precision: 0.9776 - Recall: 0.9683 - val_loss: 0.0590 - val_accuracy: 0.9817 - val_Precision: 0.9833 - val_Recall: 0.9817 - lr: 1.0000e-05
# Epoch 5/15
# 132/132 [==============================] - ETA: 0s - loss: 0.1067 - accuracy: 0.9712 - Precision: 0.9767 - Recall: 0.9669
# Epoch 5: val_loss did not improve from 0.05895
# 132/132 [==============================] - 142s 1s/step - loss: 0.1067 - accuracy: 0.9712 - Precision: 0.9767 - Recall: 0.9669 - val_loss: 0.0637 - val_accuracy: 0.9808 - val_Precision: 0.9841 - val_Recall: 0.9808 - lr: 1.0000e-05
# Epoch 6/15
# 132/132 [==============================] - ETA: 0s - loss: 0.0863 - accuracy: 0.9783 - Precision: 0.9832 - Recall: 0.9733
# Epoch 6: val_loss improved from 0.05895 to 0.05572, saving model to /content/drive/MyDrive/Colab Notebooks/EfficientNetB3_L1N32L2N16-RMS/EfficientNetB3_L1N32L2N16-RMS_H5_Model/EfficientNetB3_L1N32L2N16-RMS_FT_MCPBest.h5
# 132/132 [==============================] - 142s 1s/step - loss: 0.0863 - accuracy: 0.9783 - Precision: 0.9832 - Recall: 0.9733 - val_loss: 0.0557 - val_accuracy: 0.9842 - val_Precision: 0.9866 - val_Recall: 0.9817 - lr: 1.0000e-05
# Epoch 7/15
# 132/132 [==============================] - ETA: 0s - loss: 0.0873 - accuracy: 0.9779 - Precision: 0.9813 - Recall: 0.9736
# Epoch 7: val_loss did not improve from 0.05572
# 132/132 [==============================] - 142s 1s/step - loss: 0.0873 - accuracy: 0.9779 - Precision: 0.9813 - Recall: 0.9736 - val_loss: 0.0589 - val_accuracy: 0.9825 - val_Precision: 0.9866 - val_Recall: 0.9800 - lr: 1.0000e-05
# Epoch 8/15
# 132/132 [==============================] - ETA: 0s - loss: 0.0873 - accuracy: 0.9774 - Precision: 0.9799 - Recall: 0.9740
# Epoch 8: val_loss improved from 0.05572 to 0.05394, saving model to /content/drive/MyDrive/Colab Notebooks/EfficientNetB3_L1N32L2N16-RMS/EfficientNetB3_L1N32L2N16-RMS_H5_Model/EfficientNetB3_L1N32L2N16-RMS_FT_MCPBest.h5
# 132/132 [==============================] - 144s 1s/step - loss: 0.0873 - accuracy: 0.9774 - Precision: 0.9799 - Recall: 0.9740 - val_loss: 0.0539 - val_accuracy: 0.9858 - val_Precision: 0.9875 - val_Recall: 0.9842 - lr: 1.0000e-05
# Epoch 9/15
# 132/132 [==============================] - ETA: 0s - loss: 0.0845 - accuracy: 0.9771 - Precision: 0.9799 - Recall: 0.9740
# Epoch 9: val_loss improved from 0.05394 to 0.04792, saving model to /content/drive/MyDrive/Colab Notebooks/EfficientNetB3_L1N32L2N16-RMS/EfficientNetB3_L1N32L2N16-RMS_H5_Model/EfficientNetB3_L1N32L2N16-RMS_FT_MCPBest.h5
# 132/132 [==============================] - 143s 1s/step - loss: 0.0845 - accuracy: 0.9771 - Precision: 0.9799 - Recall: 0.9740 - val_loss: 0.0479 - val_accuracy: 0.9883 - val_Precision: 0.9883 - val_Recall: 0.9833 - lr: 1.0000e-05
# Epoch 10/15
# 132/132 [==============================] - ETA: 0s - loss: 0.0979 - accuracy: 0.9760 - Precision: 0.9784 - Recall: 0.9717
# Epoch 10: val_loss improved from 0.04792 to 0.04748, saving model to /content/drive/MyDrive/Colab Notebooks/EfficientNetB3_L1N32L2N16-RMS/EfficientNetB3_L1N32L2N16-RMS_H5_Model/EfficientNetB3_L1N32L2N16-RMS_FT_MCPBest.h5
# 132/132 [==============================] - 141s 1s/step - loss: 0.0979 - accuracy: 0.9760 - Precision: 0.9784 - Recall: 0.9717 - val_loss: 0.0475 - val_accuracy: 0.9867 - val_Precision: 0.9891 - val_Recall: 0.9850 - lr: 1.0000e-05
# Epoch 11/15
# 132/132 [==============================] - ETA: 0s - loss: 0.0831 - accuracy: 0.9776 - Precision: 0.9813 - Recall: 0.9745
# Epoch 11: val_loss did not improve from 0.04748
# 132/132 [==============================] - 142s 1s/step - loss: 0.0831 - accuracy: 0.9776 - Precision: 0.9813 - Recall: 0.9745 - val_loss: 0.0488 - val_accuracy: 0.9850 - val_Precision: 0.9866 - val_Recall: 0.9833 - lr: 1.0000e-05
# Epoch 12/15
# 132/132 [==============================] - ETA: 0s - loss: 0.0723 - accuracy: 0.9848 - Precision: 0.9864 - Recall: 0.9819
# Epoch 12: val_loss improved from 0.04748 to 0.04711, saving model to /content/drive/MyDrive/Colab Notebooks/EfficientNetB3_L1N32L2N16-RMS/EfficientNetB3_L1N32L2N16-RMS_H5_Model/EfficientNetB3_L1N32L2N16-RMS_FT_MCPBest.h5
# 132/132 [==============================] - 143s 1s/step - loss: 0.0723 - accuracy: 0.9848 - Precision: 0.9864 - Recall: 0.9819 - val_loss: 0.0471 - val_accuracy: 0.9850 - val_Precision: 0.9866 - val_Recall: 0.9833 - lr: 1.0000e-05
# Epoch 13/15
# 132/132 [==============================] - ETA: 0s - loss: 0.0784 - accuracy: 0.9800 - Precision: 0.9825 - Recall: 0.9769
# Epoch 13: val_loss did not improve from 0.04711
# 132/132 [==============================] - 149s 1s/step - loss: 0.0784 - accuracy: 0.9800 - Precision: 0.9825 - Recall: 0.9769 - val_loss: 0.0484 - val_accuracy: 0.9842 - val_Precision: 0.9866 - val_Recall: 0.9833 - lr: 1.0000e-05
# Epoch 14/15
# 132/132 [==============================] - ETA: 0s - loss: 0.0746 - accuracy: 0.9833 - Precision: 0.9842 - Recall: 0.9793
# Epoch 14: val_loss improved from 0.04711 to 0.04600, saving model to /content/drive/MyDrive/Colab Notebooks/EfficientNetB3_L1N32L2N16-RMS/EfficientNetB3_L1N32L2N16-RMS_H5_Model/EfficientNetB3_L1N32L2N16-RMS_FT_MCPBest.h5
# 132/132 [==============================] - 149s 1s/step - loss: 0.0746 - accuracy: 0.9833 - Precision: 0.9842 - Recall: 0.9793 - val_loss: 0.0460 - val_accuracy: 0.9858 - val_Precision: 0.9883 - val_Recall: 0.9833 - lr: 1.0000e-05
# Epoch 15/15
# 132/132 [==============================] - ETA: 0s - loss: 0.0710 - accuracy: 0.9805 - Precision: 0.9826 - Recall: 0.9798
# Epoch 15: val_loss improved from 0.04600 to 0.04186, saving model to /content/drive/MyDrive/Colab Notebooks/EfficientNetB3_L1N32L2N16-RMS/EfficientNetB3_L1N32L2N16-RMS_H5_Model/EfficientNetB3_L1N32L2N16-RMS_FT_MCPBest.h5
# 132/132 [==============================] - 145s 1s/step - loss: 0.0710 - accuracy: 0.9805 - Precision: 0.9826 - Recall: 0.9798 - val_loss: 0.0419 - val_accuracy: 0.9875 - val_Precision: 0.9883 - val_Recall: 0.9867 - lr: 1.0000e-05

# %% [markdown]
# ### II.4.4. Evaluation Fine Tune Model

# %%
# Evaluate the model on the Test Dataset using `evaluate`
# f1 = F1Score(test_generator.classes, Y_pred_classes)
ft_f1 = f1_score(test_generator.classes, Y_pred_classes, average = "macro")
print("F1 Score : ", ft_f1)
print("Evaluate on Test Data")
ft_results = model.evaluate(test_generator, batch_size = batch_size)
# Out:
# F1 Score :  0.16666666666666666
# Evaluate on Test Data
# 19/19 [==============================] - 6s 307ms/step - loss: 0.0408 - accuracy: 0.9883 - Precision: 0.9900 - Recall: 0.9867

# %%
# Plot the Loss graph
plt.plot(ft_history.history["loss"])
plt.plot(ft_history.history["val_loss"])
plt.title("Model Loss")
plt.ylabel("loss")
plt.xlabel("epoch")
plt.legend(["Train", "Val"], loc = "upper left")
plt.show()

# %%
# Plot the Accuracy graph
plt.plot(ft_history.history["accuracy"])
plt.plot(ft_history.history["val_accuracy"])
plt.title("Model Accuracy")
plt.ylabel("Accuracy")
plt.xlabel("Epoch")
plt.legend(["Train", "Val"], loc = "lower left")
plt.show()

# %% [markdown]
# ### II.4.5. Fine Tuned Model : Confusion Matrix

# %%
# # Predict the values from the validation dataset
# Y_pred = model.predict(test_generator, steps = test_generator.samples // batch_size + 1)

# # Convert predictions classes from one hot vectors
# Y_pred_classes = np.argmax(Y_pred, axis = 1)

# Convert validation observations from one hot vectors
# Y_true = np.argmax(test_generator.classes, axis = 1)
# OR
Y_true = test_generator.classes

# Compute the confusion matrix
ft_cm = confusion_matrix(Y_true, Y_pred_classes)

# Print the confusion matrix
print("Confusion Matrix")
print(ft_cm)

# Retrieve class names (label)
names_from_dir = sorted(os.listdir(val_dir))
dict(enumerate(names_from_dir))
#OR
class_names = list(val_generator.class_indices.keys())
# Check if the both are similar
print(names_from_dir == class_names)

# Print the classification report
print("Classification Report")
print(classification_report(Y_true, Y_pred_classes, target_names = class_names, digits = 4))
# Out:
# Confusion Matrix
# [[200   0   0]
#  [200   0   0]
#  [200   0   0]]
# True
# Classification Report
#               precision    recall  f1-score   support
#
#          Bee     0.3333    1.0000    0.5000       200
#    Butterfly     0.0000    0.0000    0.0000       200
#      Ladybug     0.0000    0.0000    0.0000       200
#
#     accuracy                         0.3333       600
#    macro avg     0.1111    0.3333    0.1667       600
# weighted avg     0.1111    0.3333    0.1667       600
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ### II.4.5. Fine Tuned Model : Confusion Matrix Graph

# %%
plot_confusion_matrix(ft_cm,
                      class_names,
                      normalize = True,
                      title = "Confusion matrix",
                      cmap = plt.cm.Blues
                      )
# Out:
# Normalized confusion matrix
# [[1. 0. 0.]
#  [1. 0. 0.]
#  [1. 0. 0.]]
