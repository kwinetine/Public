# %% [markdown]
# ## I.1. Install

# %%
# # GOOGLE Colab ONLY : Mount GOOGLE Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
# GOOGLE Colab ONLY : Get & store the default work path
user_path = os.path.join(os.getcwd(), "drive", "MyDrive", "Colab Notebooks")

# LOCAL : Get & store the current working path
# user_path = os.path.dirname(os.path.abspath("NoNeedFilename"))

print(user_path)
# Out:
# /content/drive/MyDrive/Colab Notebooks

# %%
# !pip install -r "/content/drive/MyDrive/Colab Notebooks/requirements.txt"

# %% [markdown]
# ## I.2. Libraries Import

# %%
import numpy as np
import matplotlib.pyplot as plt

# Machine Learning
import keras
from keras.models import Model
from keras.preprocessing.image import ImageDataGenerator
from keras.layers import Dense, Dropout, GlobalAveragePooling2D, BatchNormalization
from keras.optimizers import Adam, Nadam, SGD, RMSprop
from sklearn.metrics import confusion_matrix, classification_report
from keras.applications import EfficientNetB1, EfficientNetB2, EfficientNetB3, EfficientNetV2B1, EfficientNetV2B2, EfficientNetV2B3

# %% [markdown]
# ## I.4. Image Processing

# %% [markdown]
# ### I.4.2. Set Image Folder Path

# %%
# GOOGLE Colab ONLY
train_dir = os.path.join(user_path, "IMAGE_SPLIT", "train")
val_dir = os.path.join(user_path, "IMAGE_SPLIT", "val")
test_dir = os.path.join(user_path, "IMAGE_SPLIT", "test")

# LOCAL
# train_dir = r"C:\WORKSPACES\DATA\ML_DL\IMAGE_SPLIT\train"
# val_dir = r"C:\WORKSPACES\DATA\ML_DL\IMAGE_SPLIT\val"
# test_dir = r"C:\WORKSPACES\DATA\ML_DL\IMAGE_SPLIT\test"

# %% [markdown]
# ### I.4.3. Data augmentation techniques

# %%
train_datagen = ImageDataGenerator(
    rescale = 1./255,
    shear_range = 0.2,
    rotation_range = 20,
    width_shift_range = 0.1,
    height_shift_range = 0.1,
    zoom_range = [0.9, 1.25],
    brightness_range = [0.5, 1.5],
    horizontal_flip = True,
    vertical_flip = True
)

val_datagen = ImageDataGenerator(
    rescale = 1./255)

test_datagen = ImageDataGenerator(
    rescale = 1./255)

# %% [markdown]
# ### I.4.4. Setup Data generators

# %%
# Variables
batch_size = 32
height = 240
width = 240
image_shape = (height, width) # images of size 240x240 px with 3 color channels RGB automatically


train_generator = train_datagen.flow_from_directory(
    train_dir,
    class_mode = "categorical",
    target_size = image_shape,
    batch_size = batch_size
)

val_generator = val_datagen.flow_from_directory(
    val_dir,
    class_mode = "categorical",
    target_size = image_shape,
    batch_size = batch_size
)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    class_mode = "categorical",
    target_size = image_shape,
    batch_size = batch_size,
    shuffle = False
)
# Out:
# Found 4200 images belonging to 3 classes.
# Found 1200 images belonging to 3 classes.
# Found 600 images belonging to 3 classes.

# %% [markdown]
# ## II.1. Define variables and parameters

# %%
# Model to use for transfer learning
model_name = "EfficientNetV2B1"
ModelNameFunc = globals()[model_name]

# Top Architecture for the new model
l1_neurons = 32                 # Number of neurons on layer 1 (deeper)
l1_activation = "relu"
dropout = 0.4                   # 0.2 - 0.5
l2_neurons = 16                 # Number of neurons on layer 2
l2_activation = "relu"
output_neurons = 3              # This layer will have 3 neurons or units fully connected. In line with our 3 classes.
output_activation = "softmax"

# Metrics (parameter average = "macro" by default )
precision = keras.metrics.Precision(name="Precision")
recall = keras.metrics.Recall(name="Recall")
# f1 = keras.metrics.F1Score(name = "F1")
auc = keras.metrics.AUC(name="AUC")


# TRAIN : model.compile
compile_optimizer = "Nadam"                  # Test : Nadam, RMSprop, SGD
compile_loss = "categorical_crossentropy"   # More than 2 classes, so categorical
compile_metrics = ["accuracy", precision, recall, auc]

# TRAIN : model.fit
epochs = 30
verbose = 1

# FINE TUNE : model.compile
ft_compile_optimizer = Nadam(learning_rate = 1e-5)
# ft_compile_optimizer : Very low learning rate. Test : Nadam, RMSprop, SGD
ft_compile_loss = "categorical_crossentropy"
ft_compile_metrics = ["accuracy", precision, recall, auc]

# FINE TUNE : model.fit
ft_epochs = 15
ft_verbose = 1

# SAVE : File Path .h5
fileh5_path = os.path.join(user_path, f"{model_name}_H5_Model", f"{model_name}_TRAIN_ManualSave.h5")
ft_fileh5_path = os.path.join(user_path, f"{model_name}_H5_Model", f"{model_name}_FT_ManualSave.h5")

# %% [markdown]
# ## II.2. Define optimizations

# %% [markdown]
# ### II.2.1. Train optimizations

# %%
from keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint, TensorBoard

# Define the early stopping
early_stopping = EarlyStopping(
    monitor = "val_loss",        # Metric to monitor
    patience = 5,                # Number of epochs with no improvement  (around 10% of nb of epochs)
    verbose = 1,                 # Verbosity mode (0, 1, or 2)
    restore_best_weights = True  # Whether to restore model weights to the best epoch
)

# Define the learning rate scheduler
lr_scheduler = ReduceLROnPlateau(
    monitor = "val_loss",       # Metric to monitor
    factor = 0.2,               # Factor by which to reduce the learning rate
    patience = 5,               # Number of epochs with no improvement (default = 10)
    verbose = 1,                # Verbosity mode (0, 1, or 2)
    min_lr = 1e-6               # Minimum learning rate
)

# Define the model checkpoint callback
checkpoint = ModelCheckpoint(
    # filepath = os.path.join(user_path, f"{model_name}_TRAIN_CheckPoint"), # to use if don't wanna save to a .h5 or .keras file
    filepath = os.path.join(user_path, f"{model_name}_H5_Model", f"{model_name}_TRAIN_MCPBest.h5"),
    monitor = "val_loss",       # Metric to monitor
    save_freq = "epoch",        # Default = epoch
    save_weights_only = False,  # Default = False
    save_best_only = True,      # Save only if the monitored metric improves
    mode = "min",               # "min" if monitoring loss, "max" if monitoring accuracy
    verbose = 1                 # Verbosity mode (0, 1, or 2)
)

# Define TensorBoard Logs
log_dir = os.path.join(user_path, f"{model_name}_LOGS_TRAIN")
tensorboard = TensorBoard(log_dir)

# Include it in the callbacks list
callbacks_list = [early_stopping, lr_scheduler, checkpoint, tensorboard]

# %% [markdown]
# ### II.2.2. Fine Tune Optimization

# %%
# Define the early stopping
ft_early_stopping = EarlyStopping(
    monitor = "val_loss",
    patience = 3,
    verbose = 1,                 # Verbosity mode (0, 1, or 2)
    restore_best_weights = True  # Whether to restore model weights to the best epoch
)

# Define the learning rate scheduler
ft_lr_scheduler = ReduceLROnPlateau(
    monitor = "val_loss",  # Metric to monitor
    factor = 0.2,          # Factor by which to reduce the learning rate
    patience = 3,          # Number of epochs with no improvement (default = 10)
    verbose = 1,           # Verbosity mode (0, 1, or 2)
    min_lr = 1e-6          # Minimum learning rate
)

# Define the model checkpoint callback
ft_checkpoint = ModelCheckpoint(
    # filepath = os.path.join(user_path, f"{model_name}_FT_CheckPoint"), # to use if don't wanna save to a .h5 or .keras file
    filepath = os.path.join(user_path, f"{model_name}_H5_Model", f"{model_name}_FT_MCPBest.h5"),
    monitor = "val_loss",       # Metric to monitor
    save_freq = "epoch",        # Default = epoch
    save_weights_only = False,  # Default = False
    save_best_only = True,      # Save only if the monitored metric improves
    mode = "min",               # "min" if monitoring loss, "max" if monitoring accuracy
    verbose = 1                 # Verbosity mode (0, 1, or 2)
)

# Define TensorBoard Logs
ft_log_dir = os.path.join(user_path, f"{model_name}_LOGS_FT")
ft_tensorboard = TensorBoard(ft_log_dir)

# Include it in the callbacks list
ft_callbacks_list = [ft_early_stopping, ft_lr_scheduler, ft_checkpoint, ft_tensorboard]

# %% [markdown]
# ## II.3. Pre train the model

# %% [markdown]
# ### II.3.1. Instantiate a base model with pre-trained model and weights

# %%
# First instantiate a base model with pre-trained weights
base_model = ModelNameFunc(
    include_top = False,
    weights = "imagenet",
    include_preprocessing = False, # ONLY for V2 model, otherwise put it as comment.
    input_shape = (height, width, output_neurons)
)

# %%
display(base_model.input)
# Out:
# <KerasTensor: shape=(None, 240, 240, 3) dtype=float32 (created by layer 'input_1')>

# %% [markdown]
# ### II.3.2. Define the new architecture on top

# %%
x = base_model.output
x = GlobalAveragePooling2D()(x) # Pooling
x = Dense(l1_neurons, activation = l1_activation)(x)
x = Dropout(dropout)(x)
x = Dense(l2_neurons, activation = l2_activation)(x)
x = BatchNormalization()(x)

predictions = Dense(output_neurons, activation = output_activation)(x)

model = Model(inputs = base_model.input, outputs = predictions)

# %%
print(model.input_shape)
# Out:
# (None, 240, 240, 3)

# %% [markdown]
# ### II.3.4. Compile the model

# %%
model.compile(
    optimizer = compile_optimizer,
    loss = compile_loss,
    metrics = compile_metrics
)

# %% [markdown]
# ### II.3.5. Train the model
# It's called "history" because it essentially keeps a historical record of various metrics and data related to how the model performed during training.

# %%
history = model.fit(
    x = train_generator,
    steps_per_epoch = train_generator.samples // batch_size + 1,
    validation_data = val_generator,
    validation_steps = val_generator.samples // batch_size + 1,
    epochs = epochs,
    verbose = verbose,
    callbacks = callbacks_list
)

# Save the model
model.save(fileh5_path)
# Out:
# Epoch 1/30
# 132/132 [==============================] - ETA: 0s - loss: 0.3494 - accuracy: 0.8774 - Precision: 0.9031 - Recall: 0.8545 - AUC: 0.9694
# Epoch 1: val_loss improved from inf to 0.13711, saving model to /content/drive/MyDrive/Colab Notebooks/EfficientNetV2B1_H5_Model/EfficientNetV2B1_TRAIN_MCPBest.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 132/132 [==============================] - 957s 6s/step - loss: 0.3494 - accuracy: 0.8774 - Precision: 0.9031 - Recall: 0.8545 - AUC: 0.9694 - val_loss: 0.1371 - val_accuracy: 0.9517 - val_Precision: 0.9580 - val_Recall: 0.9500 - val_AUC: 0.9952 - lr: 0.0010
# Epoch 2/30
# 132/132 [==============================] - ETA: 0s - loss: 0.2012 - accuracy: 0.9407 - Precision: 0.9487 - Recall: 0.9329 - AUC: 0.9883
# Epoch 2: val_loss improved from 0.13711 to 0.08870, saving model to /content/drive/MyDrive/Colab Notebooks/EfficientNetV2B1_H5_Model/EfficientNetV2B1_TRAIN_MCPBest.h5
# 132/132 [==============================] - 135s 1s/step - loss: 0.2012 - accuracy: 0.9407 - Precision: 0.9487 - Recall: 0.9329 - AUC: 0.9883 - val_loss: 0.0887 - val_accuracy: 0.9717 - val_Precision: 0.9765 - val_Recall: 0.9700 - val_AUC: 0.9966 - lr: 0.0010
# Epoch 3/30
# 132/132 [==============================] - ETA: 0s - loss: 0.1717 - accuracy: 0.9467 - Precision: 0.9550 - Recall: 0.9402 - AUC: 0.9910
# Epoch 3: val_loss did not improve from 0.08870
# 132/132 [==============================] - 136s 1s/step - loss: 0.1717 - accuracy: 0.9467 - Precision: 0.9550 - Recall: 0.9402 - AUC: 0.9910 - val_loss: 0.2094 - val_accuracy: 0.9250 - val_Precision: 0.9262 - val_Recall: 0.9200 - val_AUC: 0.9882 - lr: 0.0010
# Epoch 4/30
# 132/132 [==============================] - ETA: 0s - loss: 0.1557 - accuracy: 0.9514 - Precision: 0.9574 - Recall: 0.9471 - AUC: 0.9927
# Epoch 4: val_loss did not improve from 0.08870
# 132/132 [==============================] - 130s 989ms/step - loss: 0.1557 - accuracy: 0.9514 - Precision: 0.9574 - Recall: 0.9471 - AUC: 0.9927 - val_loss: 0.1044 - val_accuracy: 0.9642 - val_Precision: 0.9673 - val_Recall: 0.9625 - val_AUC: 0.9970 - lr: 0.0010
# Epoch 5/30
# 132/132 [==============================] - ETA: 0s - loss: 0.1519 - accuracy: 0.9548 - Precision: 0.9600 - Recall: 0.9486 - AUC: 0.9922
# Epoch 5: val_loss did not improve from 0.08870
# 132/132 [==============================] - 132s 997ms/step - loss: 0.1519 - accuracy: 0.9548 - Precision: 0.9600 - Recall: 0.9486 - AUC: 0.9922 - val_loss: 0.1080 - val_accuracy: 0.9608 - val_Precision: 0.9616 - val_Recall: 0.9608 - val_AUC: 0.9974 - lr: 0.0010
# Epoch 6/30
# 132/132 [==============================] - ETA: 0s - loss: 0.1646 - accuracy: 0.9517 - Precision: 0.9590 - Recall: 0.9469 - AUC: 0.9907
# Epoch 6: val_loss improved from 0.08870 to 0.08354, saving model to /content/drive/MyDrive/Colab Notebooks/EfficientNetV2B1_H5_Model/EfficientNetV2B1_TRAIN_MCPBest.h5
# 132/132 [==============================] - 132s 1s/step - loss: 0.1646 - accuracy: 0.9517 - Precision: 0.9590 - Recall: 0.9469 - AUC: 0.9907 - val_loss: 0.0835 - val_accuracy: 0.9725 - val_Precision: 0.9749 - val_Recall: 0.9700 - val_AUC: 0.9981 - lr: 0.0010
# Epoch 7/30
# 132/132 [==============================] - ETA: 0s - loss: 0.1655 - accuracy: 0.9483 - Precision: 0.9549 - Recall: 0.9431 - AUC: 0.9911
# Epoch 7: val_loss did not improve from 0.08354
# 132/132 [==============================] - 138s 1s/step - loss: 0.1655 - accuracy: 0.9483 - Precision: 0.9549 - Recall: 0.9431 - AUC: 0.9911 - val_loss: 0.0862 - val_accuracy: 0.9708 - val_Precision: 0.9708 - val_Recall: 0.9700 - val_AUC: 0.9979 - lr: 0.0010
# Epoch 8/30
# 132/132 [==============================] - ETA: 0s - loss: 0.1185 - accuracy: 0.9631 - Precision: 0.9671 - Recall: 0.9600 - AUC: 0.9953
# Epoch 8: val_loss did not improve from 0.08354
# 132/132 [==============================] - 136s 1s/step - loss: 0.1185 - accuracy: 0.9631 - Precision: 0.9671 - Recall: 0.9600 - AUC: 0.9953 - val_loss: 0.1260 - val_accuracy: 0.9592 - val_Precision: 0.9607 - val_Recall: 0.9575 - val_AUC: 0.9953 - lr: 0.0010
# Epoch 9/30
# 132/132 [==============================] - ETA: 0s - loss: 0.0958 - accuracy: 0.9714 - Precision: 0.9746 - Recall: 0.9695 - AUC: 0.9968
# Epoch 9: val_loss improved from 0.08354 to 0.07446, saving model to /content/drive/MyDrive/Colab Notebooks/EfficientNetV2B1_H5_Model/EfficientNetV2B1_TRAIN_MCPBest.h5
# 132/132 [==============================] - 135s 1s/step - loss: 0.0958 - accuracy: 0.9714 - Precision: 0.9746 - Recall: 0.9695 - AUC: 0.9968 - val_loss: 0.0745 - val_accuracy: 0.9767 - val_Precision: 0.9775 - val_Recall: 0.9767 - val_AUC: 0.9978 - lr: 0.0010
# Epoch 10/30
# 132/132 [==============================] - ETA: 0s - loss: 0.1010 - accuracy: 0.9690 - Precision: 0.9706 - Recall: 0.9671 - AUC: 0.9961
# Epoch 10: val_loss did not improve from 0.07446
# 132/132 [==============================] - 128s 970ms/step - loss: 0.1010 - accuracy: 0.9690 - Precision: 0.9706 - Recall: 0.9671 - AUC: 0.9961 - val_loss: 0.1124 - val_accuracy: 0.9625 - val_Precision: 0.9632 - val_Recall: 0.9600 - val_AUC: 0.9970 - lr: 0.0010
# Epoch 11/30
# 132/132 [==============================] - ETA: 0s - loss: 0.0977 - accuracy: 0.9688 - Precision: 0.9708 - Recall: 0.9667 - AUC: 0.9970
# Epoch 11: val_loss did not improve from 0.07446
# 132/132 [==============================] - 129s 976ms/step - loss: 0.0977 - accuracy: 0.9688 - Precision: 0.9708 - Recall: 0.9667 - AUC: 0.9970 - val_loss: 0.1102 - val_accuracy: 0.9608 - val_Precision: 0.9632 - val_Recall: 0.9600 - val_AUC: 0.9951 - lr: 0.0010
# Epoch 12/30
# 132/132 [==============================] - ETA: 0s - loss: 0.1446 - accuracy: 0.9557 - Precision: 0.9597 - Recall: 0.9524 - AUC: 0.9925
# Epoch 12: val_loss did not improve from 0.07446
# 132/132 [==============================] - 128s 971ms/step - loss: 0.1446 - accuracy: 0.9557 - Precision: 0.9597 - Recall: 0.9524 - AUC: 0.9925 - val_loss: 0.1671 - val_accuracy: 0.9392 - val_Precision: 0.9430 - val_Recall: 0.9367 - val_AUC: 0.9925 - lr: 0.0010
# Epoch 13/30
# 132/132 [==============================] - ETA: 0s - loss: 0.1247 - accuracy: 0.9562 - Precision: 0.9624 - Recall: 0.9512 - AUC: 0.9945
# Epoch 13: val_loss did not improve from 0.07446
# 132/132 [==============================] - 148s 1s/step - loss: 0.1247 - accuracy: 0.9562 - Precision: 0.9624 - Recall: 0.9512 - AUC: 0.9945 - val_loss: 0.1161 - val_accuracy: 0.9583 - val_Precision: 0.9605 - val_Recall: 0.9533 - val_AUC: 0.9961 - lr: 0.0010
# Epoch 14/30
# 132/132 [==============================] - ETA: 0s - loss: 0.0846 - accuracy: 0.9755 - Precision: 0.9778 - Recall: 0.9733 - AUC: 0.9975Restoring model weights from the end of the best epoch: 9.
#
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
#
# Epoch 14: val_loss did not improve from 0.07446
# 132/132 [==============================] - 141s 1s/step - loss: 0.0846 - accuracy: 0.9755 - Precision: 0.9778 - Recall: 0.9733 - AUC: 0.9975 - val_loss: 0.1127 - val_accuracy: 0.9650 - val_Precision: 0.9658 - val_Recall: 0.9642 - val_AUC: 0.9950 - lr: 0.0010
# Epoch 14: early stopping

# %% [markdown]
# ### II.3.7. Evaluate Pre trained model

# %%
# Evaluate the model on the test data using `evaluate`
print("Evaluate on Test Data")
results = model.evaluate(test_generator, batch_size = batch_size)
# Out:
# Evaluate on Test Data
# 19/19 [==============================] - 114s 6s/step - loss: 0.1066 - accuracy: 0.9667 - Precision: 0.9667 - Recall: 0.9667 - AUC: 0.9945

# %% [markdown]
# ### II.3.8. Plot the Accuracy and the loss graphs

# %%
# Plot the Loss graph
plt.plot(history.history["loss"])
plt.plot(history.history["val_loss"])
plt.title("Model Loss")
plt.ylabel("Loss")
plt.xlabel("Epoch")
plt.legend(["Train", "Val"], loc = "upper left")
plt.show()

# %%
# Plot the Accuracy graph
plt.plot(history.history["accuracy"])
plt.plot(history.history["val_accuracy"])
plt.title("Model Accuracy")
plt.ylabel("Accuracy")
plt.xlabel("Epoch")
plt.legend(["Train", "Val"], loc = "lower left")
plt.show()

# %% [markdown]
# ### II.3.8. Trained Model : Confusion Matrix

# %%
# Predict the values from the validation dataset
Y_pred = model.predict(test_generator, steps = test_generator.samples // batch_size + 1)

# Convert predictions classes from one hot vectors
Y_pred_classes = np.argmax(Y_pred, axis = 1)

# Convert validation observations from one hot vectors
# Y_true = np.argmax(test_generator.classes, axis = 1)
# OR
Y_true = test_generator.classes

# Compute the confusion matrix
cm = confusion_matrix(Y_true, Y_pred_classes)

# Print the confusion matrix
print("Confusion Matrix")
print(cm)

# Retrieve class names (label)
names_from_dir = sorted(os.listdir(val_dir))
dict(enumerate(names_from_dir))
#OR
class_names = list(val_generator.class_indices.keys())
# Check if the both are similar
print(names_from_dir == class_names)

# Print the classification report
print("Classification Report")
print(classification_report(Y_true, Y_pred_classes, target_names = class_names, digits = 4))
# Out:
# 19/19 [==============================] - 8s 256ms/step
# Confusion Matrix
# [[200   0   0]
#  [ 11 189   0]
#  [  4   5 191]]
# True
# Classification Report
#               precision    recall  f1-score   support
#
#          Bee       0.93      1.00      0.96       200
#    Butterfly       0.97      0.94      0.96       200
#      Ladybug       1.00      0.95      0.98       200
#
#     accuracy                           0.97       600
#    macro avg       0.97      0.97      0.97       600
# weighted avg       0.97      0.97      0.97       600

# %% [markdown]
# ### II.3.9. Confusion Matrix Function

# %%
def plot_confusion_matrix(
    cm,
    classes,
    normalize = False,
    title = "Confusion matrix",
    cmap = plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype("float") / cm.sum(axis =1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)
    plt.imshow(cm, interpolation = "nearest", cmap = cmap)
    plt.title(title)
    plt.colorbar()
    plt.tight_layout()
    plt.ylabel("True label")
    plt.xlabel("Predicted label")

# %% [markdown]
# ### II.3.10. Trained Model : Confusion Matrix Graph

# %%
plot_confusion_matrix(
    cm,
    class_names,
    normalize = True,
    title = "Confusion matrix",
    cmap = plt.cm.Blues
    )
# Out:
# Normalized confusion matrix
# [[1.    0.    0.   ]
#  [0.055 0.945 0.   ]
#  [0.02  0.025 0.955]]

# %% [markdown]
# ## II.4. Fine Tuning
# This requires unfreezing the base model and then recompiling the model (necessary for the changes to take effect), and then resuming training.

# %% [markdown]
# ### II.4.1. Unfreeze the base model

# %%
# Unfreeze the base model
base_model.trainable = True

# %% [markdown]
# ### II.4.2. Re compile the model with a very low learning rate

# %%
# It's important to recompile your model after you make any changes
# to the `trainable` attribute of any inner layer, so that your changes
# are take into account
model.compile(
    optimizer = ft_compile_optimizer,
    loss = ft_compile_loss,
    metrics = ft_compile_metrics
)

# %% [markdown]
# ### II.4.3. Retraining the model

# %%
# Resume training
ft_history = model.fit(
    x = train_generator,
    steps_per_epoch = train_generator.samples // batch_size + 1,
    validation_data = val_generator,
    validation_steps = val_generator.samples // batch_size + 1,
    epochs = ft_epochs,
    verbose = ft_verbose,
    callbacks = ft_callbacks_list
)

# Save the Fine tuned model
model.save(ft_fileh5_path)
# Out:
# Epoch 1/15
# 132/132 [==============================] - ETA: 0s - loss: 0.0940 - accuracy: 0.9729 - Precision: 0.9733 - Recall: 0.9710 - AUC: 0.9961
# Epoch 1: val_loss improved from inf to 0.04593, saving model to /content/drive/MyDrive/Colab Notebooks/EfficientNetV2B1_H5_Model/EfficientNetV2B1_FT_MCPBest.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 132/132 [==============================] - 229s 1s/step - loss: 0.0940 - accuracy: 0.9729 - Precision: 0.9733 - Recall: 0.9710 - AUC: 0.9961 - val_loss: 0.0459 - val_accuracy: 0.9858 - val_Precision: 0.9866 - val_Recall: 0.9850 - val_AUC: 0.9989 - lr: 1.0000e-05
# Epoch 2/15
# 132/132 [==============================] - ETA: 0s - loss: 0.0700 - accuracy: 0.9790 - Precision: 0.9799 - Recall: 0.9771 - AUC: 0.9983
# Epoch 2: val_loss improved from 0.04593 to 0.04384, saving model to /content/drive/MyDrive/Colab Notebooks/EfficientNetV2B1_H5_Model/EfficientNetV2B1_FT_MCPBest.h5
# 132/132 [==============================] - 137s 1s/step - loss: 0.0700 - accuracy: 0.9790 - Precision: 0.9799 - Recall: 0.9771 - AUC: 0.9983 - val_loss: 0.0438 - val_accuracy: 0.9867 - val_Precision: 0.9875 - val_Recall: 0.9867 - val_AUC: 0.9989 - lr: 1.0000e-05
# Epoch 3/15
# 132/132 [==============================] - ETA: 0s - loss: 0.0616 - accuracy: 0.9838 - Precision: 0.9854 - Recall: 0.9826 - AUC: 0.9984
# Epoch 3: val_loss improved from 0.04384 to 0.04199, saving model to /content/drive/MyDrive/Colab Notebooks/EfficientNetV2B1_H5_Model/EfficientNetV2B1_FT_MCPBest.h5
# 132/132 [==============================] - 135s 1s/step - loss: 0.0616 - accuracy: 0.9838 - Precision: 0.9854 - Recall: 0.9826 - AUC: 0.9984 - val_loss: 0.0420 - val_accuracy: 0.9883 - val_Precision: 0.9883 - val_Recall: 0.9883 - val_AUC: 0.9989 - lr: 1.0000e-05
# Epoch 4/15
# 132/132 [==============================] - ETA: 0s - loss: 0.0650 - accuracy: 0.9819 - Precision: 0.9833 - Recall: 0.9812 - AUC: 0.9982
# Epoch 4: val_loss improved from 0.04199 to 0.03961, saving model to /content/drive/MyDrive/Colab Notebooks/EfficientNetV2B1_H5_Model/EfficientNetV2B1_FT_MCPBest.h5
# 132/132 [==============================] - 131s 990ms/step - loss: 0.0650 - accuracy: 0.9819 - Precision: 0.9833 - Recall: 0.9812 - AUC: 0.9982 - val_loss: 0.0396 - val_accuracy: 0.9908 - val_Precision: 0.9908 - val_Recall: 0.9908 - val_AUC: 0.9989 - lr: 1.0000e-05
# Epoch 5/15
# 132/132 [==============================] - ETA: 0s - loss: 0.0664 - accuracy: 0.9824 - Precision: 0.9830 - Recall: 0.9800 - AUC: 0.9979
# Epoch 5: val_loss improved from 0.03961 to 0.03677, saving model to /content/drive/MyDrive/Colab Notebooks/EfficientNetV2B1_H5_Model/EfficientNetV2B1_FT_MCPBest.h5
# 132/132 [==============================] - 132s 998ms/step - loss: 0.0664 - accuracy: 0.9824 - Precision: 0.9830 - Recall: 0.9800 - AUC: 0.9979 - val_loss: 0.0368 - val_accuracy: 0.9900 - val_Precision: 0.9900 - val_Recall: 0.9900 - val_AUC: 0.9990 - lr: 1.0000e-05
# Epoch 6/15
# 132/132 [==============================] - ETA: 0s - loss: 0.0533 - accuracy: 0.9855 - Precision: 0.9866 - Recall: 0.9843 - AUC: 0.9988
# Epoch 6: val_loss did not improve from 0.03677
# 132/132 [==============================] - 127s 961ms/step - loss: 0.0533 - accuracy: 0.9855 - Precision: 0.9866 - Recall: 0.9843 - AUC: 0.9988 - val_loss: 0.0382 - val_accuracy: 0.9908 - val_Precision: 0.9908 - val_Recall: 0.9908 - val_AUC: 0.9989 - lr: 1.0000e-05
# Epoch 7/15
# 132/132 [==============================] - ETA: 0s - loss: 0.0501 - accuracy: 0.9869 - Precision: 0.9885 - Recall: 0.9860 - AUC: 0.9986
# Epoch 7: val_loss improved from 0.03677 to 0.03613, saving model to /content/drive/MyDrive/Colab Notebooks/EfficientNetV2B1_H5_Model/EfficientNetV2B1_FT_MCPBest.h5
# 132/132 [==============================] - 131s 994ms/step - loss: 0.0501 - accuracy: 0.9869 - Precision: 0.9885 - Recall: 0.9860 - AUC: 0.9986 - val_loss: 0.0361 - val_accuracy: 0.9908 - val_Precision: 0.9908 - val_Recall: 0.9908 - val_AUC: 0.9990 - lr: 1.0000e-05
# Epoch 8/15
# 132/132 [==============================] - ETA: 0s - loss: 0.0440 - accuracy: 0.9888 - Precision: 0.9893 - Recall: 0.9867 - AUC: 0.9992
# Epoch 8: val_loss did not improve from 0.03613
# 132/132 [==============================] - 127s 960ms/step - loss: 0.0440 - accuracy: 0.9888 - Precision: 0.9893 - Recall: 0.9867 - AUC: 0.9992 - val_loss: 0.0367 - val_accuracy: 0.9908 - val_Precision: 0.9908 - val_Recall: 0.9908 - val_AUC: 0.9990 - lr: 1.0000e-05
# Epoch 9/15
# 132/132 [==============================] - ETA: 0s - loss: 0.0487 - accuracy: 0.9883 - Precision: 0.9890 - Recall: 0.9871 - AUC: 0.9988
# Epoch 9: val_loss improved from 0.03613 to 0.03582, saving model to /content/drive/MyDrive/Colab Notebooks/EfficientNetV2B1_H5_Model/EfficientNetV2B1_FT_MCPBest.h5
# 132/132 [==============================] - 130s 984ms/step - loss: 0.0487 - accuracy: 0.9883 - Precision: 0.9890 - Recall: 0.9871 - AUC: 0.9988 - val_loss: 0.0358 - val_accuracy: 0.9908 - val_Precision: 0.9908 - val_Recall: 0.9908 - val_AUC: 0.9990 - lr: 1.0000e-05
# Epoch 10/15
# 132/132 [==============================] - ETA: 0s - loss: 0.0510 - accuracy: 0.9862 - Precision: 0.9866 - Recall: 0.9848 - AUC: 0.9989
# Epoch 10: val_loss improved from 0.03582 to 0.03534, saving model to /content/drive/MyDrive/Colab Notebooks/EfficientNetV2B1_H5_Model/EfficientNetV2B1_FT_MCPBest.h5
# 132/132 [==============================] - 133s 1s/step - loss: 0.0510 - accuracy: 0.9862 - Precision: 0.9866 - Recall: 0.9848 - AUC: 0.9989 - val_loss: 0.0353 - val_accuracy: 0.9917 - val_Precision: 0.9925 - val_Recall: 0.9917 - val_AUC: 0.9990 - lr: 1.0000e-05
# Epoch 11/15
# 132/132 [==============================] - ETA: 0s - loss: 0.0481 - accuracy: 0.9879 - Precision: 0.9893 - Recall: 0.9871 - AUC: 0.9992
# Epoch 11: val_loss did not improve from 0.03534
# 132/132 [==============================] - 128s 966ms/step - loss: 0.0481 - accuracy: 0.9879 - Precision: 0.9893 - Recall: 0.9871 - AUC: 0.9992 - val_loss: 0.0361 - val_accuracy: 0.9917 - val_Precision: 0.9917 - val_Recall: 0.9917 - val_AUC: 0.9990 - lr: 1.0000e-05
# Epoch 12/15
# 132/132 [==============================] - ETA: 0s - loss: 0.0528 - accuracy: 0.9871 - Precision: 0.9876 - Recall: 0.9852 - AUC: 0.9987
# Epoch 12: val_loss did not improve from 0.03534
# 132/132 [==============================] - 128s 972ms/step - loss: 0.0528 - accuracy: 0.9871 - Precision: 0.9876 - Recall: 0.9852 - AUC: 0.9987 - val_loss: 0.0360 - val_accuracy: 0.9917 - val_Precision: 0.9917 - val_Recall: 0.9908 - val_AUC: 0.9990 - lr: 1.0000e-05
# Epoch 13/15
# 132/132 [==============================] - ETA: 0s - loss: 0.0458 - accuracy: 0.9876 - Precision: 0.9883 - Recall: 0.9869 - AUC: 0.9992
# Epoch 13: val_loss improved from 0.03534 to 0.03413, saving model to /content/drive/MyDrive/Colab Notebooks/EfficientNetV2B1_H5_Model/EfficientNetV2B1_FT_MCPBest.h5
# 132/132 [==============================] - 130s 981ms/step - loss: 0.0458 - accuracy: 0.9876 - Precision: 0.9883 - Recall: 0.9869 - AUC: 0.9992 - val_loss: 0.0341 - val_accuracy: 0.9908 - val_Precision: 0.9908 - val_Recall: 0.9908 - val_AUC: 0.9991 - lr: 1.0000e-05
# Epoch 14/15
# 132/132 [==============================] - ETA: 0s - loss: 0.0503 - accuracy: 0.9874 - Precision: 0.9895 - Recall: 0.9869 - AUC: 0.9988
# Epoch 14: val_loss did not improve from 0.03413
# 132/132 [==============================] - 129s 974ms/step - loss: 0.0503 - accuracy: 0.9874 - Precision: 0.9895 - Recall: 0.9869 - AUC: 0.9988 - val_loss: 0.0346 - val_accuracy: 0.9908 - val_Precision: 0.9908 - val_Recall: 0.9908 - val_AUC: 0.9991 - lr: 1.0000e-05
# Epoch 15/15
# 132/132 [==============================] - ETA: 0s - loss: 0.0419 - accuracy: 0.9888 - Precision: 0.9893 - Recall: 0.9879 - AUC: 0.9995
# Epoch 15: val_loss did not improve from 0.03413
# 132/132 [==============================] - 127s 960ms/step - loss: 0.0419 - accuracy: 0.9888 - Precision: 0.9893 - Recall: 0.9879 - AUC: 0.9995 - val_loss: 0.0350 - val_accuracy: 0.9917 - val_Precision: 0.9925 - val_Recall: 0.9917 - val_AUC: 0.9990 - lr: 1.0000e-05

# %% [markdown]
# ### II.4.4. Evaluation Fine Tune Model

# %%
# Evaluate the model on the Test Dataset using `evaluate`
print("Evaluate on Test Data")
results = model.evaluate(test_generator, batch_size = batch_size)
# Out:
# Evaluate on Test Data
# 19/19 [==============================] - 6s 304ms/step - loss: 0.0412 - accuracy: 0.9833 - Precision: 0.9850 - Recall: 0.9833 - AUC: 0.9997

# %%
# Plot the Loss graph
plt.plot(ft_history.history["loss"])
plt.plot(ft_history.history["val_loss"])
plt.title("Model Loss")
plt.ylabel("loss")
plt.xlabel("epoch")
plt.legend(["Train", "Val"], loc = "upper left")
plt.show()

# %%
# Plot the Accuracy graph
plt.plot(ft_history.history["accuracy"])
plt.plot(ft_history.history["val_accuracy"])
plt.title("Model Accuracy")
plt.ylabel("Accuracy")
plt.xlabel("Epoch")
plt.legend(["Train", "Val"], loc = "lower left")
plt.show()

# %% [markdown]
# ### II.4.5. Fine Tuned Model : Confusion Matrix

# %%
# Predict the values from the validation dataset
Y_pred = model.predict(test_generator, steps = test_generator.samples // batch_size + 1)

# Convert predictions classes from one hot vectors
Y_pred_classes = np.argmax(Y_pred, axis = 1)

# Convert validation observations from one hot vectors
# Y_true = np.argmax(test_generator.classes, axis = 1)
# OR
Y_true = test_generator.classes

# Compute the confusion matrix
cm = confusion_matrix(Y_true, Y_pred_classes)

# Print the confusion matrix
print("Confusion Matrix")
print(cm)

# Retrieve class names (label)
names_from_dir = sorted(os.listdir(val_dir))
dict(enumerate(names_from_dir))
#OR
class_names = list(val_generator.class_indices.keys())
# Check if the both are similar
print(names_from_dir == class_names)

# Print the classification report
print("Classification Report")
print(classification_report(Y_true, Y_pred_classes, target_names = class_names, digits = 4))
# Out:
# 19/19 [==============================] - 4s 239ms/step
# Confusion Matrix
# [[199   1   0]
#  [  2 198   0]
#  [  3   4 193]]
# True
# Classification Report
#               precision    recall  f1-score   support
#
#          Bee     0.9755    0.9950    0.9851       200
#    Butterfly     0.9754    0.9900    0.9826       200
#      Ladybug     1.0000    0.9650    0.9822       200
#
#     accuracy                         0.9833       600
#    macro avg     0.9836    0.9833    0.9833       600
# weighted avg     0.9836    0.9833    0.9833       600

# %% [markdown]
# ### II.4.5. Fine Tuned Model : Confusion Matrix Graph

# %%
plot_confusion_matrix(cm,
                      class_names,
                      normalize = True,
                      title = "Confusion matrix",
                      cmap = plt.cm.Blues
                      )
# Out:
# Normalized confusion matrix
# [[0.995 0.005 0.   ]
#  [0.01  0.99  0.   ]
#  [0.015 0.02  0.965]]

# %% [markdown]
# ### II.4.6. Some metrics of Fine Tune Model
# ```py
# Normalement pas besoin car keras.metrics nous donne les infos avec le `results = model.evaluate(test_generator, batch_size = batch_size)`. (average = "macro" par défaut)
# ```

# %%
from sklearn.metrics import precision_score, recall_score, f1_score

# Calcul de la précision
precision = precision_score(test_generator.classes, Y_pred_classes, average='macro') # average macro, calcul individuel par classe attribut le même poids à chaque classe
# Calcul du recall
recall = recall_score(test_generator.classes, Y_pred_classes, average='macro')

# Calcul du F1 score
f1 = f1_score(test_generator.classes, Y_pred_classes, average='macro')

# Affichage des résultats
print("Précision :", precision)
print("Recall :", recall)
print("F1 score :", f1)
# Out:
# Précision : 0.9836198847355034
# Recall : 0.9833333333333333
# F1 score : 0.9833223609899111

# %%
# Calcul de la précision
precision = precision_score(test_generator.classes, Y_pred_classes, average='weighted')
# average Weighted, calcul individuel par classe pour pondéré en fonction du poids de chaque classe

# Calcul du recall
recall = recall_score(test_generator.classes, Y_pred_classes, average='weighted')

# Calcul du F1 score
f1 = f1_score(test_generator.classes, Y_pred_classes, average='weighted')

# Affichage des résultats
print("Précision :", precision)
print("Recall :", recall)
print("F1 score :", f1)
# Out:
# Précision : 0.9836198847355033
# Recall : 0.9833333333333333
# F1 score : 0.9833223609899111

# %%
precision = precision_score(test_generator.classes, Y_pred_classes, average='micro')
# average micro, Calcule la précision globale en agrégeant les vrais positifs, faux positifs et faux négatifs sur toutes les classes

# Calcul du recall
recall = recall_score(test_generator.classes, Y_pred_classes, average='micro')

# Calcul du F1 score
f1 = f1_score(test_generator.classes, Y_pred_classes, average='micro')

# Affichage des résultats
print("Précision :", precision)
print("Recall :", recall)
print("F1 score :", f1)
# Out:
# Précision : 0.9833333333333333
# Recall : 0.9833333333333333
# F1 score : 0.9833333333333333

# %% [markdown]
# # III. READ LOGS

# %% [markdown]
# ## III.1. TRAIN

# %%
# %load_ext tensorboard
# %tensorboard --logdir log_dir

# %% [markdown]
# ## III.2. FINE TUNE

# %%
# %load_ext tensorboard
# %tensorboard --logdir ft_log_dir
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard
# ERROR: Failed to launch TensorBoard (exited with 1).
# Contents of stderr:
# 2023-09-27 10:48:47.772896: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-09-27 10:48:47.772980: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-09-27 10:48:47.773010: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-09-27 10:48:48.773332: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
#
# NOTE: Using experimental fast data loading logic. To disable, pass
#     "--load_fast=false" and report issues on GitHub. More details:
#     https://github.com/tensorflow/tensorboard/issues/4784
#
# Address already in use
# Port 6006 is in use by another program. Either identify and stop that program, or start the server with a different port.
