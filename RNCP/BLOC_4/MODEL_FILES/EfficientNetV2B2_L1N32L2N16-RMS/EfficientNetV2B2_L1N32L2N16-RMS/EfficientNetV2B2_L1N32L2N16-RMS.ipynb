# %% [markdown]
# ## I.1. Install

# %%
# # # GOOGLE Colab ONLY : Mount GOOGLE Drive
# from google.colab import drive
# drive.mount("/content/drive")

# %%
import os
# GOOGLE Colab ONLY : Get & store the default work path
user_path = os.path.join(os.getcwd(), "drive", "MyDrive", "Colab Notebooks")

# LOCAL : Get & store the current working path
# user_path = os.path.dirname(os.path.abspath("NoNeedFilename"))

print(user_path)
# Out:
# /content/drive/MyDrive/Colab Notebooks

# %%
# requirements_filepath = os.path.join(user_path, "requirements.txt")
# !pip install -r {requirements_filepath}

# %% [markdown]
# ## I.2. Libraries Import

# %%
import numpy as np
import matplotlib.pyplot as plt

# Machine Learning
# import keras
from keras.models import Model
from keras.preprocessing.image import ImageDataGenerator
from keras.layers import Dense, Dropout, GlobalAveragePooling2D, BatchNormalization
from keras.optimizers import Adam, Nadam, SGD, RMSprop
from sklearn.metrics import confusion_matrix, classification_report, f1_score

from keras.applications import EfficientNetB1, EfficientNetB2, EfficientNetB3, EfficientNetV2B1, EfficientNetV2B2, EfficientNetV2B3

# %% [markdown]
# ## I.4. Image Processing

# %% [markdown]
# ### I.4.2. Set Image Folder Path

# %%
# GOOGLE Colab ONLY
train_dir = os.path.join(user_path, "IMAGE_SPLIT", "train")
val_dir = os.path.join(user_path, "IMAGE_SPLIT", "val")
test_dir = os.path.join(user_path, "IMAGE_SPLIT", "test")

# LOCAL
# train_dir = r"C:\WORKSPACES\DATA\ML_DL\IMAGE_SPLIT\train"
# val_dir = r"C:\WORKSPACES\DATA\ML_DL\IMAGE_SPLIT\val"
# test_dir = r"C:\WORKSPACES\DATA\ML_DL\IMAGE_SPLIT\test"

# %% [markdown]
# ### I.4.3. Data augmentation techniques

# %%
train_datagen = ImageDataGenerator(
    rescale = 1./255,
    shear_range = 0.2,
    rotation_range = 20,
    width_shift_range = 0.1,
    height_shift_range = 0.1,
    zoom_range = [0.9, 1.25],
    brightness_range = [0.5, 1.5],
    horizontal_flip = True,
    vertical_flip = True
)

val_datagen = ImageDataGenerator(
    rescale = 1./255)

test_datagen = ImageDataGenerator(
    rescale = 1./255)

# %% [markdown]
# ### I.4.4. Setup Data generators

# %%
# Variables
batch_size = 32
height = 240
width = 240
image_shape = (height, width) # images of size 240x240 px with 3 color channels RGB automatically

train_generator = train_datagen.flow_from_directory(
    train_dir,
    class_mode = "categorical",
    target_size = image_shape,
    batch_size = batch_size
)

val_generator = val_datagen.flow_from_directory(
    val_dir,
    class_mode = "categorical",
    target_size = image_shape,
    batch_size = batch_size
)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    class_mode = "categorical",
    target_size = image_shape,
    batch_size = batch_size,
    shuffle = False
)
# Out:
# Found 4200 images belonging to 3 classes.
# Found 1200 images belonging to 3 classes.
# Found 600 images belonging to 3 classes.

# %% [markdown]
# ## II.1. Define variables and parameters

# %%
from keras.metrics import Precision, Recall, AUC

# Model to use for transfer learning
model_name = "EfficientNetV2B2"
ModelNameFunc = globals()[model_name]

# Work path
folder_name = f"{model_name}_L1N32L2N16-RMS"
work_path = os.path.join(user_path, folder_name)

# Top Architecture for the new model
l1_neurons = 32                 # Number of neurons on layer 1 (deeper)
l1_activation = "relu"
dropout = 0.4                   # 0.2 - 0.5
l2_neurons = 16                 # Number of neurons on layer 2
l2_activation = "relu"
output_neurons = 3              # This layer will have 3 neurons or units fully connected. In line with our 3 classes.
output_activation = "softmax"

# Metrics (parameter average = "macro" by default )
precision = Precision(name = "Precision")
recall = Recall(name = "Recall")
# f1 = (2 * (precision * recall) / (precision + recall))
# auc = AUC(name = "AUC")

# TRAIN : model.compile
compile_optimizer = "RMSprop"                  # Test : Nadam, RMSprop, SGD
compile_loss = "categorical_crossentropy"   # More than 2 classes, so categorical
compile_metrics = ["accuracy", precision, recall]

# TRAIN : model.fit
epochs = 30
verbose = 1

# FINE TUNE : model.compile
ft_compile_optimizer = RMSprop(learning_rate = 1e-5)
# ft_compile_optimizer : Very low learning rate. Test : Nadam, RMSprop, SGD
ft_compile_loss = "categorical_crossentropy"
ft_compile_metrics = ["accuracy", precision, recall]

# FINE TUNE : model.fit
ft_epochs = 15
ft_verbose = 1

# SAVE : File Path .h5
fileh5_path = os.path.join(work_path, f"{folder_name}_H5_Model", f"{folder_name}_TRAIN_ManualSave.h5")
ft_fileh5_path = os.path.join(work_path, f"{folder_name}_H5_Model", f"{folder_name}_FT_ManualSave.h5")

# %% [markdown]
# ## II.2. Define optimizations

# %% [markdown]
# ### II.2.1. Train optimizations (callbacks)

# %%
from keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint, TensorBoard, CSVLogger

# Define the early stopping
early_stopping = EarlyStopping(
    monitor = "val_loss",        # Metric to monitor
    patience = 5,                # Number of epochs with no improvement  (around 10% of nb of epochs)
    verbose = 1,                 # Verbosity mode (0, 1, or 2)
    restore_best_weights = True  # Whether to restore model weights to the best epoch
)

# Define the learning rate scheduler
lr_scheduler = ReduceLROnPlateau(
    monitor = "val_loss",       # Metric to monitor
    factor = 0.2,               # Factor by which to reduce the learning rate
    patience = 5,               # Number of epochs with no improvement (default = 10)
    verbose = 1,                # Verbosity mode (0, 1, or 2)
    min_lr = 1e-6               # Minimum learning rate
)

# Define the model checkpoint callback
checkpoint = ModelCheckpoint(
    # filepath = os.path.join(work_path, f"{model_name}_TRAIN_CheckPoint"), # to use if don't wanna save to a .h5 or .keras file
    filepath = os.path.join(work_path, f"{folder_name}_H5_Model", f"{folder_name}_TRAIN_MCPBest.h5"),
    monitor = "val_loss",       # Metric to monitor
    save_freq = "epoch",        # Default = epoch
    save_weights_only = False,  # Default = False
    save_best_only = True,      # Save only if the monitored metric improves
    mode = "min",               # "min" if monitoring loss, "max" if monitoring accuracy
    verbose = 1                 # Verbosity mode (0, 1, or 2)
)

# Define TensorBoard Logs
log_dir = os.path.join(work_path, f"{folder_name}_LOGS_TRAIN")
tensorboard = TensorBoard(
    log_dir = log_dir,
    write_graph = True,
    write_images = True,
    update_freq = "epoch"
)

# Define CSVLogger
CSV_Log_filename = os.path.join(work_path, f"{folder_name}_TRAIN.log")
CSV_Logger = CSVLogger(
    CSV_Log_filename,
    separator = "|",
    append = False
)

# Define the callbacks list
callbacks_list = [early_stopping, lr_scheduler, checkpoint, tensorboard, CSV_Logger]

# %% [markdown]
# ### II.2.2. Fine Tune Optimization

# %%
# Define the FT Early stopping
ft_early_stopping = EarlyStopping(
    monitor = "val_loss",
    patience = 3,
    verbose = 1,                 # Verbosity mode (0, 1, or 2)
    restore_best_weights = True  # Whether to restore model weights to the best epoch
)

# Define the FT Learning rate scheduler
ft_lr_scheduler = ReduceLROnPlateau(
    monitor = "val_loss",  # Metric to monitor
    factor = 0.2,          # Factor by which to reduce the learning rate
    patience = 3,          # Number of epochs with no improvement (default = 10)
    verbose = 1,           # Verbosity mode (0, 1, or 2)
    min_lr = 1e-6          # Minimum learning rate
)

# Define the FT checkpoint callback
ft_checkpoint = ModelCheckpoint(
    # filepath = os.path.join(work_path, f"{model_name}_FT_CheckPoint"), # to use if don't wanna save to a .h5 or .keras file
    filepath = os.path.join(work_path, f"{folder_name}_H5_Model", f"{folder_name}_FT_MCPBest.h5"),
    monitor = "val_loss",       # Metric to monitor
    save_freq = "epoch",        # Default = epoch
    save_weights_only = False,  # Default = False
    save_best_only = True,      # Save only if the monitored metric improves
    mode = "min",               # "min" if monitoring loss, "max" if monitoring accuracy
    verbose = 1                 # Verbosity mode (0, 1, or 2)
)

# Define the FT TensorBoard Logs
ft_log_dir = os.path.join(work_path, f"{folder_name}_LOGS_FT")
ft_tensorboard = TensorBoard(
    log_dir = ft_log_dir,
    write_graph=True,
    write_images=True,
    update_freq = "epoch"
)

# Define the FT CSVLogger
ft_CSV_Log_filename = os.path.join(work_path, f"{folder_name}_FT.log")
ft_CSV_Logger = CSVLogger(
    ft_CSV_Log_filename,
    separator = "|",
    append = False
)

# Define the FT callbacks list
ft_callbacks_list = [ft_early_stopping, ft_lr_scheduler, ft_checkpoint, ft_tensorboard, ft_CSV_Logger]

# %% [markdown]
# ## II.3. Pre train the model

# %% [markdown]
# ### II.3.1. Instantiate a base model with pre-trained model and weights

# %%
# First instantiate a base model with pre-trained weights
base_model = ModelNameFunc(
    include_top = False,
    weights = "imagenet",
    include_preprocessing = False, # ONLY for V2 model, otherwise put it as comment.
    input_shape = (height, width, output_neurons)
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/efficientnet_v2/efficientnetv2-b2_notop.h5
# 35839040/35839040 [==============================] - 0s 0us/step

# %%
display(base_model.input)
# Out:
# <KerasTensor: shape=(None, 240, 240, 3) dtype=float32 (created by layer 'input_1')>

# %% [markdown]
# ### II.3.2. Define the new architecture on top

# %%
x = base_model.output
x = GlobalAveragePooling2D()(x) # Pooling
x = Dense(l1_neurons, activation = l1_activation)(x)
x = Dropout(dropout)(x)
x = Dense(l2_neurons, activation = l2_activation)(x)
x = BatchNormalization()(x)

predictions = Dense(output_neurons, activation = output_activation)(x)

model = Model(inputs = base_model.input, outputs = predictions)

# %%
print(model.input_shape)
# Out:
# (None, 240, 240, 3)

# %% [markdown]
# ### II.3.4. Compile the model

# %%
model.compile(
    optimizer = compile_optimizer,
    loss = compile_loss,
    metrics = compile_metrics
)

# %% [markdown]
# ### II.3.5. Train the model
# It's called "history" because it essentially keeps a historical record of various metrics and data related to how the model performed during training.

# %%
history = model.fit(
    x = train_generator,
    steps_per_epoch = train_generator.samples // batch_size + 1,
    validation_data = val_generator,
    validation_steps = val_generator.samples // batch_size + 1,
    epochs = epochs,
    verbose = verbose,
    callbacks = callbacks_list
)

# Save the model
model.save(fileh5_path)
# Out:
# Epoch 1/30
# 132/132 [==============================] - ETA: 0s - loss: 0.3484 - accuracy: 0.8933 - Precision: 0.9215 - Recall: 0.8550
# Epoch 1: val_loss improved from inf to 0.19906, saving model to /content/drive/MyDrive/Colab Notebooks/EfficientNetV2B2_L1N32L2N16-RMS/EfficientNetV2B2_L1N32L2N16-RMS_H5_Model/EfficientNetV2B2_L1N32L2N16-RMS_TRAIN_MCPBest.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 132/132 [==============================] - 1717s 13s/step - loss: 0.3484 - accuracy: 0.8933 - Precision: 0.9215 - Recall: 0.8550 - val_loss: 0.1991 - val_accuracy: 0.9325 - val_Precision: 0.9363 - val_Recall: 0.9308 - lr: 0.0010
# Epoch 2/30
# 132/132 [==============================] - ETA: 0s - loss: 0.2219 - accuracy: 0.9321 - Precision: 0.9403 - Recall: 0.9221
# Epoch 2: val_loss improved from 0.19906 to 0.09891, saving model to /content/drive/MyDrive/Colab Notebooks/EfficientNetV2B2_L1N32L2N16-RMS/EfficientNetV2B2_L1N32L2N16-RMS_H5_Model/EfficientNetV2B2_L1N32L2N16-RMS_TRAIN_MCPBest.h5
# 132/132 [==============================] - 130s 983ms/step - loss: 0.2219 - accuracy: 0.9321 - Precision: 0.9403 - Recall: 0.9221 - val_loss: 0.0989 - val_accuracy: 0.9683 - val_Precision: 0.9722 - val_Recall: 0.9617 - lr: 0.0010
# Epoch 3/30
# 132/132 [==============================] - ETA: 0s - loss: 0.1798 - accuracy: 0.9483 - Precision: 0.9553 - Recall: 0.9414
# Epoch 3: val_loss did not improve from 0.09891
# 132/132 [==============================] - 130s 981ms/step - loss: 0.1798 - accuracy: 0.9483 - Precision: 0.9553 - Recall: 0.9414 - val_loss: 0.1603 - val_accuracy: 0.9492 - val_Precision: 0.9498 - val_Recall: 0.9467 - lr: 0.0010
# Epoch 4/30
# 132/132 [==============================] - ETA: 0s - loss: 0.1603 - accuracy: 0.9529 - Precision: 0.9573 - Recall: 0.9450
# Epoch 4: val_loss improved from 0.09891 to 0.08129, saving model to /content/drive/MyDrive/Colab Notebooks/EfficientNetV2B2_L1N32L2N16-RMS/EfficientNetV2B2_L1N32L2N16-RMS_H5_Model/EfficientNetV2B2_L1N32L2N16-RMS_TRAIN_MCPBest.h5
# 132/132 [==============================] - 131s 990ms/step - loss: 0.1603 - accuracy: 0.9529 - Precision: 0.9573 - Recall: 0.9450 - val_loss: 0.0813 - val_accuracy: 0.9733 - val_Precision: 0.9765 - val_Recall: 0.9717 - lr: 0.0010
# Epoch 5/30
# 132/132 [==============================] - ETA: 0s - loss: 0.1414 - accuracy: 0.9598 - Precision: 0.9635 - Recall: 0.9543
# Epoch 5: val_loss did not improve from 0.08129
# 132/132 [==============================] - 127s 960ms/step - loss: 0.1414 - accuracy: 0.9598 - Precision: 0.9635 - Recall: 0.9543 - val_loss: 0.1455 - val_accuracy: 0.9533 - val_Precision: 0.9556 - val_Recall: 0.9508 - lr: 0.0010
# Epoch 6/30
# 132/132 [==============================] - ETA: 0s - loss: 0.1304 - accuracy: 0.9607 - Precision: 0.9633 - Recall: 0.9550
# Epoch 6: val_loss did not improve from 0.08129
# 132/132 [==============================] - 130s 983ms/step - loss: 0.1304 - accuracy: 0.9607 - Precision: 0.9633 - Recall: 0.9550 - val_loss: 0.2097 - val_accuracy: 0.9350 - val_Precision: 0.9387 - val_Recall: 0.9317 - lr: 0.0010
# Epoch 7/30
# 132/132 [==============================] - ETA: 0s - loss: 0.1115 - accuracy: 0.9657 - Precision: 0.9696 - Recall: 0.9631
# Epoch 7: val_loss did not improve from 0.08129
# 132/132 [==============================] - 128s 968ms/step - loss: 0.1115 - accuracy: 0.9657 - Precision: 0.9696 - Recall: 0.9631 - val_loss: 0.0848 - val_accuracy: 0.9733 - val_Precision: 0.9758 - val_Recall: 0.9725 - lr: 0.0010
# Epoch 8/30
# 132/132 [==============================] - ETA: 0s - loss: 0.1059 - accuracy: 0.9667 - Precision: 0.9691 - Recall: 0.9643
# Epoch 8: val_loss did not improve from 0.08129
# 132/132 [==============================] - 126s 954ms/step - loss: 0.1059 - accuracy: 0.9667 - Precision: 0.9691 - Recall: 0.9643 - val_loss: 0.1202 - val_accuracy: 0.9583 - val_Precision: 0.9615 - val_Recall: 0.9583 - lr: 0.0010
# Epoch 9/30
# 132/132 [==============================] - ETA: 0s - loss: 0.0988 - accuracy: 0.9740 - Precision: 0.9751 - Recall: 0.9712
# Epoch 9: val_loss improved from 0.08129 to 0.04773, saving model to /content/drive/MyDrive/Colab Notebooks/EfficientNetV2B2_L1N32L2N16-RMS/EfficientNetV2B2_L1N32L2N16-RMS_H5_Model/EfficientNetV2B2_L1N32L2N16-RMS_TRAIN_MCPBest.h5
# 132/132 [==============================] - 131s 988ms/step - loss: 0.0988 - accuracy: 0.9740 - Precision: 0.9751 - Recall: 0.9712 - val_loss: 0.0477 - val_accuracy: 0.9825 - val_Precision: 0.9833 - val_Recall: 0.9817 - lr: 0.0010
# Epoch 10/30
# 132/132 [==============================] - ETA: 0s - loss: 0.0933 - accuracy: 0.9738 - Precision: 0.9756 - Recall: 0.9717
# Epoch 10: val_loss did not improve from 0.04773
# 132/132 [==============================] - 126s 954ms/step - loss: 0.0933 - accuracy: 0.9738 - Precision: 0.9756 - Recall: 0.9717 - val_loss: 0.2037 - val_accuracy: 0.9342 - val_Precision: 0.9356 - val_Recall: 0.9325 - lr: 0.0010
# Epoch 11/30
# 132/132 [==============================] - ETA: 0s - loss: 0.0966 - accuracy: 0.9712 - Precision: 0.9741 - Recall: 0.9681
# Epoch 11: val_loss did not improve from 0.04773
# 132/132 [==============================] - 127s 964ms/step - loss: 0.0966 - accuracy: 0.9712 - Precision: 0.9741 - Recall: 0.9681 - val_loss: 0.0637 - val_accuracy: 0.9775 - val_Precision: 0.9775 - val_Recall: 0.9767 - lr: 0.0010
# Epoch 12/30
# 132/132 [==============================] - ETA: 0s - loss: 0.0830 - accuracy: 0.9750 - Precision: 0.9759 - Recall: 0.9729
# Epoch 12: val_loss improved from 0.04773 to 0.04636, saving model to /content/drive/MyDrive/Colab Notebooks/EfficientNetV2B2_L1N32L2N16-RMS/EfficientNetV2B2_L1N32L2N16-RMS_H5_Model/EfficientNetV2B2_L1N32L2N16-RMS_TRAIN_MCPBest.h5
# 132/132 [==============================] - 130s 988ms/step - loss: 0.0830 - accuracy: 0.9750 - Precision: 0.9759 - Recall: 0.9729 - val_loss: 0.0464 - val_accuracy: 0.9850 - val_Precision: 0.9866 - val_Recall: 0.9850 - lr: 0.0010
# Epoch 13/30
# 132/132 [==============================] - ETA: 0s - loss: 0.0713 - accuracy: 0.9812 - Precision: 0.9816 - Recall: 0.9793
# Epoch 13: val_loss improved from 0.04636 to 0.04458, saving model to /content/drive/MyDrive/Colab Notebooks/EfficientNetV2B2_L1N32L2N16-RMS/EfficientNetV2B2_L1N32L2N16-RMS_H5_Model/EfficientNetV2B2_L1N32L2N16-RMS_TRAIN_MCPBest.h5
# 132/132 [==============================] - 128s 972ms/step - loss: 0.0713 - accuracy: 0.9812 - Precision: 0.9816 - Recall: 0.9793 - val_loss: 0.0446 - val_accuracy: 0.9850 - val_Precision: 0.9850 - val_Recall: 0.9850 - lr: 0.0010
# Epoch 14/30
# 132/132 [==============================] - ETA: 0s - loss: 0.0842 - accuracy: 0.9738 - Precision: 0.9749 - Recall: 0.9724
# Epoch 14: val_loss did not improve from 0.04458
# 132/132 [==============================] - 128s 970ms/step - loss: 0.0842 - accuracy: 0.9738 - Precision: 0.9749 - Recall: 0.9724 - val_loss: 0.0515 - val_accuracy: 0.9850 - val_Precision: 0.9850 - val_Recall: 0.9850 - lr: 0.0010
# Epoch 15/30
# 132/132 [==============================] - ETA: 0s - loss: 0.0659 - accuracy: 0.9798 - Precision: 0.9807 - Recall: 0.9781
# Epoch 15: val_loss did not improve from 0.04458
# 132/132 [==============================] - 137s 1s/step - loss: 0.0659 - accuracy: 0.9798 - Precision: 0.9807 - Recall: 0.9781 - val_loss: 0.1013 - val_accuracy: 0.9725 - val_Precision: 0.9733 - val_Recall: 0.9725 - lr: 0.0010
# Epoch 16/30
# 132/132 [==============================] - ETA: 0s - loss: 0.0735 - accuracy: 0.9783 - Precision: 0.9797 - Recall: 0.9767
# Epoch 16: val_loss did not improve from 0.04458
# 132/132 [==============================] - 125s 947ms/step - loss: 0.0735 - accuracy: 0.9783 - Precision: 0.9797 - Recall: 0.9767 - val_loss: 0.0570 - val_accuracy: 0.9817 - val_Precision: 0.9817 - val_Recall: 0.9808 - lr: 0.0010
# Epoch 17/30
# 132/132 [==============================] - ETA: 0s - loss: 0.0739 - accuracy: 0.9776 - Precision: 0.9790 - Recall: 0.9764
# Epoch 17: val_loss did not improve from 0.04458
# 132/132 [==============================] - 127s 963ms/step - loss: 0.0739 - accuracy: 0.9776 - Precision: 0.9790 - Recall: 0.9764 - val_loss: 0.0829 - val_accuracy: 0.9800 - val_Precision: 0.9808 - val_Recall: 0.9800 - lr: 0.0010
# Epoch 18/30
# 132/132 [==============================] - ETA: 0s - loss: 0.0723 - accuracy: 0.9802 - Precision: 0.9809 - Recall: 0.9790Restoring model weights from the end of the best epoch: 13.
#
# Epoch 18: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
#
# Epoch 18: val_loss did not improve from 0.04458
# 132/132 [==============================] - 127s 959ms/step - loss: 0.0723 - accuracy: 0.9802 - Precision: 0.9809 - Recall: 0.9790 - val_loss: 0.0633 - val_accuracy: 0.9775 - val_Precision: 0.9775 - val_Recall: 0.9758 - lr: 0.0010
# Epoch 18: early stopping

# %% [markdown]
# ### II.3.7. Evaluate Pre trained model

# %%
# Predict the values from the Test Dataset
Y_pred = model.predict(test_generator, steps = test_generator.samples // batch_size + 1)

# Convert predictions classes from one hot vectors
Y_pred_classes = np.argmax(Y_pred, axis = 1)
# Out:
# 19/19 [==============================] - 234s 13s/step

# %%
# Evaluate the model on the Test Dataset using `evaluate`
# f1 = F1Score(test_generator.classes, Y_pred_classes)
f1 = f1_score(test_generator.classes, Y_pred_classes, average = "macro")
print("F1 Score : ", f1)
print("Evaluate on Test Data")
results = model.evaluate(test_generator, batch_size = batch_size)
# Out:
# F1 Score :  0.978420690729068
# Evaluate on Test Data
# 19/19 [==============================] - 5s 250ms/step - loss: 0.0700 - accuracy: 0.9783 - Precision: 0.9783 - Recall: 0.9783

# %% [markdown]
# ### II.3.8. Plot the Accuracy and the loss graphs

# %%
# Plot the Loss graph
plt.plot(history.history["loss"])
plt.plot(history.history["val_loss"])
plt.title("Model Loss")
plt.ylabel("Loss")
plt.xlabel("Epoch")
plt.legend(["Train", "Val"], loc = "upper left")
plt.show()

# %%
# Plot the Accuracy graph
plt.plot(history.history["accuracy"])
plt.plot(history.history["val_accuracy"])
plt.title("Model Accuracy")
plt.ylabel("Accuracy")
plt.xlabel("Epoch")
plt.legend(["Train", "Val"], loc = "lower left")
plt.show()

# %% [markdown]
# ### II.3.8. Trained Model : Confusion Matrix

# %%
# # Predict the values from the Test Dataset
# Y_pred = model.predict(test_generator, steps = test_generator.samples // batch_size + 1)

# # Convert predictions classes from one hot vectors
# Y_pred_classes = np.argmax(Y_pred, axis = 1)

# Convert validation observations from one hot vectors
# Y_true = np.argmax(test_generator.classes, axis = 1)
# OR
Y_true = test_generator.classes

# Compute the confusion matrix
cm = confusion_matrix(Y_true, Y_pred_classes)

# Print the confusion matrix
print("Confusion Matrix")
print(cm)

# Retrieve class names (label)
names_from_dir = sorted(os.listdir(val_dir))
dict(enumerate(names_from_dir))
#OR
class_names = list(val_generator.class_indices.keys())
# Check if the both are similar
print(names_from_dir == class_names)

# Print the classification report
print("Classification Report")
print(classification_report(Y_true, Y_pred_classes, target_names = class_names, digits = 4))
# Out:
# Confusion Matrix
# [[196   4   0]
#  [  2 197   1]
#  [  0   6 194]]
# True
# Classification Report
#               precision    recall  f1-score   support
#
#          Bee     0.9899    0.9800    0.9849       200
#    Butterfly     0.9517    0.9850    0.9681       200
#      Ladybug     0.9949    0.9700    0.9823       200
#
#     accuracy                         0.9783       600
#    macro avg     0.9788    0.9783    0.9784       600
# weighted avg     0.9788    0.9783    0.9784       600

# %% [markdown]
# ### II.3.9. Confusion Matrix Function

# %%
def plot_confusion_matrix(
    cm,
    classes,
    normalize = False,
    title = "Confusion matrix",
    cmap = plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype("float") / cm.sum(axis =1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)
    plt.imshow(cm, interpolation = "nearest", cmap = cmap)
    plt.title(title)
    plt.colorbar()
    plt.tight_layout()
    plt.ylabel("True label")
    plt.xlabel("Predicted label")

# %% [markdown]
# ### II.3.10. Trained Model : Confusion Matrix Graph

# %%
plot_confusion_matrix(
    cm,
    class_names,
    normalize = True,
    title = "Confusion matrix",
    cmap = plt.cm.Blues
    )
# Out:
# Normalized confusion matrix
# [[0.98  0.02  0.   ]
#  [0.01  0.985 0.005]
#  [0.    0.03  0.97 ]]

# %% [markdown]
# ## II.4. Fine Tuning
# This requires unfreezing the base model and then recompiling the model (necessary for the changes to take effect), and then resuming training.

# %% [markdown]
# ### II.4.1. Unfreeze the base model

# %%
# Unfreeze the base model
base_model.trainable = True

# %% [markdown]
# ### II.4.2. Re compile the model with a very low learning rate

# %%
# It's important to recompile your model after you make any changes
# to the `trainable` attribute of any inner layer, so that your changes
# are take into account
model.compile(
    optimizer = ft_compile_optimizer,
    loss = ft_compile_loss,
    metrics = ft_compile_metrics
)

# %% [markdown]
# ### II.4.3. Retraining the model

# %%
# Resume training
ft_history = model.fit(
    x = train_generator,
    steps_per_epoch = train_generator.samples // batch_size + 1,
    validation_data = val_generator,
    validation_steps = val_generator.samples // batch_size + 1,
    epochs = ft_epochs,
    verbose = ft_verbose,
    callbacks = ft_callbacks_list
)

# Save the Fine tuned model
model.save(ft_fileh5_path)
# Out:
# Epoch 1/15
# 132/132 [==============================] - ETA: 0s - loss: 0.0584 - accuracy: 0.9829 - Precision: 0.9829 - Recall: 0.9808
# Epoch 1: val_loss improved from inf to 0.03877, saving model to /content/drive/MyDrive/Colab Notebooks/EfficientNetV2B2_L1N32L2N16-RMS/EfficientNetV2B2_L1N32L2N16-RMS_H5_Model/EfficientNetV2B2_L1N32L2N16-RMS_FT_MCPBest.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 132/132 [==============================] - 178s 981ms/step - loss: 0.0584 - accuracy: 0.9829 - Precision: 0.9829 - Recall: 0.9808 - val_loss: 0.0388 - val_accuracy: 0.9875 - val_Precision: 0.9883 - val_Recall: 0.9867 - lr: 1.0000e-05
# Epoch 2/15
# 132/132 [==============================] - ETA: 0s - loss: 0.0603 - accuracy: 0.9819 - Precision: 0.9833 - Recall: 0.9802
# Epoch 2: val_loss improved from 0.03877 to 0.03778, saving model to /content/drive/MyDrive/Colab Notebooks/EfficientNetV2B2_L1N32L2N16-RMS/EfficientNetV2B2_L1N32L2N16-RMS_H5_Model/EfficientNetV2B2_L1N32L2N16-RMS_FT_MCPBest.h5
# 132/132 [==============================] - 130s 981ms/step - loss: 0.0603 - accuracy: 0.9819 - Precision: 0.9833 - Recall: 0.9802 - val_loss: 0.0378 - val_accuracy: 0.9883 - val_Precision: 0.9900 - val_Recall: 0.9875 - lr: 1.0000e-05
# Epoch 3/15
# 132/132 [==============================] - ETA: 0s - loss: 0.0591 - accuracy: 0.9836 - Precision: 0.9849 - Recall: 0.9814
# Epoch 3: val_loss improved from 0.03778 to 0.03644, saving model to /content/drive/MyDrive/Colab Notebooks/EfficientNetV2B2_L1N32L2N16-RMS/EfficientNetV2B2_L1N32L2N16-RMS_H5_Model/EfficientNetV2B2_L1N32L2N16-RMS_FT_MCPBest.h5
# 132/132 [==============================] - 129s 977ms/step - loss: 0.0591 - accuracy: 0.9836 - Precision: 0.9849 - Recall: 0.9814 - val_loss: 0.0364 - val_accuracy: 0.9883 - val_Precision: 0.9900 - val_Recall: 0.9875 - lr: 1.0000e-05
# Epoch 4/15
# 132/132 [==============================] - ETA: 0s - loss: 0.0555 - accuracy: 0.9838 - Precision: 0.9861 - Recall: 0.9814
# Epoch 4: val_loss improved from 0.03644 to 0.03542, saving model to /content/drive/MyDrive/Colab Notebooks/EfficientNetV2B2_L1N32L2N16-RMS/EfficientNetV2B2_L1N32L2N16-RMS_H5_Model/EfficientNetV2B2_L1N32L2N16-RMS_FT_MCPBest.h5
# 132/132 [==============================] - 130s 984ms/step - loss: 0.0555 - accuracy: 0.9838 - Precision: 0.9861 - Recall: 0.9814 - val_loss: 0.0354 - val_accuracy: 0.9883 - val_Precision: 0.9892 - val_Recall: 0.9883 - lr: 1.0000e-05
# Epoch 5/15
# 132/132 [==============================] - ETA: 0s - loss: 0.0552 - accuracy: 0.9848 - Precision: 0.9866 - Recall: 0.9831
# Epoch 5: val_loss improved from 0.03542 to 0.03303, saving model to /content/drive/MyDrive/Colab Notebooks/EfficientNetV2B2_L1N32L2N16-RMS/EfficientNetV2B2_L1N32L2N16-RMS_H5_Model/EfficientNetV2B2_L1N32L2N16-RMS_FT_MCPBest.h5
# 132/132 [==============================] - 130s 988ms/step - loss: 0.0552 - accuracy: 0.9848 - Precision: 0.9866 - Recall: 0.9831 - val_loss: 0.0330 - val_accuracy: 0.9892 - val_Precision: 0.9900 - val_Recall: 0.9892 - lr: 1.0000e-05
# Epoch 6/15
# 132/132 [==============================] - ETA: 0s - loss: 0.0458 - accuracy: 0.9874 - Precision: 0.9890 - Recall: 0.9867
# Epoch 6: val_loss improved from 0.03303 to 0.03225, saving model to /content/drive/MyDrive/Colab Notebooks/EfficientNetV2B2_L1N32L2N16-RMS/EfficientNetV2B2_L1N32L2N16-RMS_H5_Model/EfficientNetV2B2_L1N32L2N16-RMS_FT_MCPBest.h5
# 132/132 [==============================] - 129s 973ms/step - loss: 0.0458 - accuracy: 0.9874 - Precision: 0.9890 - Recall: 0.9867 - val_loss: 0.0323 - val_accuracy: 0.9883 - val_Precision: 0.9892 - val_Recall: 0.9883 - lr: 1.0000e-05
# Epoch 7/15
# 132/132 [==============================] - ETA: 0s - loss: 0.0362 - accuracy: 0.9912 - Precision: 0.9926 - Recall: 0.9890
# Epoch 7: val_loss did not improve from 0.03225
# 132/132 [==============================] - 127s 962ms/step - loss: 0.0362 - accuracy: 0.9912 - Precision: 0.9926 - Recall: 0.9890 - val_loss: 0.0338 - val_accuracy: 0.9900 - val_Precision: 0.9917 - val_Recall: 0.9900 - lr: 1.0000e-05
# Epoch 8/15
# 132/132 [==============================] - ETA: 0s - loss: 0.0424 - accuracy: 0.9886 - Precision: 0.9904 - Recall: 0.9860
# Epoch 8: val_loss improved from 0.03225 to 0.03169, saving model to /content/drive/MyDrive/Colab Notebooks/EfficientNetV2B2_L1N32L2N16-RMS/EfficientNetV2B2_L1N32L2N16-RMS_H5_Model/EfficientNetV2B2_L1N32L2N16-RMS_FT_MCPBest.h5
# 132/132 [==============================] - 131s 990ms/step - loss: 0.0424 - accuracy: 0.9886 - Precision: 0.9904 - Recall: 0.9860 - val_loss: 0.0317 - val_accuracy: 0.9908 - val_Precision: 0.9917 - val_Recall: 0.9908 - lr: 1.0000e-05
# Epoch 9/15
# 132/132 [==============================] - ETA: 0s - loss: 0.0449 - accuracy: 0.9874 - Precision: 0.9888 - Recall: 0.9862
# Epoch 9: val_loss improved from 0.03169 to 0.03156, saving model to /content/drive/MyDrive/Colab Notebooks/EfficientNetV2B2_L1N32L2N16-RMS/EfficientNetV2B2_L1N32L2N16-RMS_H5_Model/EfficientNetV2B2_L1N32L2N16-RMS_FT_MCPBest.h5
# 132/132 [==============================] - 129s 980ms/step - loss: 0.0449 - accuracy: 0.9874 - Precision: 0.9888 - Recall: 0.9862 - val_loss: 0.0316 - val_accuracy: 0.9908 - val_Precision: 0.9917 - val_Recall: 0.9900 - lr: 1.0000e-05
# Epoch 10/15
# 132/132 [==============================] - ETA: 0s - loss: 0.0409 - accuracy: 0.9893 - Precision: 0.9902 - Recall: 0.9890
# Epoch 10: val_loss improved from 0.03156 to 0.03069, saving model to /content/drive/MyDrive/Colab Notebooks/EfficientNetV2B2_L1N32L2N16-RMS/EfficientNetV2B2_L1N32L2N16-RMS_H5_Model/EfficientNetV2B2_L1N32L2N16-RMS_FT_MCPBest.h5
# 132/132 [==============================] - 131s 992ms/step - loss: 0.0409 - accuracy: 0.9893 - Precision: 0.9902 - Recall: 0.9890 - val_loss: 0.0307 - val_accuracy: 0.9908 - val_Precision: 0.9917 - val_Recall: 0.9900 - lr: 1.0000e-05
# Epoch 11/15
# 132/132 [==============================] - ETA: 0s - loss: 0.0370 - accuracy: 0.9907 - Precision: 0.9914 - Recall: 0.9895
# Epoch 11: val_loss improved from 0.03069 to 0.02947, saving model to /content/drive/MyDrive/Colab Notebooks/EfficientNetV2B2_L1N32L2N16-RMS/EfficientNetV2B2_L1N32L2N16-RMS_H5_Model/EfficientNetV2B2_L1N32L2N16-RMS_FT_MCPBest.h5
# 132/132 [==============================] - 130s 982ms/step - loss: 0.0370 - accuracy: 0.9907 - Precision: 0.9914 - Recall: 0.9895 - val_loss: 0.0295 - val_accuracy: 0.9908 - val_Precision: 0.9917 - val_Recall: 0.9908 - lr: 1.0000e-05
# Epoch 12/15
# 132/132 [==============================] - ETA: 0s - loss: 0.0432 - accuracy: 0.9881 - Precision: 0.9890 - Recall: 0.9862
# Epoch 12: val_loss did not improve from 0.02947
# 132/132 [==============================] - 130s 984ms/step - loss: 0.0432 - accuracy: 0.9881 - Precision: 0.9890 - Recall: 0.9862 - val_loss: 0.0297 - val_accuracy: 0.9908 - val_Precision: 0.9917 - val_Recall: 0.9908 - lr: 1.0000e-05
# Epoch 13/15
# 132/132 [==============================] - ETA: 0s - loss: 0.0419 - accuracy: 0.9888 - Precision: 0.9900 - Recall: 0.9874
# Epoch 13: val_loss did not improve from 0.02947
# 132/132 [==============================] - 127s 964ms/step - loss: 0.0419 - accuracy: 0.9888 - Precision: 0.9900 - Recall: 0.9874 - val_loss: 0.0312 - val_accuracy: 0.9917 - val_Precision: 0.9925 - val_Recall: 0.9917 - lr: 1.0000e-05
# Epoch 14/15
# 132/132 [==============================] - ETA: 0s - loss: 0.0328 - accuracy: 0.9907 - Precision: 0.9926 - Recall: 0.9898
# Epoch 14: val_loss improved from 0.02947 to 0.02852, saving model to /content/drive/MyDrive/Colab Notebooks/EfficientNetV2B2_L1N32L2N16-RMS/EfficientNetV2B2_L1N32L2N16-RMS_H5_Model/EfficientNetV2B2_L1N32L2N16-RMS_FT_MCPBest.h5
# 132/132 [==============================] - 131s 991ms/step - loss: 0.0328 - accuracy: 0.9907 - Precision: 0.9926 - Recall: 0.9898 - val_loss: 0.0285 - val_accuracy: 0.9908 - val_Precision: 0.9917 - val_Recall: 0.9908 - lr: 1.0000e-05
# Epoch 15/15
# 132/132 [==============================] - ETA: 0s - loss: 0.0364 - accuracy: 0.9926 - Precision: 0.9931 - Recall: 0.9921
# Epoch 15: val_loss did not improve from 0.02852
# 132/132 [==============================] - 128s 968ms/step - loss: 0.0364 - accuracy: 0.9926 - Precision: 0.9931 - Recall: 0.9921 - val_loss: 0.0300 - val_accuracy: 0.9908 - val_Precision: 0.9917 - val_Recall: 0.9908 - lr: 1.0000e-05

# %% [markdown]
# ### II.4.4. Evaluation Fine Tune Model

# %%
# Evaluate the model on the Test Dataset using `evaluate`
# f1 = F1Score(test_generator.classes, Y_pred_classes)
ft_f1 = f1_score(test_generator.classes, Y_pred_classes, average = "macro")
print("F1 Score : ", ft_f1)
print("Evaluate on Test Data")
ft_results = model.evaluate(test_generator, batch_size = batch_size)
# Out:
# F1 Score :  0.978420690729068
# Evaluate on Test Data
# 19/19 [==============================] - 5s 287ms/step - loss: 0.0510 - accuracy: 0.9850 - Precision: 0.9850 - Recall: 0.9850

# %%
# Plot the Loss graph
plt.plot(ft_history.history["loss"])
plt.plot(ft_history.history["val_loss"])
plt.title("Model Loss")
plt.ylabel("loss")
plt.xlabel("epoch")
plt.legend(["Train", "Val"], loc = "upper left")
plt.show()

# %%
# Plot the Accuracy graph
plt.plot(ft_history.history["accuracy"])
plt.plot(ft_history.history["val_accuracy"])
plt.title("Model Accuracy")
plt.ylabel("Accuracy")
plt.xlabel("Epoch")
plt.legend(["Train", "Val"], loc = "lower left")
plt.show()

# %% [markdown]
# ### II.4.5. Fine Tuned Model : Confusion Matrix

# %%
# # Predict the values from the validation dataset
# Y_pred = model.predict(test_generator, steps = test_generator.samples // batch_size + 1)

# # Convert predictions classes from one hot vectors
# Y_pred_classes = np.argmax(Y_pred, axis = 1)

# Convert validation observations from one hot vectors
# Y_true = np.argmax(test_generator.classes, axis = 1)
# OR
Y_true = test_generator.classes

# Compute the confusion matrix
ft_cm = confusion_matrix(Y_true, Y_pred_classes)

# Print the confusion matrix
print("Confusion Matrix")
print(ft_cm)

# Retrieve class names (label)
names_from_dir = sorted(os.listdir(val_dir))
dict(enumerate(names_from_dir))
#OR
class_names = list(val_generator.class_indices.keys())
# Check if the both are similar
print(names_from_dir == class_names)

# Print the classification report
print("Classification Report")
print(classification_report(Y_true, Y_pred_classes, target_names = class_names, digits = 4))
# Out:
# Confusion Matrix
# [[196   4   0]
#  [  2 197   1]
#  [  0   6 194]]
# True
# Classification Report
#               precision    recall  f1-score   support
#
#          Bee     0.9899    0.9800    0.9849       200
#    Butterfly     0.9517    0.9850    0.9681       200
#      Ladybug     0.9949    0.9700    0.9823       200
#
#     accuracy                         0.9783       600
#    macro avg     0.9788    0.9783    0.9784       600
# weighted avg     0.9788    0.9783    0.9784       600

# %% [markdown]
# ### II.4.5. Fine Tuned Model : Confusion Matrix Graph

# %%
plot_confusion_matrix(ft_cm,
                      class_names,
                      normalize = True,
                      title = "Confusion matrix",
                      cmap = plt.cm.Blues
                      )
# Out:
# Normalized confusion matrix
# [[0.98  0.02  0.   ]
#  [0.01  0.985 0.005]
#  [0.    0.03  0.97 ]]
